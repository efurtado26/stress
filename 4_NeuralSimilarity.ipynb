# %% [markdown]
# ## Neural Similarity Analysis

# %%
import pandas as pd
import scipy.stats as scp
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf

outdir = "/Users/emilyfurtado/Box/HBN_study/stress_analysis/"
#outdir = '/Users/catcamacho/Library/CloudStorage/Box-Box/CCP/HBN_study/stress_analysis/'

#neural activation data
data_dm = pd.read_csv(outdir+"neural_similarity_analysis/activation/full_sample/dynamic_movieDM/subject_level_peak_activation.csv", index_col = 0)
data_dm.index.name = "sub"
data_dm["class"].replace("class01", "conflict", inplace = True)
data_dm["class"].replace("class02", "highstress", inplace = True)
data_dm["class"].replace("class03", "lowstress", inplace = True)
data_tp = pd.read_csv(outdir+"neural_similarity_analysis/activation/full_sample/dynamic_movieTP/subject_level_peak_activation.csv", index_col = 0)
data_tp.index.name = "sub"
data_tp["class"].replace("class01", "conflict", inplace = True)
data_tp["class"].replace("class02", "highstress", inplace = True)
data_tp["class"].replace("class03", "lowstress", inplace = True)

#full data including depression scores
dep_data = pd.read_csv(outdir+"full_data_20220124.csv", index_col = 0)
dep_data = dep_data.loc[:,["MFQ_P_Total", "MFQ_SR_Total", "MDD_mean"]]
dep_data.index.name = "sub"

# merge activation and full data
data_dm = data_dm.merge(dep_data, how = "left", left_index = True, right_index = True).drop_duplicates()
data_tp = data_tp.merge(dep_data, how = "left", left_index = True, right_index = True).drop_duplicates()

#MFQ factor scores 
dep_sr_factor = pd.read_csv(outdir+"MFQsr_factorscores_20220629.csv", index_col = 0)
dep_pr_factor = pd.read_csv(outdir+"MFQpr_factorscores_20220629.csv", index_col = 0)
dep_factor = dep_sr_factor.merge(dep_pr_factor, how = "left", left_index = True, right_index = True)
dep_factor = dep_factor.loc[:,["MFQ_P_NegEmotion", "MFQ_SR_NegEmotion"]]
dep_factor.index = ["sub-{0}".format(sub) for sub in dep_factor.index]
dep_factor.index.name = "subject_id"

# merge activation with mfq factor
data_dm_factor = data_dm.merge(dep_factor, how = "left", left_index = True, right_index = True).drop_duplicates()
data_tp_factor = data_tp.merge(dep_factor, how = "left", left_index = True, right_index = True).drop_duplicates()

# set up results dataframe
results = pd.DataFrame()
ind = 0

# %% [markdown]
# ##                                             ACTIVATION - STRESS

# %% [markdown]
# ## Ventral Attention Network

# %%
#weighted least squares regression model - movie DM (Discovery)
data_dm["class_string"] = data_dm["class"]
for x in range(1,13):
    res = smf.wls("VentralAttn_peak{0}_mean ~ age + class_string + female + meanFD".format(x), 
                  data = data_dm.loc[data_dm['site'] == "rubic",:]).fit()
    results.loc[ind, 'dataset'] = 'discovery'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'VentralAttn'
    results.loc[ind, 'sceneNo'] = x
    results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.highstress]']
    results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.highstress]']
    results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.lowstress]']
    results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.lowstress]']
    ind = ind + 1
    print(res.summary())
# Out:
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak1_mean   R-squared:                       0.071
# Model:                                WLS   Adj. R-squared:                  0.054
# Method:                     Least Squares   F-statistic:                     4.280
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):           0.000911
# Time:                            17:37:19   Log-Likelihood:                -941.58
# No. Observations:                     286   AIC:                             1895.
# Df Residuals:                         280   BIC:                             1917.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      8.4933      1.948      4.361      0.000       4.659      12.327
# class_string[T.highstress]     1.1944      1.110      1.076      0.283      -0.991       3.379
# class_string[T.lowstress]      0.6211      0.983      0.632      0.528      -1.313       2.555
# age                            0.3183      0.156      2.044      0.042       0.012       0.625
# female                        -1.5219      0.823     -1.849      0.065      -3.142       0.098
# meanFD                        -7.6042      2.549     -2.984      0.003     -12.621      -2.588
# ==============================================================================
# Omnibus:                        1.417   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.492   Jarque-Bera (JB):                1.140
# Skew:                          -0.130   Prob(JB):                        0.566
# Kurtosis:                       3.168   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak2_mean   R-squared:                       0.033
# Model:                                WLS   Adj. R-squared:                  0.016
# Method:                     Least Squares   F-statistic:                     1.905
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):             0.0936
# Time:                            17:37:19   Log-Likelihood:                -810.62
# No. Observations:                     286   AIC:                             1633.
# Df Residuals:                         280   BIC:                             1655.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      7.0541      1.232      5.725      0.000       4.629       9.479
# class_string[T.highstress]    -1.0416      0.702     -1.483      0.139      -2.424       0.341
# class_string[T.lowstress]     -0.5396      0.622     -0.868      0.386      -1.763       0.684
# age                            0.0008      0.099      0.008      0.993      -0.193       0.195
# female                        -0.1801      0.521     -0.346      0.730      -1.205       0.845
# meanFD                        -4.3895      1.612     -2.723      0.007      -7.563      -1.216
# ==============================================================================
# Omnibus:                        3.415   Durbin-Watson:                   1.824
# Prob(Omnibus):                  0.181   Jarque-Bera (JB):                3.140
# Skew:                           0.198   Prob(JB):                        0.208
# Kurtosis:                       3.327   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak3_mean   R-squared:                       0.067
# Model:                                WLS   Adj. R-squared:                  0.050
# Method:                     Least Squares   F-statistic:                     3.993
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):            0.00163
# Time:                            17:37:19   Log-Likelihood:                -863.38
# No. Observations:                     286   AIC:                             1739.
# Df Residuals:                         280   BIC:                             1761.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      9.9451      1.482      6.712      0.000       7.028      12.862
# class_string[T.highstress]    -1.2702      0.845     -1.504      0.134      -2.933       0.392
# class_string[T.lowstress]     -1.3078      0.747     -1.750      0.081      -2.779       0.164
# age                           -0.0741      0.118     -0.625      0.532      -0.307       0.159
# female                        -0.7506      0.626     -1.199      0.232      -1.983       0.482
# meanFD                        -7.8534      1.939     -4.051      0.000     -11.670      -4.037
# ==============================================================================
# Omnibus:                        4.855   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.088   Jarque-Bera (JB):                6.449
# Skew:                           0.056   Prob(JB):                       0.0398
# Kurtosis:                       3.727   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak4_mean   R-squared:                       0.066
# Model:                                WLS   Adj. R-squared:                  0.049
# Method:                     Least Squares   F-statistic:                     3.941
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):            0.00181
# Time:                            17:37:19   Log-Likelihood:                -945.76
# No. Observations:                     286   AIC:                             1904.
# Df Residuals:                         280   BIC:                             1925.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      5.7102      1.976      2.889      0.004       1.820       9.601
# class_string[T.highstress]     1.1557      1.126      1.026      0.306      -1.062       3.373
# class_string[T.lowstress]      0.3886      0.997      0.390      0.697      -1.574       2.351
# age                            0.2886      0.158      1.826      0.069      -0.023       0.600
# female                         0.8851      0.835      1.060      0.290      -0.759       2.529
# meanFD                        -7.9134      2.586     -3.060      0.002     -13.004      -2.823
# ==============================================================================
# Omnibus:                        0.393   Durbin-Watson:                   1.928
# Prob(Omnibus):                  0.821   Jarque-Bera (JB):                0.523
# Skew:                           0.062   Prob(JB):                        0.770
# Kurtosis:                       2.832   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak5_mean   R-squared:                       0.021
# Model:                                WLS   Adj. R-squared:                  0.004
# Method:                     Least Squares   F-statistic:                     1.200
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):              0.309
# Time:                            17:37:19   Log-Likelihood:                -919.74
# No. Observations:                     286   AIC:                             1851.
# Df Residuals:                         280   BIC:                             1873.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      4.1733      1.804      2.313      0.021       0.621       7.725
# class_string[T.highstress]     0.6194      1.028      0.602      0.547      -1.405       2.644
# class_string[T.lowstress]     -0.0771      0.910     -0.085      0.933      -1.869       1.715
# age                            0.0601      0.144      0.417      0.677      -0.224       0.344
# female                        -1.6152      0.762     -2.118      0.035      -3.116      -0.114
# meanFD                         0.3788      2.361      0.160      0.873      -4.269       5.027
# ==============================================================================
# Omnibus:                        2.368   Durbin-Watson:                   2.045
# Prob(Omnibus):                  0.306   Jarque-Bera (JB):                2.343
# Skew:                          -0.055   Prob(JB):                        0.310
# Kurtosis:                       3.430   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak6_mean   R-squared:                       0.044
# Model:                                WLS   Adj. R-squared:                  0.027
# Method:                     Least Squares   F-statistic:                     2.585
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):             0.0264
# Time:                            17:37:19   Log-Likelihood:                -874.29
# No. Observations:                     286   AIC:                             1761.
# Df Residuals:                         280   BIC:                             1783.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      6.7112      1.539      4.360      0.000       3.681       9.741
# class_string[T.highstress]    -0.9721      0.877     -1.108      0.269      -2.699       0.755
# class_string[T.lowstress]     -0.4136      0.777     -0.533      0.595      -1.942       1.115
# age                           -0.0968      0.123     -0.787      0.432      -0.339       0.145
# female                         0.1634      0.650      0.251      0.802      -1.117       1.444
# meanFD                        -6.5500      2.014     -3.252      0.001     -10.515      -2.585
# ==============================================================================
# Omnibus:                        7.392   Durbin-Watson:                   2.126
# Prob(Omnibus):                  0.025   Jarque-Bera (JB):                7.213
# Skew:                          -0.376   Prob(JB):                       0.0271
# Kurtosis:                       3.203   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak7_mean   R-squared:                       0.094
# Model:                                WLS   Adj. R-squared:                  0.077
# Method:                     Least Squares   F-statistic:                     5.782
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):           4.25e-05
# Time:                            17:37:19   Log-Likelihood:                -888.99
# No. Observations:                     286   AIC:                             1790.
# Df Residuals:                         280   BIC:                             1812.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -1.1912      1.621     -0.735      0.463      -4.381       1.999
# class_string[T.highstress]     0.4464      0.924      0.483      0.629      -1.372       2.265
# class_string[T.lowstress]     -0.1207      0.818     -0.148      0.883      -1.730       1.489
# age                            0.5513      0.130      4.255      0.000       0.296       0.806
# female                         1.2786      0.685      1.867      0.063      -0.069       2.626
# meanFD                        -3.1380      2.120     -1.480      0.140      -7.312       1.036
# ==============================================================================
# Omnibus:                        5.481   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.065   Jarque-Bera (JB):                7.838
# Skew:                           0.028   Prob(JB):                       0.0199
# Kurtosis:                       3.809   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak8_mean   R-squared:                       0.020
# Model:                                WLS   Adj. R-squared:                  0.002
# Method:                     Least Squares   F-statistic:                     1.132
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):              0.344
# Time:                            17:37:19   Log-Likelihood:                -881.41
# No. Observations:                     286   AIC:                             1775.
# Df Residuals:                         280   BIC:                             1797.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      4.6942      1.578      2.974      0.003       1.588       7.801
# class_string[T.highstress]     0.8442      0.899      0.939      0.349      -0.926       2.615
# class_string[T.lowstress]      1.2340      0.796      1.550      0.122      -0.333       2.801
# age                           -0.2050      0.126     -1.625      0.105      -0.453       0.043
# female                         0.0806      0.667      0.121      0.904      -1.232       1.393
# meanFD                        -2.4509      2.065     -1.187      0.236      -6.516       1.614
# ==============================================================================
# Omnibus:                        1.132   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.568   Jarque-Bera (JB):                0.877
# Skew:                          -0.114   Prob(JB):                        0.645
# Kurtosis:                       3.148   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak9_mean   R-squared:                       0.073
# Model:                                WLS   Adj. R-squared:                  0.056
# Method:                     Least Squares   F-statistic:                     4.404
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):           0.000707
# Time:                            17:37:19   Log-Likelihood:                -953.70
# No. Observations:                     286   AIC:                             1919.
# Df Residuals:                         280   BIC:                             1941.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.7945      2.032      0.391      0.696      -3.205       4.794
# class_string[T.highstress]     2.4294      1.158      2.098      0.037       0.150       4.709
# class_string[T.lowstress]      2.4226      1.025      2.363      0.019       0.405       4.440
# age                            0.2920      0.162      1.797      0.073      -0.028       0.612
# female                        -0.8098      0.859     -0.943      0.346      -2.500       0.880
# meanFD                        -6.7584      2.659     -2.542      0.012     -11.992      -1.525
# ==============================================================================
# Omnibus:                        1.352   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.509   Jarque-Bera (JB):                1.097
# Skew:                           0.046   Prob(JB):                        0.578
# Kurtosis:                       3.289   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak10_mean   R-squared:                       0.048
# Model:                                 WLS   Adj. R-squared:                  0.031
# Method:                      Least Squares   F-statistic:                     2.830
# Date:                     Thu, 01 Sep 2022   Prob (F-statistic):             0.0164
# Time:                             17:37:19   Log-Likelihood:                -939.77
# No. Observations:                      286   AIC:                             1892.
# Df Residuals:                          280   BIC:                             1913.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -0.2062      1.935     -0.107      0.915      -4.016       3.604
# class_string[T.highstress]     1.3306      1.103      1.206      0.229      -0.841       3.502
# class_string[T.lowstress]      1.0057      0.976      1.030      0.304      -0.916       2.928
# age                            0.3640      0.155      2.352      0.019       0.059       0.669
# female                        -0.3153      0.818     -0.386      0.700      -1.925       1.295
# meanFD                        -4.2378      2.532     -1.673      0.095      -9.223       0.747
# ==============================================================================
# Omnibus:                        0.968   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.616   Jarque-Bera (JB):                0.750
# Skew:                           0.112   Prob(JB):                        0.687
# Kurtosis:                       3.111   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak11_mean   R-squared:                       0.036
# Model:                                 WLS   Adj. R-squared:                  0.019
# Method:                      Least Squares   F-statistic:                     2.093
# Date:                     Thu, 01 Sep 2022   Prob (F-statistic):             0.0664
# Time:                             17:37:19   Log-Likelihood:                -930.95
# No. Observations:                      286   AIC:                             1874.
# Df Residuals:                          280   BIC:                             1896.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      2.9950      1.877      1.596      0.112      -0.699       6.689
# class_string[T.highstress]    -0.7194      1.070     -0.673      0.502      -2.825       1.386
# class_string[T.lowstress]      0.8232      0.947      0.869      0.385      -1.040       2.687
# age                            0.0336      0.150      0.224      0.823      -0.262       0.329
# female                         1.2044      0.793      1.519      0.130      -0.357       2.765
# meanFD                        -4.8944      2.456     -1.993      0.047      -9.728      -0.061
# ==============================================================================
# Omnibus:                        9.776   Durbin-Watson:                   2.251
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               11.009
# Skew:                          -0.340   Prob(JB):                      0.00407
# Kurtosis:                       3.679   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak12_mean   R-squared:                       0.055
# Model:                                 WLS   Adj. R-squared:                  0.038
# Method:                      Least Squares   F-statistic:                     3.238
# Date:                     Thu, 01 Sep 2022   Prob (F-statistic):            0.00737
# Time:                             17:37:20   Log-Likelihood:                -933.09
# No. Observations:                      286   AIC:                             1878.
# Df Residuals:                          280   BIC:                             1900.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      4.7321      1.891      2.503      0.013       1.010       8.454
# class_string[T.highstress]     0.7095      1.078      0.658      0.511      -1.412       2.831
# class_string[T.lowstress]     -1.4245      0.954     -1.493      0.136      -3.302       0.453
# age                            0.0739      0.151      0.489      0.625      -0.224       0.371
# female                         1.0238      0.799      1.282      0.201      -0.549       2.596
# meanFD                        -6.1020      2.474     -2.466      0.014     -10.972      -1.232
# ==============================================================================
# Omnibus:                        4.035   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.133   Jarque-Bera (JB):                3.894
# Skew:                           0.202   Prob(JB):                        0.143
# Kurtosis:                       3.405   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#weighted least squares regression model - movie DM (Replication)
data_dm["class_string"] = data_dm["class"]
for x in range(1,13):
    res = smf.wls("VentralAttn_peak{0}_mean ~ age + class_string + female + meanFD".format(x), 
                  data = data_dm.loc[data_dm['site'] == "cbic",:]).fit()
    results.loc[ind, 'dataset'] = 'replication'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'VentralAttn'
    results.loc[ind, 'sceneNo'] = x
    results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.highstress]']
    results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.highstress]']
    results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.lowstress]']
    results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.lowstress]']
    ind = ind + 1
    print(res.summary())
# Out:
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak1_mean   R-squared:                       0.054
# Model:                                WLS   Adj. R-squared:                  0.031
# Method:                     Least Squares   F-statistic:                     2.349
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):             0.0423
# Time:                            17:38:10   Log-Likelihood:                -694.16
# No. Observations:                     210   AIC:                             1400.
# Df Residuals:                         204   BIC:                             1420.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      4.9111      2.331      2.107      0.036       0.315       9.507
# class_string[T.highstress]     1.9720      1.294      1.524      0.129      -0.580       4.524
# class_string[T.lowstress]      1.5921      1.181      1.349      0.179      -0.736       3.920
# age                            0.3500      0.154      2.266      0.024       0.045       0.655
# female                         0.5503      0.953      0.578      0.564      -1.328       2.429
# meanFD                        -4.2467      2.748     -1.546      0.124      -9.664       1.171
# ==============================================================================
# Omnibus:                       24.177   Durbin-Watson:                   1.835
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.844
# Skew:                          -0.595   Prob(JB):                     1.83e-10
# Kurtosis:                       4.926   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak2_mean   R-squared:                       0.072
# Model:                                WLS   Adj. R-squared:                  0.049
# Method:                     Least Squares   F-statistic:                     3.157
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):            0.00909
# Time:                            17:38:10   Log-Likelihood:                -626.50
# No. Observations:                     210   AIC:                             1265.
# Df Residuals:                         204   BIC:                             1285.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     10.9429      1.689      6.479      0.000       7.613      14.273
# class_string[T.highstress]    -1.4673      0.938     -1.565      0.119      -3.316       0.382
# class_string[T.lowstress]     -1.3652      0.855     -1.596      0.112      -3.052       0.321
# age                            0.0152      0.112      0.136      0.892      -0.205       0.236
# female                         0.0836      0.690      0.121      0.904      -1.277       1.445
# meanFD                        -7.3221      1.991     -3.678      0.000     -11.247      -3.397
# ==============================================================================
# Omnibus:                        1.431   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.489   Jarque-Bera (JB):                1.123
# Skew:                          -0.049   Prob(JB):                        0.570
# Kurtosis:                       3.344   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak3_mean   R-squared:                       0.019
# Model:                                WLS   Adj. R-squared:                 -0.005
# Method:                     Least Squares   F-statistic:                    0.7884
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):              0.559
# Time:                            17:38:10   Log-Likelihood:                -672.63
# No. Observations:                     210   AIC:                             1357.
# Df Residuals:                         204   BIC:                             1377.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     10.2043      2.104      4.850      0.000       6.056      14.353
# class_string[T.highstress]    -0.2641      1.168     -0.226      0.821      -2.567       2.039
# class_string[T.lowstress]      0.1575      1.065      0.148      0.883      -1.943       2.258
# age                           -0.1333      0.139     -0.957      0.340      -0.408       0.141
# female                        -0.4125      0.860     -0.480      0.632      -2.108       1.283
# meanFD                        -3.8616      2.480     -1.557      0.121      -8.751       1.028
# ==============================================================================
# Omnibus:                       12.088   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               12.587
# Skew:                          -0.539   Prob(JB):                      0.00185
# Kurtosis:                       3.525   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak4_mean   R-squared:                       0.025
# Model:                                WLS   Adj. R-squared:                  0.001
# Method:                     Least Squares   F-statistic:                     1.029
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):              0.402
# Time:                            17:38:10   Log-Likelihood:                -710.24
# No. Observations:                     210   AIC:                             1432.
# Df Residuals:                         204   BIC:                             1453.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      4.4768      2.517      1.779      0.077      -0.485       9.439
# class_string[T.highstress]     1.0393      1.397      0.744      0.458      -1.716       3.794
# class_string[T.lowstress]      1.8227      1.274      1.430      0.154      -0.690       4.336
# age                           -0.0282      0.167     -0.169      0.866      -0.357       0.301
# female                         1.7555      1.028      1.707      0.089      -0.272       3.783
# meanFD                         0.1271      2.966      0.043      0.966      -5.722       5.976
# ==============================================================================
# Omnibus:                        5.880   Durbin-Watson:                   2.167
# Prob(Omnibus):                  0.053   Jarque-Bera (JB):                5.528
# Skew:                          -0.373   Prob(JB):                       0.0630
# Kurtosis:                       3.276   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak5_mean   R-squared:                       0.023
# Model:                                WLS   Adj. R-squared:                 -0.001
# Method:                     Least Squares   F-statistic:                    0.9763
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):              0.433
# Time:                            17:38:10   Log-Likelihood:                -695.85
# No. Observations:                     210   AIC:                             1404.
# Df Residuals:                         204   BIC:                             1424.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     10.0106      2.350      4.260      0.000       5.377      14.644
# class_string[T.highstress]    -1.7160      1.305     -1.315      0.190      -4.288       0.856
# class_string[T.lowstress]     -0.9213      1.190     -0.774      0.440      -3.268       1.425
# age                           -0.0471      0.156     -0.302      0.763      -0.354       0.260
# female                        -1.0429      0.960     -1.086      0.279      -2.936       0.851
# meanFD                        -3.7911      2.770     -1.369      0.173      -9.252       1.670
# ==============================================================================
# Omnibus:                        0.621   Durbin-Watson:                   2.083
# Prob(Omnibus):                  0.733   Jarque-Bera (JB):                0.418
# Skew:                          -0.100   Prob(JB):                        0.811
# Kurtosis:                       3.090   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak6_mean   R-squared:                       0.050
# Model:                                WLS   Adj. R-squared:                  0.027
# Method:                     Least Squares   F-statistic:                     2.159
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):             0.0600
# Time:                            17:38:10   Log-Likelihood:                -657.89
# No. Observations:                     210   AIC:                             1328.
# Df Residuals:                         204   BIC:                             1348.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     10.1755      1.961      5.188      0.000       6.308      14.043
# class_string[T.highstress]    -1.3753      1.089     -1.263      0.208      -3.522       0.772
# class_string[T.lowstress]     -1.3493      0.993     -1.358      0.176      -3.308       0.609
# age                           -0.0056      0.130     -0.043      0.966      -0.262       0.251
# female                        -0.4325      0.802     -0.540      0.590      -2.013       1.148
# meanFD                        -6.8373      2.312     -2.957      0.003     -11.396      -2.279
# ==============================================================================
# Omnibus:                       11.580   Durbin-Watson:                   2.109
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               11.928
# Skew:                          -0.532   Prob(JB):                      0.00257
# Kurtosis:                       3.479   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak7_mean   R-squared:                       0.008
# Model:                                WLS   Adj. R-squared:                 -0.016
# Method:                     Least Squares   F-statistic:                    0.3478
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):              0.883
# Time:                            17:38:10   Log-Likelihood:                -674.03
# No. Observations:                     210   AIC:                             1360.
# Df Residuals:                         204   BIC:                             1380.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      2.7645      2.118      1.305      0.193      -1.411       6.940
# class_string[T.highstress]     0.6693      1.176      0.569      0.570      -1.649       2.988
# class_string[T.lowstress]     -0.0178      1.073     -0.017      0.987      -2.133       2.097
# age                            0.1235      0.140      0.880      0.380      -0.153       0.400
# female                        -0.0211      0.866     -0.024      0.981      -1.728       1.686
# meanFD                         1.4607      2.497      0.585      0.559      -3.462       6.383
# ==============================================================================
# Omnibus:                        4.748   Durbin-Watson:                   2.121
# Prob(Omnibus):                  0.093   Jarque-Bera (JB):                4.838
# Skew:                          -0.364   Prob(JB):                       0.0890
# Kurtosis:                       2.846   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak8_mean   R-squared:                       0.035
# Model:                                WLS   Adj. R-squared:                  0.011
# Method:                     Least Squares   F-statistic:                     1.467
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):              0.202
# Time:                            17:38:11   Log-Likelihood:                -625.82
# No. Observations:                     210   AIC:                             1264.
# Df Residuals:                         204   BIC:                             1284.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      6.3175      1.684      3.752      0.000       2.998       9.637
# class_string[T.highstress]     0.4699      0.935      0.503      0.616      -1.373       2.313
# class_string[T.lowstress]     -0.9144      0.853     -1.073      0.285      -2.595       0.767
# age                           -0.0501      0.112     -0.450      0.654      -0.270       0.170
# female                         0.6045      0.688      0.879      0.381      -0.752       1.961
# meanFD                        -3.9730      1.984     -2.002      0.047      -7.886      -0.060
# ==============================================================================
# Omnibus:                        0.001   Durbin-Watson:                   1.891
# Prob(Omnibus):                  0.999   Jarque-Bera (JB):                0.037
# Skew:                           0.003   Prob(JB):                        0.981
# Kurtosis:                       2.935   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak9_mean   R-squared:                       0.070
# Model:                                WLS   Adj. R-squared:                  0.047
# Method:                     Least Squares   F-statistic:                     3.057
# Date:                    Thu, 01 Sep 2022   Prob (F-statistic):             0.0110
# Time:                            17:38:11   Log-Likelihood:                -702.15
# No. Observations:                     210   AIC:                             1416.
# Df Residuals:                         204   BIC:                             1436.
# Df Model:                               5
# Covariance Type:                nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      6.2764      2.421      2.592      0.010       1.502      11.051
# class_string[T.highstress]     1.7056      1.344      1.269      0.206      -0.945       4.356
# class_string[T.lowstress]      2.5185      1.226      2.054      0.041       0.101       4.936
# age                            0.0219      0.160      0.136      0.892      -0.294       0.338
# female                         0.2461      0.990      0.249      0.804      -1.705       2.197
# meanFD                        -8.8759      2.854     -3.110      0.002     -14.504      -3.248
# ==============================================================================
# Omnibus:                        0.717   Durbin-Watson:                   2.073
# Prob(Omnibus):                  0.699   Jarque-Bera (JB):                0.800
# Skew:                           0.020   Prob(JB):                        0.670
# Kurtosis:                       2.700   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak10_mean   R-squared:                       0.039
# Model:                                 WLS   Adj. R-squared:                  0.015
# Method:                      Least Squares   F-statistic:                     1.635
# Date:                     Thu, 01 Sep 2022   Prob (F-statistic):              0.152
# Time:                             17:38:11   Log-Likelihood:                -716.48
# No. Observations:                      210   AIC:                             1445.
# Df Residuals:                          204   BIC:                             1465.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      4.5792      2.592      1.766      0.079      -0.532       9.691
# class_string[T.highstress]     2.8425      1.439      1.975      0.050       0.005       5.680
# class_string[T.lowstress]      0.2856      1.313      0.218      0.828      -2.303       2.874
# age                            0.0810      0.172      0.471      0.638      -0.258       0.420
# female                         0.4541      1.059      0.429      0.669      -1.635       2.543
# meanFD                        -4.4237      3.056     -1.448      0.149     -10.449       1.601
# ==============================================================================
# Omnibus:                        4.362   Durbin-Watson:                   1.759
# Prob(Omnibus):                  0.113   Jarque-Bera (JB):                2.698
# Skew:                           0.013   Prob(JB):                        0.260
# Kurtosis:                       2.445   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak11_mean   R-squared:                       0.045
# Model:                                 WLS   Adj. R-squared:                  0.022
# Method:                      Least Squares   F-statistic:                     1.941
# Date:                     Thu, 01 Sep 2022   Prob (F-statistic):             0.0890
# Time:                             17:38:11   Log-Likelihood:                -693.59
# No. Observations:                      210   AIC:                             1399.
# Df Residuals:                          204   BIC:                             1419.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      8.1682      2.325      3.513      0.001       3.584      12.752
# class_string[T.highstress]     1.7561      1.291      1.361      0.175      -0.789       4.301
# class_string[T.lowstress]      2.1829      1.177      1.854      0.065      -0.138       4.504
# age                           -0.1697      0.154     -1.102      0.272      -0.473       0.134
# female                        -0.5149      0.950     -0.542      0.588      -2.388       1.358
# meanFD                        -5.4493      2.740     -1.989      0.048     -10.852      -0.046
# ==============================================================================
# Omnibus:                        2.137   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.343   Jarque-Bera (JB):                1.780
# Skew:                          -0.204   Prob(JB):                        0.411
# Kurtosis:                       3.193   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak12_mean   R-squared:                       0.021
# Model:                                 WLS   Adj. R-squared:                 -0.003
# Method:                      Least Squares   F-statistic:                    0.8780
# Date:                     Thu, 01 Sep 2022   Prob (F-statistic):              0.497
# Time:                             17:38:11   Log-Likelihood:                -727.23
# No. Observations:                      210   AIC:                             1466.
# Df Residuals:                          204   BIC:                             1487.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      1.1679      2.729      0.428      0.669      -4.212       6.548
# class_string[T.highstress]     0.5449      1.515      0.360      0.719      -2.442       3.532
# class_string[T.lowstress]     -0.5250      1.382     -0.380      0.704      -3.250       2.200
# age                            0.2959      0.181      1.637      0.103      -0.061       0.652
# female                         0.7234      1.115      0.649      0.517      -1.475       2.922
# meanFD                        -1.6909      3.216     -0.526      0.600      -8.033       4.651
# ==============================================================================
# Omnibus:                        2.927   Durbin-Watson:                   1.885
# Prob(Omnibus):                  0.231   Jarque-Bera (JB):                2.820
# Skew:                           0.135   Prob(JB):                        0.244
# Kurtosis:                       3.499   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#weighted least squares regression model - movie TP (Discovery)
data_tp["class_string"] = data_tp["class"]
for x in range(1,6):
    res = smf.wls("VentralAttn_peak{0}_mean ~ age + class_string + female + meanFD".format(x), 
                  data = data_tp.loc[data_tp['site'] == "rubic",:]).fit()
    results.loc[ind, 'dataset'] = 'discovery'
    results.loc[ind, 'movie'] = 'TP'
    results.loc[ind, 'networkDV'] = 'VentralAttn'
    results.loc[ind, 'sceneNo'] = x
    results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.class02]']
    results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.class02]']
    results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.class03]']
    results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.class03]']
    ind = ind + 1
    print(res.summary())
# Out:
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak1_mean   R-squared:                       0.056
# Model:                                WLS   Adj. R-squared:                  0.041
# Method:                     Least Squares   F-statistic:                     3.820
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):            0.00224
# Time:                            20:40:50   Log-Likelihood:                -1096.5
# No. Observations:                     329   AIC:                             2205.
# Df Residuals:                         323   BIC:                             2228.
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   3.2255      1.843      1.750      0.081      -0.401       6.852
# class_string[T.class02]     2.1327      1.039      2.054      0.041       0.090       4.176
# class_string[T.class03]     1.3496      0.951      1.419      0.157      -0.522       3.221
# age                         0.3342      0.148      2.262      0.024       0.044       0.625
# female                     -0.2938      0.802     -0.366      0.714      -1.872       1.284
# meanFD                     -5.1880      2.286     -2.270      0.024      -9.685      -0.692
# ==============================================================================
# Omnibus:                        1.633   Durbin-Watson:                   1.875
# Prob(Omnibus):                  0.442   Jarque-Bera (JB):                1.420
# Skew:                           0.153   Prob(JB):                        0.492
# Kurtosis:                       3.099   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak2_mean   R-squared:                       0.018
# Model:                                WLS   Adj. R-squared:                  0.002
# Method:                     Least Squares   F-statistic:                     1.155
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.331
# Time:                            20:40:50   Log-Likelihood:                -1100.0
# No. Observations:                     329   AIC:                             2212.
# Df Residuals:                         323   BIC:                             2235.
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   8.9559      1.863      4.807      0.000       5.291      12.621
# class_string[T.class02]     0.0636      1.050      0.061      0.952      -2.001       2.129
# class_string[T.class03]    -0.9744      0.961     -1.014      0.312      -2.866       0.917
# age                        -0.0711      0.149     -0.476      0.634      -0.365       0.223
# female                     -1.2841      0.811     -1.584      0.114      -2.879       0.311
# meanFD                     -3.0284      2.310     -1.311      0.191      -7.573       1.516
# ==============================================================================
# Omnibus:                       36.078   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               90.645
# Skew:                          -0.520   Prob(JB):                     2.07e-20
# Kurtosis:                       5.352   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak3_mean   R-squared:                       0.056
# Model:                                WLS   Adj. R-squared:                  0.042
# Method:                     Least Squares   F-statistic:                     3.857
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):            0.00208
# Time:                            20:40:50   Log-Likelihood:                -985.11
# No. Observations:                     329   AIC:                             1982.
# Df Residuals:                         323   BIC:                             2005.
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   6.1453      1.314      4.678      0.000       3.561       8.730
# class_string[T.class02]    -1.5969      0.740     -2.157      0.032      -3.053      -0.141
# class_string[T.class03]    -1.0765      0.678     -1.588      0.113      -2.410       0.257
# age                         0.0835      0.105      0.793      0.429      -0.124       0.291
# female                      0.3939      0.572      0.689      0.491      -0.731       1.519
# meanFD                     -5.8654      1.629     -3.601      0.000      -9.070      -2.661
# ==============================================================================
# Omnibus:                        3.926   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.140   Jarque-Bera (JB):                3.911
# Skew:                           0.170   Prob(JB):                        0.142
# Kurtosis:                       3.412   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak4_mean   R-squared:                       0.053
# Model:                                WLS   Adj. R-squared:                  0.039
# Method:                     Least Squares   F-statistic:                     3.631
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):            0.00328
# Time:                            20:40:50   Log-Likelihood:                -1089.8
# No. Observations:                     329   AIC:                             2192.
# Df Residuals:                         323   BIC:                             2214.
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   5.9511      1.806      3.296      0.001       2.399       9.504
# class_string[T.class02]     1.9141      1.017      1.881      0.061      -0.087       3.916
# class_string[T.class03]     0.6081      0.932      0.653      0.515      -1.225       2.442
# age                         0.0738      0.145      0.510      0.610      -0.211       0.359
# female                      0.7992      0.786      1.017      0.310      -0.747       2.345
# meanFD                     -7.4318      2.239     -3.319      0.001     -11.837      -3.027
# ==============================================================================
# Omnibus:                        0.930   Durbin-Watson:                   1.875
# Prob(Omnibus):                  0.628   Jarque-Bera (JB):                0.682
# Skew:                           0.066   Prob(JB):                        0.711
# Kurtosis:                       3.179   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak5_mean   R-squared:                       0.038
# Model:                                WLS   Adj. R-squared:                  0.023
# Method:                     Least Squares   F-statistic:                     2.565
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0270
# Time:                            20:40:50   Log-Likelihood:                -1050.3
# No. Observations:                     329   AIC:                             2113.
# Df Residuals:                         323   BIC:                             2135.
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   3.4611      1.601      2.161      0.031       0.310       6.612
# class_string[T.class02]     0.0966      0.902      0.107      0.915      -1.679       1.872
# class_string[T.class03]    -0.7357      0.826     -0.890      0.374      -2.362       0.890
# age                         0.2590      0.128      2.018      0.044       0.006       0.512
# female                     -0.6025      0.697     -0.865      0.388      -1.974       0.769
# meanFD                     -4.1499      1.986     -2.090      0.037      -8.057      -0.243
# ==============================================================================
# Omnibus:                        0.700   Durbin-Watson:                   2.265
# Prob(Omnibus):                  0.705   Jarque-Bera (JB):                0.786
# Skew:                          -0.007   Prob(JB):                        0.675
# Kurtosis:                       2.761   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#weighted least squares regression model - movie TP (Replication)
data_tp["class_string"] = data_tp["class"]
for x in range(1,6):
    res = smf.wls("VentralAttn_peak{0}_mean ~ age + class_string + female + meanFD".format(x), 
                  data = data_tp.loc[data_tp['site'] == "cbic",:]).fit()
    results.loc[ind, 'dataset'] = 'replication'
    results.loc[ind, 'movie'] = 'TP'
    results.loc[ind, 'networkDV'] = 'VentralAttn'
    results.loc[ind, 'sceneNo'] = x
    results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.class02]']
    results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.class02]']
    results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.class03]']
    results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.class03]']
    ind = ind + 1
    print(res.summary())
# Out:
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak1_mean   R-squared:                       0.051
# Model:                                WLS   Adj. R-squared:                  0.031
# Method:                     Least Squares   F-statistic:                     2.577
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0271
# Time:                            20:40:55   Log-Likelihood:                -824.84
# No. Observations:                     244   AIC:                             1662.
# Df Residuals:                         238   BIC:                             1683.
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   6.4353      2.260      2.847      0.005       1.983      10.887
# class_string[T.class02]     0.5390      1.334      0.404      0.686      -2.088       3.166
# class_string[T.class03]     1.0875      1.181      0.921      0.358      -1.239       3.414
# age                         0.2691      0.165      1.632      0.104      -0.056       0.594
# female                      1.5279      0.962      1.588      0.114      -0.367       3.423
# meanFD                     -5.7139      2.437     -2.345      0.020     -10.514      -0.914
# ==============================================================================
# Omnibus:                        1.444   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.486   Jarque-Bera (JB):                1.323
# Skew:                          -0.043   Prob(JB):                        0.516
# Kurtosis:                       2.650   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak2_mean   R-squared:                       0.032
# Model:                                WLS   Adj. R-squared:                  0.011
# Method:                     Least Squares   F-statistic:                     1.561
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.172
# Time:                            20:40:55   Log-Likelihood:                -789.76
# No. Observations:                     244   AIC:                             1592.
# Df Residuals:                         238   BIC:                             1613.
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   6.3597      1.957      3.249      0.001       2.504      10.216
# class_string[T.class02]     0.8641      1.155      0.748      0.455      -1.411       3.140
# class_string[T.class03]    -0.0888      1.023     -0.087      0.931      -2.104       1.926
# age                         0.1688      0.143      1.182      0.238      -0.113       0.450
# female                     -1.4745      0.833     -1.770      0.078      -3.116       0.167
# meanFD                     -2.9711      2.110     -1.408      0.160      -7.128       1.186
# ==============================================================================
# Omnibus:                        3.372   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.185   Jarque-Bera (JB):                3.073
# Skew:                           0.206   Prob(JB):                        0.215
# Kurtosis:                       3.363   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak3_mean   R-squared:                       0.032
# Model:                                WLS   Adj. R-squared:                  0.012
# Method:                     Least Squares   F-statistic:                     1.578
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.167
# Time:                            20:40:55   Log-Likelihood:                -735.10
# No. Observations:                     244   AIC:                             1482.
# Df Residuals:                         238   BIC:                             1503.
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   5.8794      1.564      3.758      0.000       2.797       8.961
# class_string[T.class02]    -0.6059      0.923     -0.656      0.512      -2.425       1.213
# class_string[T.class03]     0.5763      0.817      0.705      0.482      -1.034       2.187
# age                         0.0785      0.114      0.687      0.492      -0.146       0.303
# female                     -0.5619      0.666     -0.844      0.400      -1.874       0.750
# meanFD                     -3.3657      1.687     -1.995      0.047      -6.688      -0.043
# ==============================================================================
# Omnibus:                        0.644   Durbin-Watson:                   1.851
# Prob(Omnibus):                  0.725   Jarque-Bera (JB):                0.745
# Skew:                           0.114   Prob(JB):                        0.689
# Kurtosis:                       2.852   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak4_mean   R-squared:                       0.062
# Model:                                WLS   Adj. R-squared:                  0.042
# Method:                     Least Squares   F-statistic:                     3.140
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):            0.00916
# Time:                            20:40:56   Log-Likelihood:                -800.23
# No. Observations:                     244   AIC:                             1612.
# Df Residuals:                         238   BIC:                             1633.
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   2.3223      2.043      1.137      0.257      -1.703       6.347
# class_string[T.class02]     1.3362      1.206      1.108      0.269      -1.039       3.711
# class_string[T.class03]     1.5415      1.068      1.444      0.150      -0.562       3.645
# age                         0.2394      0.149      1.606      0.110      -0.054       0.533
# female                      2.0094      0.870      2.310      0.022       0.296       3.723
# meanFD                     -4.4394      2.203     -2.015      0.045      -8.779      -0.100
# ==============================================================================
# Omnibus:                        1.097   Durbin-Watson:                   2.052
# Prob(Omnibus):                  0.578   Jarque-Bera (JB):                0.907
# Skew:                          -0.145   Prob(JB):                        0.635
# Kurtosis:                       3.070   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak5_mean   R-squared:                       0.060
# Model:                                WLS   Adj. R-squared:                  0.040
# Method:                     Least Squares   F-statistic:                     3.026
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0114
# Time:                            20:40:56   Log-Likelihood:                -823.02
# No. Observations:                     244   AIC:                             1658.
# Df Residuals:                         238   BIC:                             1679.
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -0.2410      2.243     -0.107      0.915      -4.660       4.178
# class_string[T.class02]     0.3499      1.324      0.264      0.792      -2.258       2.958
# class_string[T.class03]     0.7278      1.172      0.621      0.535      -1.581       3.037
# age                         0.5538      0.164      3.384      0.001       0.231       0.876
# female                      1.1127      0.955      1.165      0.245      -0.768       2.994
# meanFD                      0.1785      2.418      0.074      0.941      -4.586       4.943
# ==============================================================================
# Omnibus:                        2.199   Durbin-Watson:                   1.852
# Prob(Omnibus):                  0.333   Jarque-Bera (JB):                1.882
# Skew:                           0.199   Prob(JB):                        0.390
# Kurtosis:                       3.165   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Default Mode Network

# %%
#weighted least squares regression model - movie DM (Discovery)
data_dm["class_string"] = data_dm["class"]
for x in range(1,10):
    res = smf.wls("Default_peak{0}_mean ~ age + class_string + female + meanFD".format(x), 
                  data = data_dm.loc[data_dm['site'] == "rubic",:]).fit()
    results.loc[ind, 'dataset'] = 'discovery'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'Default'
    results.loc[ind, 'sceneNo'] = x
    results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.class02]']
    results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.class02]']
    results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.class03]']
    results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.class03]']
    ind = ind + 1
    print(res.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak1_mean   R-squared:                       0.095
# Model:                            WLS   Adj. R-squared:                  0.079
# Method:                 Least Squares   F-statistic:                     5.906
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):           3.29e-05
# Time:                        20:40:58   Log-Likelihood:                -809.05
# No. Observations:                 286   AIC:                             1630.
# Df Residuals:                     280   BIC:                             1652.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   5.5413      1.225      4.522      0.000       3.129       7.953
# class_string[T.class02]     0.4405      0.698      0.631      0.529      -0.934       1.815
# class_string[T.class03]     0.6741      0.618      1.091      0.276      -0.543       1.891
# age                         0.0291      0.098      0.297      0.767      -0.164       0.222
# female                      0.2468      0.518      0.477      0.634      -0.772       1.266
# meanFD                     -8.0071      1.603     -4.994      0.000     -11.163      -4.851
# ==============================================================================
# Omnibus:                        1.190   Durbin-Watson:                   2.173
# Prob(Omnibus):                  0.552   Jarque-Bera (JB):                1.085
# Skew:                          -0.151   Prob(JB):                        0.581
# Kurtosis:                       3.014   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak2_mean   R-squared:                       0.106
# Model:                            WLS   Adj. R-squared:                  0.090
# Method:                 Least Squares   F-statistic:                     6.625
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):           7.55e-06
# Time:                        20:40:58   Log-Likelihood:                -830.66
# No. Observations:                 286   AIC:                             1673.
# Df Residuals:                     280   BIC:                             1695.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   8.6554      1.322      6.550      0.000       6.054      11.257
# class_string[T.class02]    -0.6465      0.753     -0.858      0.391      -2.129       0.836
# class_string[T.class03]    -1.3489      0.667     -2.023      0.044      -2.661      -0.037
# age                        -0.2097      0.106     -1.984      0.048      -0.418      -0.002
# female                      0.1997      0.558      0.358      0.721      -0.900       1.299
# meanFD                     -8.5675      1.729     -4.955      0.000     -11.971      -5.164
# ==============================================================================
# Omnibus:                        2.516   Durbin-Watson:                   1.850
# Prob(Omnibus):                  0.284   Jarque-Bera (JB):                2.590
# Skew:                          -0.208   Prob(JB):                        0.274
# Kurtosis:                       2.791   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak3_mean   R-squared:                       0.030
# Model:                            WLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     1.755
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.122
# Time:                        20:40:58   Log-Likelihood:                -833.79
# No. Observations:                 286   AIC:                             1680.
# Df Residuals:                     280   BIC:                             1702.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   2.7973      1.336      2.094      0.037       0.167       5.427
# class_string[T.class02]     0.4442      0.761      0.583      0.560      -1.055       1.943
# class_string[T.class03]    -0.6358      0.674     -0.943      0.346      -1.963       0.691
# age                         0.0266      0.107      0.249      0.803      -0.184       0.237
# female                      0.9533      0.565      1.689      0.092      -0.158       2.065
# meanFD                     -2.2213      1.748     -1.271      0.205      -5.663       1.220
# ==============================================================================
# Omnibus:                        0.695   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.706   Jarque-Bera (JB):                0.458
# Skew:                          -0.064   Prob(JB):                        0.795
# Kurtosis:                       3.148   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak4_mean   R-squared:                       0.052
# Model:                            WLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     3.043
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0108
# Time:                        20:40:58   Log-Likelihood:                -796.97
# No. Observations:                 286   AIC:                             1606.
# Df Residuals:                     280   BIC:                             1628.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   2.2022      1.175      1.875      0.062      -0.110       4.515
# class_string[T.class02]    -0.6709      0.670     -1.002      0.317      -1.989       0.647
# class_string[T.class03]     0.0445      0.593      0.075      0.940      -1.122       1.211
# age                         0.1987      0.094      2.115      0.035       0.014       0.384
# female                      0.7601      0.496      1.531      0.127      -0.217       1.737
# meanFD                     -3.5688      1.537     -2.322      0.021      -6.594      -0.543
# ==============================================================================
# Omnibus:                        6.384   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                9.536
# Skew:                          -0.072   Prob(JB):                      0.00850
# Kurtosis:                       3.883   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak5_mean   R-squared:                       0.005
# Model:                            WLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.2918
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.917
# Time:                        20:40:58   Log-Likelihood:                -852.29
# No. Observations:                 286   AIC:                             1717.
# Df Residuals:                     280   BIC:                             1739.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   3.4574      1.425      2.426      0.016       0.652       6.263
# class_string[T.class02]    -0.2233      0.812     -0.275      0.784      -1.822       1.376
# class_string[T.class03]    -0.3503      0.719     -0.487      0.627      -1.766       1.065
# age                         0.1139      0.114      1.000      0.318      -0.110       0.338
# female                     -0.0993      0.602     -0.165      0.869      -1.285       1.086
# meanFD                     -0.6684      1.865     -0.358      0.720      -4.340       3.003
# ==============================================================================
# Omnibus:                        4.255   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.119   Jarque-Bera (JB):                4.220
# Skew:                           0.297   Prob(JB):                        0.121
# Kurtosis:                       2.967   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak6_mean   R-squared:                       0.067
# Model:                            WLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     4.038
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):            0.00149
# Time:                        20:40:58   Log-Likelihood:                -791.07
# No. Observations:                 286   AIC:                             1594.
# Df Residuals:                     280   BIC:                             1616.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   2.0656      1.151      1.795      0.074      -0.199       4.331
# class_string[T.class02]     0.1233      0.656      0.188      0.851      -1.168       1.414
# class_string[T.class03]    -0.7404      0.581     -1.275      0.203      -1.883       0.402
# age                         0.1620      0.092      1.760      0.079      -0.019       0.343
# female                      0.2432      0.486      0.500      0.617      -0.714       1.200
# meanFD                     -4.9243      1.506     -3.270      0.001      -7.888      -1.960
# ==============================================================================
# Omnibus:                       25.229   Durbin-Watson:                   2.068
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.547
# Skew:                          -0.590   Prob(JB):                     1.16e-08
# Kurtosis:                       4.293   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak7_mean   R-squared:                       0.059
# Model:                            WLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     3.490
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):            0.00446
# Time:                        20:40:58   Log-Likelihood:                -832.64
# No. Observations:                 286   AIC:                             1677.
# Df Residuals:                     280   BIC:                             1699.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   4.3535      1.331      3.272      0.001       1.734       6.973
# class_string[T.class02]     0.3687      0.758      0.486      0.627      -1.124       1.862
# class_string[T.class03]     0.0694      0.671      0.103      0.918      -1.252       1.391
# age                        -0.0522      0.106     -0.491      0.624      -0.262       0.157
# female                      0.7426      0.562      1.321      0.188      -0.364       1.849
# meanFD                     -6.2920      1.741     -3.613      0.000      -9.720      -2.864
# ==============================================================================
# Omnibus:                       10.795   Durbin-Watson:                   2.128
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               11.453
# Skew:                          -0.401   Prob(JB):                      0.00326
# Kurtosis:                       3.563   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak8_mean   R-squared:                       0.065
# Model:                            WLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     3.874
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):            0.00207
# Time:                        20:40:58   Log-Likelihood:                -813.42
# No. Observations:                 286   AIC:                             1639.
# Df Residuals:                     280   BIC:                             1661.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   5.4679      1.244      4.395      0.000       3.019       7.917
# class_string[T.class02]     1.4256      0.709      2.010      0.045       0.030       2.822
# class_string[T.class03]     0.9003      0.628      1.434      0.153      -0.335       2.136
# age                        -0.2665      0.099     -2.678      0.008      -0.462      -0.071
# female                     -0.2616      0.526     -0.498      0.619      -1.297       0.773
# meanFD                     -5.6471      1.628     -3.468      0.001      -8.852      -2.442
# ==============================================================================
# Omnibus:                        0.087   Durbin-Watson:                   2.123
# Prob(Omnibus):                  0.957   Jarque-Bera (JB):                0.147
# Skew:                          -0.040   Prob(JB):                        0.929
# Kurtosis:                       2.924   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak9_mean   R-squared:                       0.006
# Model:                            WLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.3251
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.898
# Time:                        20:40:58   Log-Likelihood:                -853.71
# No. Observations:                 286   AIC:                             1719.
# Df Residuals:                     280   BIC:                             1741.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   2.8846      1.432      2.014      0.045       0.065       5.704
# class_string[T.class02]     0.0383      0.816      0.047      0.963      -1.569       1.645
# class_string[T.class03]    -0.1118      0.723     -0.155      0.877      -1.534       1.311
# age                        -0.0821      0.115     -0.717      0.474      -0.308       0.143
# female                      0.5283      0.605      0.873      0.384      -0.663       1.720
# meanFD                      0.4817      1.874      0.257      0.797      -3.208       4.171
# ==============================================================================
# Omnibus:                        0.938   Durbin-Watson:                   1.920
# Prob(Omnibus):                  0.626   Jarque-Bera (JB):                0.670
# Skew:                          -0.019   Prob(JB):                        0.715
# Kurtosis:                       3.234   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#weighted least squares regression model - movie DM (Replication)
data_dm["class_string"] = data_dm["class"]
for x in range(1,10):
    res = smf.wls("Default_peak{0}_mean ~ age + class_string + female + meanFD".format(x), 
                  data = data_dm.loc[data_dm['site'] == "cbic",:]).fit()
    results.loc[ind, 'dataset'] = 'replication'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'Default'
    results.loc[ind, 'sceneNo'] = x
    results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.class02]']
    results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.class02]']
    results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.class03]']
    results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.class03]']
    ind = ind + 1
    print(res.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak1_mean   R-squared:                       0.021
# Model:                            WLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.8623
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.507
# Time:                        20:41:00   Log-Likelihood:                -630.87
# No. Observations:                 210   AIC:                             1274.
# Df Residuals:                     204   BIC:                             1294.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   6.9899      1.725      4.053      0.000       3.590      10.390
# class_string[T.class02]    -0.2509      0.957     -0.262      0.794      -2.139       1.637
# class_string[T.class03]     0.2349      0.873      0.269      0.788      -1.487       1.957
# age                        -0.0993      0.114     -0.869      0.386      -0.325       0.126
# female                      0.4250      0.705      0.603      0.547      -0.965       1.815
# meanFD                     -3.4645      2.033     -1.704      0.090      -7.472       0.543
# ==============================================================================
# Omnibus:                       11.077   Durbin-Watson:                   1.852
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.718
# Skew:                          -0.483   Prob(JB):                      0.00285
# Kurtosis:                       3.638   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak2_mean   R-squared:                       0.031
# Model:                            WLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     1.317
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.258
# Time:                        20:41:00   Log-Likelihood:                -632.79
# No. Observations:                 210   AIC:                             1278.
# Df Residuals:                     204   BIC:                             1298.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   5.9614      1.740      3.425      0.001       2.530       9.393
# class_string[T.class02]     0.8474      0.966      0.877      0.382      -1.058       2.752
# class_string[T.class03]     0.0040      0.881      0.005      0.996      -1.734       1.742
# age                        -0.1100      0.115     -0.954      0.341      -0.337       0.117
# female                     -0.9092      0.711     -1.278      0.203      -2.311       0.493
# meanFD                     -3.0893      2.051     -1.506      0.134      -7.134       0.955
# ==============================================================================
# Omnibus:                        1.096   Durbin-Watson:                   1.908
# Prob(Omnibus):                  0.578   Jarque-Bera (JB):                0.774
# Skew:                           0.020   Prob(JB):                        0.679
# Kurtosis:                       3.295   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak3_mean   R-squared:                       0.034
# Model:                            WLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1.430
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.215
# Time:                        20:41:00   Log-Likelihood:                -591.97
# No. Observations:                 210   AIC:                             1196.
# Df Residuals:                     204   BIC:                             1216.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   1.7642      1.433      1.231      0.220      -1.061       4.589
# class_string[T.class02]     0.9254      0.796      1.163      0.246      -0.643       2.494
# class_string[T.class03]     0.7961      0.726      1.097      0.274      -0.635       2.227
# age                         0.1430      0.095      1.506      0.134      -0.044       0.330
# female                      0.6792      0.586      1.160      0.247      -0.475       1.834
# meanFD                     -1.8787      1.689     -1.112      0.267      -5.209       1.451
# ==============================================================================
# Omnibus:                        1.533   Durbin-Watson:                   1.817
# Prob(Omnibus):                  0.465   Jarque-Bera (JB):                1.577
# Skew:                          -0.202   Prob(JB):                        0.454
# Kurtosis:                       2.869   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak4_mean   R-squared:                       0.058
# Model:                            WLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     2.522
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0306
# Time:                        20:41:01   Log-Likelihood:                -573.65
# No. Observations:                 210   AIC:                             1159.
# Df Residuals:                     204   BIC:                             1179.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   0.3160      1.313      0.241      0.810      -2.273       2.905
# class_string[T.class02]     0.3552      0.729      0.487      0.627      -1.082       1.793
# class_string[T.class03]    -0.4149      0.665     -0.624      0.533      -1.726       0.896
# age                         0.2408      0.087      2.767      0.006       0.069       0.412
# female                      0.6675      0.537      1.244      0.215      -0.391       1.726
# meanFD                     -1.4997      1.548     -0.969      0.334      -4.552       1.552
# ==============================================================================
# Omnibus:                        0.271   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.873   Jarque-Bera (JB):                0.270
# Skew:                          -0.084   Prob(JB):                        0.874
# Kurtosis:                       2.951   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak5_mean   R-squared:                       0.004
# Model:                            WLS   Adj. R-squared:                 -0.020
# Method:                 Least Squares   F-statistic:                    0.1761
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.971
# Time:                        20:41:01   Log-Likelihood:                -636.46
# No. Observations:                 210   AIC:                             1285.
# Df Residuals:                     204   BIC:                             1305.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   2.0107      1.771      1.135      0.258      -1.481       5.503
# class_string[T.class02]     0.2989      0.983      0.304      0.761      -1.640       2.238
# class_string[T.class03]     0.2321      0.897      0.259      0.796      -1.536       2.001
# age                        -0.0467      0.117     -0.398      0.691      -0.278       0.185
# female                     -0.2979      0.724     -0.412      0.681      -1.725       1.129
# meanFD                      1.4216      2.088      0.681      0.497      -2.694       5.538
# ==============================================================================
# Omnibus:                        2.974   Durbin-Watson:                   2.102
# Prob(Omnibus):                  0.226   Jarque-Bera (JB):                2.582
# Skew:                           0.247   Prob(JB):                        0.275
# Kurtosis:                       3.226   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak6_mean   R-squared:                       0.094
# Model:                            WLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     4.231
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):            0.00111
# Time:                        20:41:01   Log-Likelihood:                -600.49
# No. Observations:                 210   AIC:                             1213.
# Df Residuals:                     204   BIC:                             1233.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   4.3214      1.492      2.896      0.004       1.379       7.264
# class_string[T.class02]     1.1378      0.829      1.373      0.171      -0.496       2.771
# class_string[T.class03]     1.0871      0.756      1.439      0.152      -0.403       2.577
# age                         0.0177      0.099      0.179      0.858      -0.177       0.213
# female                      1.4970      0.610      2.455      0.015       0.295       2.699
# meanFD                     -6.2426      1.759     -3.549      0.000      -9.711      -2.775
# ==============================================================================
# Omnibus:                        4.631   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.099   Jarque-Bera (JB):                4.238
# Skew:                          -0.307   Prob(JB):                        0.120
# Kurtosis:                       3.329   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak7_mean   R-squared:                       0.044
# Model:                            WLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     1.876
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.100
# Time:                        20:41:01   Log-Likelihood:                -647.79
# No. Observations:                 210   AIC:                             1308.
# Df Residuals:                     204   BIC:                             1328.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   6.7928      1.869      3.634      0.000       3.107      10.478
# class_string[T.class02]     0.1013      1.038      0.098      0.922      -1.945       2.147
# class_string[T.class03]     0.4010      0.947      0.424      0.672      -1.465       2.267
# age                        -0.3492      0.124     -2.820      0.005      -0.593      -0.105
# female                     -0.3833      0.764     -0.502      0.616      -1.889       1.123
# meanFD                     -1.7113      2.203     -0.777      0.438      -6.055       2.633
# ==============================================================================
# Omnibus:                        0.172   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.917   Jarque-Bera (JB):                0.318
# Skew:                          -0.027   Prob(JB):                        0.853
# Kurtosis:                       2.817   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak8_mean   R-squared:                       0.026
# Model:                            WLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.068
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.379
# Time:                        20:41:01   Log-Likelihood:                -605.70
# No. Observations:                 210   AIC:                             1223.
# Df Residuals:                     204   BIC:                             1243.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   4.0602      1.530      2.654      0.009       1.044       7.076
# class_string[T.class02]    -0.3774      0.849     -0.444      0.657      -2.052       1.297
# class_string[T.class03]    -0.4179      0.775     -0.539      0.590      -1.945       1.110
# age                        -0.1782      0.101     -1.759      0.080      -0.378       0.022
# female                      0.9376      0.625      1.500      0.135      -0.295       2.170
# meanFD                     -0.3433      1.803     -0.190      0.849      -3.899       3.212
# ==============================================================================
# Omnibus:                        4.464   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.107   Jarque-Bera (JB):                4.145
# Skew:                          -0.275   Prob(JB):                        0.126
# Kurtosis:                       3.414   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak9_mean   R-squared:                       0.031
# Model:                            WLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     1.307
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.262
# Time:                        20:41:01   Log-Likelihood:                -622.66
# No. Observations:                 210   AIC:                             1257.
# Df Residuals:                     204   BIC:                             1277.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -1.3098      1.658     -0.790      0.431      -4.580       1.960
# class_string[T.class02]     0.6517      0.921      0.708      0.480      -1.164       2.467
# class_string[T.class03]    -0.1943      0.840     -0.231      0.817      -1.850       1.462
# age                         0.2125      0.110      1.934      0.055      -0.004       0.429
# female                      0.4100      0.678      0.605      0.546      -0.926       1.746
# meanFD                      1.6911      1.955      0.865      0.388      -2.163       5.545
# ==============================================================================
# Omnibus:                        0.306   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.858   Jarque-Bera (JB):                0.192
# Skew:                           0.072   Prob(JB):                        0.909
# Kurtosis:                       3.033   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#weighted least squares regression model - movie TP (Discovery)
data_tp["class_string"] = data_tp["class"]
for x in range(1,6):
    if 'Default_peak{0}_mean'.format(x) in data_tp.columns:
        res = smf.wls("Default_peak{0}_mean ~ age + class_string + female + meanFD".format(x), 
                      data = data_tp.loc[data_tp['site'] == "rubic",:]).fit()
        results.loc[ind, 'dataset'] = 'discovery'
        results.loc[ind, 'movie'] = 'TP'
        results.loc[ind, 'networkDV'] = 'Default'
        results.loc[ind, 'sceneNo'] = x
        results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.class02]']
        results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.class02]']
        results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.class03]']
        results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.class03]']
        ind = ind + 1
    else:
        break
    print(res.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak1_mean   R-squared:                       0.019
# Model:                            WLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.267
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.278
# Time:                        20:41:01   Log-Likelihood:                -912.42
# No. Observations:                 329   AIC:                             1837.
# Df Residuals:                     323   BIC:                             1860.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   2.2158      1.053      2.104      0.036       0.144       4.288
# class_string[T.class02]     0.4048      0.593      0.682      0.496      -0.763       1.572
# class_string[T.class03]     0.6094      0.544      1.121      0.263      -0.460       1.679
# age                         0.1117      0.084      1.323      0.187      -0.054       0.278
# female                      0.2596      0.458      0.566      0.572      -0.642       1.161
# meanFD                     -1.8150      1.306     -1.390      0.166      -4.384       0.754
# ==============================================================================
# Omnibus:                       19.694   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.158
# Skew:                          -0.339   Prob(JB):                     8.54e-09
# Kurtosis:                       4.501   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak2_mean   R-squared:                       0.065
# Model:                            WLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     4.456
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):           0.000612
# Time:                        20:41:01   Log-Likelihood:                -876.07
# No. Observations:                 329   AIC:                             1764.
# Df Residuals:                     323   BIC:                             1787.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   3.4732      0.943      3.683      0.000       1.618       5.329
# class_string[T.class02]    -0.3674      0.531     -0.691      0.490      -1.413       0.678
# class_string[T.class03]     0.1486      0.487      0.305      0.760      -0.809       1.106
# age                         0.1156      0.076      1.529      0.127      -0.033       0.264
# female                     -0.3545      0.410     -0.864      0.388      -1.162       0.453
# meanFD                     -4.7171      1.169     -4.034      0.000      -7.018      -2.416
# ==============================================================================
# Omnibus:                        6.120   Durbin-Watson:                   1.874
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                5.875
# Skew:                           0.310   Prob(JB):                       0.0530
# Kurtosis:                       3.209   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak3_mean   R-squared:                       0.056
# Model:                            WLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     3.864
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):            0.00205
# Time:                        20:41:01   Log-Likelihood:                -887.91
# No. Observations:                 329   AIC:                             1788.
# Df Residuals:                     323   BIC:                             1811.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   0.5330      0.978      0.545      0.586      -1.390       2.456
# class_string[T.class02]    -0.7713      0.551     -1.400      0.162      -1.855       0.312
# class_string[T.class03]    -0.1603      0.505     -0.318      0.751      -1.153       0.832
# age                         0.2148      0.078      2.741      0.006       0.061       0.369
# female                      1.1274      0.425      2.650      0.008       0.290       1.964
# meanFD                     -2.2651      1.212     -1.868      0.063      -4.650       0.120
# ==============================================================================
# Omnibus:                        4.218   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.121   Jarque-Bera (JB):                5.359
# Skew:                          -0.009   Prob(JB):                       0.0686
# Kurtosis:                       3.625   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#weighted least squares regression model - movie TP (Replication)
data_tp["class_string"] = data_tp["class"]
for x in range(1,6):
    if 'Default_peak{0}_mean'.format(x) in data_tp.columns:
        res = smf.wls("Default_peak{0}_mean ~ age + class_string + female + meanFD".format(x), 
                      data = data_tp.loc[data_tp['site'] == "cbic",:]).fit()
        results.loc[ind, 'dataset'] = 'replication'
        results.loc[ind, 'movie'] = 'TP'
        results.loc[ind, 'networkDV'] = 'Default'
        results.loc[ind, 'sceneNo'] = x
        results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.class02]']
        results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.class02]']
        results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.class03]']
        results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.class03]']
        ind = ind + 1
    else:
        break
    print(res.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak1_mean   R-squared:                       0.089
# Model:                            WLS   Adj. R-squared:                  0.070
# Method:                 Least Squares   F-statistic:                     4.648
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):           0.000456
# Time:                        20:41:02   Log-Likelihood:                -688.56
# No. Observations:                 244   AIC:                             1389.
# Df Residuals:                     238   BIC:                             1410.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   1.2964      1.293      1.003      0.317      -1.250       3.843
# class_string[T.class02]     1.1114      0.763      1.457      0.146      -0.392       2.614
# class_string[T.class03]     1.1611      0.676      1.719      0.087      -0.170       2.492
# age                         0.1949      0.094      2.067      0.040       0.009       0.381
# female                      1.6163      0.550      2.937      0.004       0.532       2.700
# meanFD                     -2.9621      1.394     -2.125      0.035      -5.708      -0.216
# ==============================================================================
# Omnibus:                        6.199   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.045   Jarque-Bera (JB):                6.219
# Skew:                           0.391   Prob(JB):                       0.0446
# Kurtosis:                       2.989   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak2_mean   R-squared:                       0.031
# Model:                            WLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     1.528
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.182
# Time:                        20:41:02   Log-Likelihood:                -714.82
# No. Observations:                 244   AIC:                             1442.
# Df Residuals:                     238   BIC:                             1463.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   6.7313      1.440      4.675      0.000       3.895       9.568
# class_string[T.class02]    -1.1192      0.850     -1.317      0.189      -2.793       0.554
# class_string[T.class03]    -1.0504      0.752     -1.396      0.164      -2.532       0.432
# age                        -0.1875      0.105     -1.785      0.076      -0.394       0.019
# female                     -0.1248      0.613     -0.204      0.839      -1.332       1.082
# meanFD                     -2.0830      1.552     -1.342      0.181      -5.141       0.975
# ==============================================================================
# Omnibus:                        4.439   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.109   Jarque-Bera (JB):                4.210
# Skew:                           0.246   Prob(JB):                        0.122
# Kurtosis:                       3.414   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak3_mean   R-squared:                       0.014
# Model:                            WLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.6596
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.654
# Time:                        20:41:03   Log-Likelihood:                -682.75
# No. Observations:                 244   AIC:                             1377.
# Df Residuals:                     238   BIC:                             1398.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   2.1705      1.262      1.719      0.087      -0.316       4.657
# class_string[T.class02]     0.1825      0.745      0.245      0.807      -1.285       1.650
# class_string[T.class03]     0.7294      0.660      1.106      0.270      -0.570       2.029
# age                         0.0019      0.092      0.021      0.983      -0.180       0.183
# female                      0.4498      0.537      0.837      0.403      -0.609       1.508
# meanFD                     -1.4513      1.361     -1.066      0.287      -4.132       1.230
# ==============================================================================
# Omnibus:                        0.413   Durbin-Watson:                   2.146
# Prob(Omnibus):                  0.814   Jarque-Bera (JB):                0.233
# Skew:                          -0.062   Prob(JB):                        0.890
# Kurtosis:                       3.087   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Cingulo-Opercular Network

# %%
#weighted least squares regression model - movie DM (Discovery)
data_dm["class_string"] = data_dm["class"]
for x in range(1,8):
    res = smf.wls("CinguloOperc_peak{0}_mean ~ age + class_string + female + meanFD".format(x), 
                  data = data_dm.loc[data_dm['site'] == "rubic",:]).fit()
    results.loc[ind, 'dataset'] = 'discovery'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'CinguloOperc'
    results.loc[ind, 'sceneNo'] = x
    results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.class02]']
    results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.class02]']
    results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.class03]']
    results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.class03]']
    ind = ind + 1
    print(res.summary())
# Out:
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak1_mean   R-squared:                       0.056
# Model:                                 WLS   Adj. R-squared:                  0.039
# Method:                      Least Squares   F-statistic:                     3.329
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):            0.00616
# Time:                             20:41:05   Log-Likelihood:                -852.98
# No. Observations:                      286   AIC:                             1718.
# Df Residuals:                          280   BIC:                             1740.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   1.2438      1.429      0.870      0.385      -1.569       4.056
# class_string[T.class02]    -0.5127      0.814     -0.630      0.529      -2.116       1.090
# class_string[T.class03]     0.4721      0.721      0.655      0.513      -0.947       1.891
# age                         0.3909      0.114      3.422      0.001       0.166       0.616
# female                      0.4355      0.604      0.721      0.471      -0.753       1.624
# meanFD                     -2.1188      1.870     -1.133      0.258      -5.799       1.561
# ==============================================================================
# Omnibus:                        7.156   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.028   Jarque-Bera (JB):                7.630
# Skew:                          -0.282   Prob(JB):                       0.0220
# Kurtosis:                       3.568   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak2_mean   R-squared:                       0.058
# Model:                                 WLS   Adj. R-squared:                  0.041
# Method:                      Least Squares   F-statistic:                     3.465
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):            0.00469
# Time:                             20:41:05   Log-Likelihood:                -922.29
# No. Observations:                      286   AIC:                             1857.
# Df Residuals:                          280   BIC:                             1879.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   7.7992      1.821      4.284      0.000       4.215      11.383
# class_string[T.class02]    -1.8756      1.038     -1.808      0.072      -3.918       0.167
# class_string[T.class03]    -1.2563      0.918     -1.368      0.172      -3.064       0.552
# age                         0.0740      0.146      0.509      0.611      -0.213       0.361
# female                      1.0914      0.769      1.419      0.157      -0.423       2.606
# meanFD                     -7.6154      2.382     -3.197      0.002     -12.305      -2.926
# ==============================================================================
# Omnibus:                        4.095   Durbin-Watson:                   1.816
# Prob(Omnibus):                  0.129   Jarque-Bera (JB):                5.169
# Skew:                          -0.012   Prob(JB):                       0.0754
# Kurtosis:                       3.658   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak3_mean   R-squared:                       0.076
# Model:                                 WLS   Adj. R-squared:                  0.059
# Method:                      Least Squares   F-statistic:                     4.585
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):           0.000490
# Time:                             20:41:05   Log-Likelihood:                -907.61
# No. Observations:                      286   AIC:                             1827.
# Df Residuals:                          280   BIC:                             1849.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   8.6938      1.730      5.027      0.000       5.289      12.098
# class_string[T.class02]    -0.9650      0.986     -0.979      0.328      -2.905       0.975
# class_string[T.class03]    -1.8954      0.873     -2.172      0.031      -3.613      -0.178
# age                        -0.1660      0.138     -1.200      0.231      -0.438       0.106
# female                      1.4096      0.731      1.929      0.055      -0.029       2.848
# meanFD                     -7.1388      2.263     -3.154      0.002     -11.594      -2.684
# ==============================================================================
# Omnibus:                        0.680   Durbin-Watson:                   2.118
# Prob(Omnibus):                  0.712   Jarque-Bera (JB):                0.439
# Skew:                          -0.056   Prob(JB):                        0.803
# Kurtosis:                       3.156   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak4_mean   R-squared:                       0.073
# Model:                                 WLS   Adj. R-squared:                  0.056
# Method:                      Least Squares   F-statistic:                     4.413
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):           0.000695
# Time:                             20:41:05   Log-Likelihood:                -874.46
# No. Observations:                      286   AIC:                             1761.
# Df Residuals:                          280   BIC:                             1783.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   6.7568      1.540      4.387      0.000       3.725       9.789
# class_string[T.class02]     0.4061      0.878      0.463      0.644      -1.322       2.134
# class_string[T.class03]     0.9304      0.777      1.197      0.232      -0.599       2.460
# age                        -0.2599      0.123     -2.110      0.036      -0.502      -0.017
# female                      0.9619      0.651      1.478      0.141      -0.319       2.243
# meanFD                     -7.1750      2.015     -3.560      0.000     -11.142      -3.208
# ==============================================================================
# Omnibus:                        3.477   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.176   Jarque-Bera (JB):                4.040
# Skew:                          -0.044   Prob(JB):                        0.133
# Kurtosis:                       3.576   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak5_mean   R-squared:                       0.009
# Model:                                 WLS   Adj. R-squared:                 -0.009
# Method:                      Least Squares   F-statistic:                    0.4952
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.780
# Time:                             20:41:05   Log-Likelihood:                -872.25
# No. Observations:                      286   AIC:                             1756.
# Df Residuals:                          280   BIC:                             1778.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   5.3610      1.528      3.508      0.001       2.352       8.370
# class_string[T.class02]    -1.0443      0.871     -1.199      0.232      -2.759       0.670
# class_string[T.class03]    -0.8322      0.771     -1.079      0.281      -2.350       0.686
# age                        -0.0029      0.122     -0.024      0.981      -0.243       0.238
# female                      0.1678      0.646      0.260      0.795      -1.103       1.439
# meanFD                     -1.6163      2.000     -0.808      0.420      -5.553       2.320
# ==============================================================================
# Omnibus:                        2.742   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.254   Jarque-Bera (JB):                2.434
# Skew:                           0.209   Prob(JB):                        0.296
# Kurtosis:                       3.173   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak6_mean   R-squared:                       0.037
# Model:                                 WLS   Adj. R-squared:                  0.020
# Method:                      Least Squares   F-statistic:                     2.136
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):             0.0613
# Time:                             20:41:05   Log-Likelihood:                -899.00
# No. Observations:                      286   AIC:                             1810.
# Df Residuals:                          280   BIC:                             1832.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   3.3054      1.678      1.970      0.050       0.002       6.609
# class_string[T.class02]    -0.7393      0.957     -0.773      0.440      -2.622       1.144
# class_string[T.class03]     0.3001      0.847      0.354      0.723      -1.367       1.967
# age                         0.0796      0.134      0.593      0.553      -0.185       0.344
# female                      0.9949      0.709      1.403      0.162      -0.401       2.391
# meanFD                     -5.1273      2.196     -2.335      0.020      -9.450      -0.804
# ==============================================================================
# Omnibus:                        3.787   Durbin-Watson:                   2.132
# Prob(Omnibus):                  0.151   Jarque-Bera (JB):                4.258
# Skew:                          -0.103   Prob(JB):                        0.119
# Kurtosis:                       3.561   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak7_mean   R-squared:                       0.043
# Model:                                 WLS   Adj. R-squared:                  0.026
# Method:                      Least Squares   F-statistic:                     2.534
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):             0.0291
# Time:                             20:41:05   Log-Likelihood:                -852.35
# No. Observations:                      286   AIC:                             1717.
# Df Residuals:                          280   BIC:                             1739.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   6.3674      1.426      4.466      0.000       3.561       9.174
# class_string[T.class02]     0.0169      0.813      0.021      0.983      -1.583       1.616
# class_string[T.class03]    -0.5930      0.719     -0.824      0.410      -2.009       0.823
# age                        -0.2516      0.114     -2.207      0.028      -0.476      -0.027
# female                      0.5244      0.602      0.871      0.385      -0.661       1.710
# meanFD                     -4.3036      1.866     -2.307      0.022      -7.976      -0.631
# ==============================================================================
# Omnibus:                        5.205   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.074   Jarque-Bera (JB):                4.931
# Skew:                          -0.310   Prob(JB):                       0.0850
# Kurtosis:                       3.170   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#weighted least squares regression model - movie DM (Replication)
data_dm["class_string"] = data_dm["class"]
for x in range(1,8):
    res = smf.wls("CinguloOperc_peak{0}_mean ~ age + class_string + female + meanFD".format(x), 
                  data = data_dm.loc[data_dm['site'] == "cbic",:]).fit()
    results.loc[ind, 'dataset'] = 'replication'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'CinguloOperc'
    results.loc[ind, 'sceneNo'] = x
    results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.class02]']
    results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.class02]']
    results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.class03]']
    results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.class03]']
    ind = ind + 1
    print(res.summary())
# Out:
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak1_mean   R-squared:                       0.011
# Model:                                 WLS   Adj. R-squared:                 -0.014
# Method:                      Least Squares   F-statistic:                    0.4351
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.824
# Time:                             20:41:06   Log-Likelihood:                -641.21
# No. Observations:                      210   AIC:                             1294.
# Df Residuals:                          204   BIC:                             1315.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   2.4298      1.812      1.341      0.181      -1.142       6.002
# class_string[T.class02]     1.1631      1.006      1.156      0.249      -0.820       3.146
# class_string[T.class03]     1.1652      0.917      1.270      0.206      -0.644       2.974
# age                         0.0032      0.120      0.027      0.979      -0.233       0.240
# female                      0.3615      0.740      0.488      0.626      -1.098       1.821
# meanFD                      0.8489      2.135      0.398      0.691      -3.361       5.059
# ==============================================================================
# Omnibus:                        2.128   Durbin-Watson:                   2.108
# Prob(Omnibus):                  0.345   Jarque-Bera (JB):                1.887
# Skew:                          -0.124   Prob(JB):                        0.389
# Kurtosis:                       2.607   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak2_mean   R-squared:                       0.018
# Model:                                 WLS   Adj. R-squared:                 -0.006
# Method:                      Least Squares   F-statistic:                    0.7376
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.596
# Time:                             20:41:06   Log-Likelihood:                -709.06
# No. Observations:                      210   AIC:                             1430.
# Df Residuals:                          204   BIC:                             1450.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   8.1950      2.502      3.275      0.001       3.261      13.129
# class_string[T.class02]     0.3049      1.389      0.219      0.826      -2.434       3.044
# class_string[T.class03]    -0.8481      1.267     -0.669      0.504      -3.347       1.651
# age                        -0.2238      0.166     -1.350      0.179      -0.551       0.103
# female                      0.6170      1.023      0.603      0.547      -1.399       2.633
# meanFD                     -2.9633      2.950     -1.005      0.316      -8.779       2.853
# ==============================================================================
# Omnibus:                       14.086   Durbin-Watson:                   1.906
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               19.959
# Skew:                          -0.437   Prob(JB):                     4.63e-05
# Kurtosis:                       4.232   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak3_mean   R-squared:                       0.026
# Model:                                 WLS   Adj. R-squared:                  0.002
# Method:                      Least Squares   F-statistic:                     1.090
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.367
# Time:                             20:41:06   Log-Likelihood:                -707.68
# No. Observations:                      210   AIC:                             1427.
# Df Residuals:                          204   BIC:                             1447.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   8.2037      2.486      3.300      0.001       3.302      13.105
# class_string[T.class02]    -0.0050      1.380     -0.004      0.997      -2.727       2.717
# class_string[T.class03]    -1.5094      1.259     -1.199      0.232      -3.992       0.973
# age                        -0.2256      0.165     -1.370      0.172      -0.550       0.099
# female                     -0.1397      1.016     -0.138      0.891      -2.143       1.864
# meanFD                     -3.7164      2.931     -1.268      0.206      -9.494       2.062
# ==============================================================================
# Omnibus:                        0.123   Durbin-Watson:                   2.122
# Prob(Omnibus):                  0.940   Jarque-Bera (JB):                0.030
# Skew:                           0.027   Prob(JB):                        0.985
# Kurtosis:                       3.025   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak4_mean   R-squared:                       0.055
# Model:                                 WLS   Adj. R-squared:                  0.032
# Method:                      Least Squares   F-statistic:                     2.369
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):             0.0407
# Time:                             20:41:06   Log-Likelihood:                -651.09
# No. Observations:                      210   AIC:                             1314.
# Df Residuals:                          204   BIC:                             1334.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   9.2524      1.899      4.873      0.000       5.509      12.996
# class_string[T.class02]    -1.2111      1.054     -1.149      0.252      -3.290       0.868
# class_string[T.class03]    -0.6255      0.962     -0.650      0.516      -2.521       1.271
# age                        -0.2606      0.126     -2.072      0.040      -0.509      -0.013
# female                      0.0412      0.776      0.053      0.958      -1.489       1.571
# meanFD                     -5.6717      2.238     -2.534      0.012     -10.085      -1.259
# ==============================================================================
# Omnibus:                        5.521   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.063   Jarque-Bera (JB):                7.251
# Skew:                          -0.144   Prob(JB):                       0.0266
# Kurtosis:                       3.864   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak5_mean   R-squared:                       0.030
# Model:                                 WLS   Adj. R-squared:                  0.006
# Method:                      Least Squares   F-statistic:                     1.243
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.290
# Time:                             20:41:06   Log-Likelihood:                -633.48
# No. Observations:                      210   AIC:                             1279.
# Df Residuals:                          204   BIC:                             1299.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   4.6129      1.746      2.642      0.009       1.170       8.056
# class_string[T.class02]     0.3747      0.969      0.386      0.700      -1.537       2.286
# class_string[T.class03]     0.3458      0.884      0.391      0.696      -1.398       2.089
# age                        -0.1275      0.116     -1.102      0.272      -0.356       0.101
# female                      1.4217      0.714      1.992      0.048       0.015       2.829
# meanFD                     -2.5746      2.058     -1.251      0.212      -6.633       1.483
# ==============================================================================
# Omnibus:                        1.007   Durbin-Watson:                   2.103
# Prob(Omnibus):                  0.604   Jarque-Bera (JB):                0.682
# Skew:                           0.040   Prob(JB):                        0.711
# Kurtosis:                       3.267   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak6_mean   R-squared:                       0.047
# Model:                                 WLS   Adj. R-squared:                  0.023
# Method:                      Least Squares   F-statistic:                     2.004
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):             0.0795
# Time:                             20:41:06   Log-Likelihood:                -644.27
# No. Observations:                      210   AIC:                             1301.
# Df Residuals:                          204   BIC:                             1321.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   1.4897      1.838      0.810      0.419      -2.135       5.114
# class_string[T.class02]     1.9799      1.021      1.940      0.054      -0.032       3.992
# class_string[T.class03]     0.5693      0.931      0.612      0.542      -1.266       2.405
# age                         0.2118      0.122      1.739      0.084      -0.028       0.452
# female                     -0.2933      0.751     -0.390      0.697      -1.774       1.188
# meanFD                     -2.6339      2.167     -1.216      0.226      -6.906       1.638
# ==============================================================================
# Omnibus:                        0.423   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.809   Jarque-Bera (JB):                0.564
# Skew:                           0.075   Prob(JB):                        0.754
# Kurtosis:                       2.795   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak7_mean   R-squared:                       0.030
# Model:                                 WLS   Adj. R-squared:                  0.006
# Method:                      Least Squares   F-statistic:                     1.269
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.279
# Time:                             20:41:06   Log-Likelihood:                -646.46
# No. Observations:                      210   AIC:                             1305.
# Df Residuals:                          204   BIC:                             1325.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   2.9441      1.857      1.585      0.114      -0.718       6.606
# class_string[T.class02]     0.3743      1.031      0.363      0.717      -1.659       2.408
# class_string[T.class03]    -0.6610      0.941     -0.703      0.483      -2.516       1.194
# age                        -0.1734      0.123     -1.409      0.160      -0.416       0.069
# female                      1.1547      0.759      1.521      0.130      -0.342       2.651
# meanFD                      1.9838      2.189      0.906      0.366      -2.333       6.301
# ==============================================================================
# Omnibus:                        1.029   Durbin-Watson:                   2.114
# Prob(Omnibus):                  0.598   Jarque-Bera (JB):                0.828
# Skew:                          -0.150   Prob(JB):                        0.661
# Kurtosis:                       3.071   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#weighted least squares regression model - movie TP (Discovery)
data_tp["class_string"] = data_tp["class"]
for x in range(1,7):
    if 'CinguloOperc_peak{0}_mean'.format(x) in data_tp.columns:
        res = smf.wls("CinguloOperc_peak{0}_mean ~ age + class_string + female + meanFD".format(x), 
                      data = data_tp.loc[data_tp['site'] == "rubic",:]).fit()
        results.loc[ind, 'dataset'] = 'discovery'
        results.loc[ind, 'movie'] = 'TP'
        results.loc[ind, 'networkDV'] = 'CinguloOperc'
        results.loc[ind, 'sceneNo'] = x
        results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.class02]']
        results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.class02]']
        results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.class03]']
        results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.class03]']
        ind = ind + 1
    else:
        break
    print(res.summary())
# Out:
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak1_mean   R-squared:                       0.043
# Model:                                 WLS   Adj. R-squared:                  0.028
# Method:                      Least Squares   F-statistic:                     2.921
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):             0.0135
# Time:                             20:41:06   Log-Likelihood:                -1055.7
# No. Observations:                      329   AIC:                             2123.
# Df Residuals:                          323   BIC:                             2146.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   7.9041      1.628      4.854      0.000       4.701      11.107
# class_string[T.class02]     1.5879      0.917      1.731      0.084      -0.217       3.393
# class_string[T.class03]     0.9916      0.840      1.180      0.239      -0.661       2.645
# age                        -0.0424      0.131     -0.325      0.745      -0.299       0.214
# female                     -1.3067      0.709     -1.844      0.066      -2.701       0.087
# meanFD                     -6.1324      2.019     -3.037      0.003     -10.104      -2.160
# ==============================================================================
# Omnibus:                        5.084   Durbin-Watson:                   1.943
# Prob(Omnibus):                  0.079   Jarque-Bera (JB):                4.885
# Skew:                          -0.247   Prob(JB):                       0.0870
# Kurtosis:                       3.336   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak2_mean   R-squared:                       0.022
# Model:                                 WLS   Adj. R-squared:                  0.007
# Method:                      Least Squares   F-statistic:                     1.456
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.204
# Time:                             20:41:06   Log-Likelihood:                -1115.5
# No. Observations:                      329   AIC:                             2243.
# Df Residuals:                          323   BIC:                             2266.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   5.7249      1.952      2.932      0.004       1.884       9.566
# class_string[T.class02]     0.2373      1.100      0.216      0.829      -1.927       2.401
# class_string[T.class03]     0.5012      1.008      0.497      0.619      -1.481       2.483
# age                         0.0705      0.156      0.451      0.653      -0.237       0.378
# female                      0.8927      0.850      1.051      0.294      -0.779       2.564
# meanFD                     -5.3937      2.421     -2.228      0.027     -10.156      -0.631
# ==============================================================================
# Omnibus:                        3.825   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.148   Jarque-Bera (JB):                3.633
# Skew:                          -0.203   Prob(JB):                        0.163
# Kurtosis:                       2.684   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak3_mean   R-squared:                       0.037
# Model:                                 WLS   Adj. R-squared:                  0.022
# Method:                      Least Squares   F-statistic:                     2.460
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):             0.0331
# Time:                             20:41:06   Log-Likelihood:                -1069.6
# No. Observations:                      329   AIC:                             2151.
# Df Residuals:                          323   BIC:                             2174.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   4.8929      1.698      2.881      0.004       1.552       8.234
# class_string[T.class02]     1.7352      0.957      1.813      0.071      -0.147       3.618
# class_string[T.class03]     0.1903      0.876      0.217      0.828      -1.534       1.915
# age                         0.0746      0.136      0.548      0.584      -0.193       0.342
# female                     -1.5080      0.739     -2.040      0.042      -2.962      -0.054
# meanFD                     -3.2916      2.106     -1.563      0.119      -7.435       0.852
# ==============================================================================
# Omnibus:                        1.556   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.459   Jarque-Bera (JB):                1.529
# Skew:                          -0.166   Prob(JB):                        0.466
# Kurtosis:                       2.961   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak4_mean   R-squared:                       0.063
# Model:                                 WLS   Adj. R-squared:                  0.048
# Method:                      Least Squares   F-statistic:                     4.307
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):           0.000831
# Time:                             20:41:06   Log-Likelihood:                -1022.1
# No. Observations:                      329   AIC:                             2056.
# Df Residuals:                          323   BIC:                             2079.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   3.4594      1.470      2.353      0.019       0.567       6.351
# class_string[T.class02]     1.3365      0.828      1.614      0.108      -0.293       2.966
# class_string[T.class03]     0.1067      0.759      0.141      0.888      -1.386       1.599
# age                         0.1814      0.118      1.539      0.125      -0.050       0.413
# female                     -0.7043      0.640     -1.101      0.272      -1.963       0.554
# meanFD                     -6.0518      1.823     -3.320      0.001      -9.638      -2.466
# ==============================================================================
# Omnibus:                        0.191   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.909   Jarque-Bera (JB):                0.063
# Skew:                           0.012   Prob(JB):                        0.969
# Kurtosis:                       3.064   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak5_mean   R-squared:                       0.011
# Model:                                 WLS   Adj. R-squared:                 -0.004
# Method:                      Least Squares   F-statistic:                    0.7275
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.603
# Time:                             20:41:06   Log-Likelihood:                -1017.0
# No. Observations:                      329   AIC:                             2046.
# Df Residuals:                          323   BIC:                             2069.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   5.2935      1.447      3.658      0.000       2.446       8.141
# class_string[T.class02]     0.2608      0.815      0.320      0.749      -1.343       1.865
# class_string[T.class03]    -0.7538      0.747     -1.009      0.314      -2.223       0.716
# age                        -0.0826      0.116     -0.712      0.477      -0.311       0.146
# female                      0.3183      0.630      0.505      0.614      -0.921       1.557
# meanFD                     -1.4779      1.795     -0.824      0.411      -5.009       2.053
# ==============================================================================
# Omnibus:                        3.046   Durbin-Watson:                   2.071
# Prob(Omnibus):                  0.218   Jarque-Bera (JB):                2.992
# Skew:                           0.233   Prob(JB):                        0.224
# Kurtosis:                       2.974   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak6_mean   R-squared:                       0.044
# Model:                                 WLS   Adj. R-squared:                  0.029
# Method:                      Least Squares   F-statistic:                     2.961
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):             0.0125
# Time:                             20:41:06   Log-Likelihood:                -964.52
# No. Observations:                      329   AIC:                             1941.
# Df Residuals:                          323   BIC:                             1964.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   1.5048      1.234      1.219      0.224      -0.923       3.932
# class_string[T.class02]     0.8479      0.695      1.220      0.224      -0.520       2.216
# class_string[T.class03]     0.0037      0.637      0.006      0.995      -1.249       1.257
# age                         0.1953      0.099      1.974      0.049       0.001       0.390
# female                     -0.5627      0.537     -1.048      0.295      -1.619       0.494
# meanFD                     -3.1744      1.530     -2.075      0.039      -6.185      -0.164
# ==============================================================================
# Omnibus:                       13.436   Durbin-Watson:                   2.171
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.602
# Skew:                          -0.393   Prob(JB):                     0.000409
# Kurtosis:                       3.720   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#weighted least squares regression model - movie TP (Replication)
data_tp["class_string"] = data_tp["class"]
for x in range(1,7):
    if 'CinguloOperc_peak{0}_mean'.format(x) in data_tp.columns:
        res = smf.wls("CinguloOperc_peak{0}_mean ~ age + class_string + female + meanFD".format(x), 
                      data = data_tp.loc[data_tp['site'] == "cbic",:]).fit()
        results.loc[ind, 'dataset'] = 'replication'
        results.loc[ind, 'movie'] = 'TP'
        results.loc[ind, 'networkDV'] = 'CinguloOperc'
        results.loc[ind, 'sceneNo'] = x
        results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.class02]']
        results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.class02]']
        results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.class03]']
        results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.class03]']
        ind = ind + 1
    else:
        break
    print(res.summary())
# Out:
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak1_mean   R-squared:                       0.018
# Model:                                 WLS   Adj. R-squared:                 -0.003
# Method:                      Least Squares   F-statistic:                    0.8737
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.499
# Time:                             20:41:07   Log-Likelihood:                -799.73
# No. Observations:                      244   AIC:                             1611.
# Df Residuals:                          238   BIC:                             1632.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   4.6436      2.039      2.277      0.024       0.627       8.660
# class_string[T.class02]     0.0770      1.203      0.064      0.949      -2.293       2.447
# class_string[T.class03]     1.0895      1.065      1.023      0.308      -1.009       3.188
# age                         0.1734      0.149      1.165      0.245      -0.120       0.466
# female                      0.4949      0.868      0.570      0.569      -1.215       2.205
# meanFD                     -1.9455      2.198     -0.885      0.377      -6.276       2.385
# ==============================================================================
# Omnibus:                        8.407   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.015   Jarque-Bera (JB):                8.879
# Skew:                          -0.355   Prob(JB):                       0.0118
# Kurtosis:                       3.607   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak2_mean   R-squared:                       0.020
# Model:                                 WLS   Adj. R-squared:                 -0.001
# Method:                      Least Squares   F-statistic:                    0.9493
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.450
# Time:                             20:41:07   Log-Likelihood:                -838.05
# No. Observations:                      244   AIC:                             1688.
# Df Residuals:                          238   BIC:                             1709.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   9.3110      2.386      3.903      0.000       4.611      14.011
# class_string[T.class02]     0.8778      1.408      0.623      0.534      -1.896       3.651
# class_string[T.class03]     0.4962      1.247      0.398      0.691      -1.960       2.952
# age                        -0.2530      0.174     -1.454      0.147      -0.596       0.090
# female                      1.0048      1.016      0.989      0.323      -0.996       3.005
# meanFD                     -3.9880      2.572     -1.550      0.122      -9.055       1.079
# ==============================================================================
# Omnibus:                        3.457   Durbin-Watson:                   2.133
# Prob(Omnibus):                  0.178   Jarque-Bera (JB):                3.459
# Skew:                          -0.255   Prob(JB):                        0.177
# Kurtosis:                       2.717   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak3_mean   R-squared:                       0.030
# Model:                                 WLS   Adj. R-squared:                  0.010
# Method:                      Least Squares   F-statistic:                     1.478
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.198
# Time:                             20:41:07   Log-Likelihood:                -796.88
# No. Observations:                      244   AIC:                             1606.
# Df Residuals:                          238   BIC:                             1627.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   3.0294      2.015      1.503      0.134      -0.941       7.000
# class_string[T.class02]     2.1228      1.189      1.785      0.076      -0.220       4.466
# class_string[T.class03]     2.1422      1.053      2.034      0.043       0.068       4.217
# age                         0.0274      0.147      0.186      0.853      -0.262       0.317
# female                      1.2558      0.858      1.464      0.145      -0.434       2.946
# meanFD                     -1.8453      2.173     -0.849      0.397      -6.126       2.435
# ==============================================================================
# Omnibus:                        3.736   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.154   Jarque-Bera (JB):                3.379
# Skew:                          -0.245   Prob(JB):                        0.185
# Kurtosis:                       3.305   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak4_mean   R-squared:                       0.046
# Model:                                 WLS   Adj. R-squared:                  0.026
# Method:                      Least Squares   F-statistic:                     2.298
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):             0.0459
# Time:                             20:41:07   Log-Likelihood:                -738.22
# No. Observations:                      244   AIC:                             1488.
# Df Residuals:                          238   BIC:                             1509.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   2.4820      1.585      1.566      0.119      -0.640       5.604
# class_string[T.class02]     1.5501      0.935      1.658      0.099      -0.292       3.392
# class_string[T.class03]     0.3118      0.828      0.377      0.707      -1.319       1.943
# age                         0.1598      0.116      1.382      0.168      -0.068       0.388
# female                      0.9364      0.675      1.388      0.166      -0.392       2.265
# meanFD                     -2.9707      1.708     -1.739      0.083      -6.336       0.395
# ==============================================================================
# Omnibus:                        0.492   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.782   Jarque-Bera (JB):                0.627
# Skew:                          -0.073   Prob(JB):                        0.731
# Kurtosis:                       2.800   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak5_mean   R-squared:                       0.035
# Model:                                 WLS   Adj. R-squared:                  0.015
# Method:                      Least Squares   F-statistic:                     1.745
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.125
# Time:                             20:41:07   Log-Likelihood:                -742.66
# No. Observations:                      244   AIC:                             1497.
# Df Residuals:                          238   BIC:                             1518.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   2.5431      1.614      1.576      0.116      -0.636       5.722
# class_string[T.class02]    -0.1863      0.952     -0.196      0.845      -2.062       1.690
# class_string[T.class03]     0.5447      0.843      0.646      0.519      -1.116       2.206
# age                         0.0835      0.118      0.709      0.479      -0.148       0.315
# female                      1.5855      0.687      2.308      0.022       0.232       2.939
# meanFD                     -1.9721      1.740     -1.134      0.258      -5.399       1.455
# ==============================================================================
# Omnibus:                        9.091   Durbin-Watson:                   2.127
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):               14.636
# Skew:                          -0.188   Prob(JB):                     0.000664
# Kurtosis:                       4.139   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_peak6_mean   R-squared:                       0.077
# Model:                                 WLS   Adj. R-squared:                  0.058
# Method:                      Least Squares   F-statistic:                     3.991
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):            0.00170
# Time:                             20:41:07   Log-Likelihood:                -712.17
# No. Observations:                      244   AIC:                             1436.
# Df Residuals:                          238   BIC:                             1457.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -0.0284      1.424     -0.020      0.984      -2.834       2.777
# class_string[T.class02]     2.5182      0.840      2.996      0.003       0.863       4.174
# class_string[T.class03]     1.4771      0.744      1.985      0.048       0.011       2.943
# age                         0.2199      0.104      2.116      0.035       0.015       0.425
# female                      0.8337      0.606      1.375      0.170      -0.361       2.028
# meanFD                     -2.4085      1.535     -1.569      0.118      -5.433       0.616
# ==============================================================================
# Omnibus:                        6.733   Durbin-Watson:                   2.062
# Prob(Omnibus):                  0.035   Jarque-Bera (JB):                7.726
# Skew:                          -0.253   Prob(JB):                       0.0210
# Kurtosis:                       3.709   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Amygdala

# %%
#weighted least squares regression model - movie DM (Discovery)
data_dm["class_string"] = data_dm["class"]
for x in range(1,8):
    res = smf.wls("Amygdala_peak{0}_mean ~ age + class_string + female + meanFD".format(x), 
                  data = data_dm.loc[data_dm['site'] == "rubic",:]).fit()
    results.loc[ind, 'dataset'] = 'discovery'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'Amygdala'
    results.loc[ind, 'sceneNo'] = x
    results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.class02]']
    results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.class02]']
    results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.class03]']
    results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.class03]']
    ind = ind + 1
    print(res.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     164         code = compile(expr, source_name, "eval", self.flags, False)
# --> 165         return eval(code, {}, VarLookupDict([inner_namespace]
#     166                                             + self._namespaces))
#
# <string> in <module>
#
# NameError: name 'Amygdala_peak1_mean' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# /var/folders/0g/g8tyy3vn2zxcv2_bfxpbpr780000gn/T/ipykernel_1741/3477304166.py in <module>
#       2 data_dm["class_string"] = data_dm["class"]
#       3 for x in range(1,8):
# ----> 4     res = smf.wls("Amygdala_peak{0}_mean ~ age + class_string + female + meanFD".format(x),
#       5                   data = data_dm.loc[data_dm['site'] == "rubic",:]).fit()
#       6     results.loc[ind, 'dataset'] = 'discovery'
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     198             missing = 'raise'
#     199
# --> 200         tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     201                                   missing=missing)
#     202         ((endog, exog), missing_idx, design_info) = tmp
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      61     else:
#      62         if data_util._is_using_pandas(Y, None):
# ---> 63             result = dmatrices(formula, Y, depth, return_type='dataframe',
#      64                                NA_action=na_action)
#      65         else:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     307     """
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     162     def data_iter_maker():
#     163         return iter([data])
# --> 164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
#     165                                       NA_action)
#     166     if design_infos is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      64     if isinstance(formula_like, ModelDesc):
#      65         assert isinstance(eval_env, EvalEnvironment)
# ---> 66         return design_matrix_builders([formula_like.lhs_termlist,
#      67                                        formula_like.rhs_termlist],
#      68                                       data_iter_maker,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     691     # on some data to find out what type of data they return.
#     692     (num_column_counts,
# --> 693      cat_levels_contrasts) = _examine_factor_types(all_factors,
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/build.py in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441     for data in data_iter_maker():
#     442         for factor in list(examine_needed):
# --> 443             value = factor.eval(factor_states[factor], data)
#     444             if factor in cat_sniffers or guess_categorical(value):
#     445                 if factor not in cat_sniffers:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/eval.py in eval(self, memorize_state, data)
#     562
#     563     def eval(self, memorize_state, data):
# --> 564         return self._eval(memorize_state["eval_code"],
#     565                           memorize_state,
#     566                           data)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/eval.py in _eval(self, code, memorize_state, data)
#     545     def _eval(self, code, memorize_state, data):
#     546         inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 547         return call_and_wrap_exc("Error evaluating factor",
#     548                                  self,
#     549                                  memorize_state["eval_env"].eval,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      41                                  origin)
#      42             # Use 'exec' to hide this syntax from the Python 2 parser:
# ---> 43             exec("raise new_exc from e")
#      44         else:
#      45             # In python 2, we just let the original exception escape -- better
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/compat.py in <module>
#
# PatsyError: Error evaluating factor: NameError: name 'Amygdala_peak1_mean' is not defined
#     Amygdala_peak1_mean ~ age + class_string + female + meanFD
#     ^^^^^^^^^^^^^^^^^^^

# %%
#weighted least squares regression model - movie DM (Replication)
data_dm["class_string"] = data_dm["class"]
for x in range(1,8):
    res = smf.wls("Amygdala_peak{0}_mean ~ age + class_string + female + meanFD".format(x), 
                  data = data_dm.loc[data_dm['site'] == "cbic",:]).fit()
    results.loc[ind, 'dataset'] = 'replication'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'Amygdala'
    results.loc[ind, 'sceneNo'] = x
    results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.class02]']
    results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.class02]']
    results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.class03]']
    results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.class03]']
    ind = ind + 1
    print(res.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     164         code = compile(expr, source_name, "eval", self.flags, False)
# --> 165         return eval(code, {}, VarLookupDict([inner_namespace]
#     166                                             + self._namespaces))
#
# <string> in <module>
#
# NameError: name 'Amygdala_peak1_mean' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# /var/folders/0g/g8tyy3vn2zxcv2_bfxpbpr780000gn/T/ipykernel_1741/512796613.py in <module>
#       2 data_dm["class_string"] = data_dm["class"]
#       3 for x in range(1,8):
# ----> 4     res = smf.wls("Amygdala_peak{0}_mean ~ age + class_string + female + meanFD".format(x),
#       5                   data = data_dm.loc[data_dm['site'] == "cbic",:]).fit()
#       6     results.loc[ind, 'dataset'] = 'replication'
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     198             missing = 'raise'
#     199
# --> 200         tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     201                                   missing=missing)
#     202         ((endog, exog), missing_idx, design_info) = tmp
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      61     else:
#      62         if data_util._is_using_pandas(Y, None):
# ---> 63             result = dmatrices(formula, Y, depth, return_type='dataframe',
#      64                                NA_action=na_action)
#      65         else:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     307     """
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     162     def data_iter_maker():
#     163         return iter([data])
# --> 164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
#     165                                       NA_action)
#     166     if design_infos is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      64     if isinstance(formula_like, ModelDesc):
#      65         assert isinstance(eval_env, EvalEnvironment)
# ---> 66         return design_matrix_builders([formula_like.lhs_termlist,
#      67                                        formula_like.rhs_termlist],
#      68                                       data_iter_maker,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     691     # on some data to find out what type of data they return.
#     692     (num_column_counts,
# --> 693      cat_levels_contrasts) = _examine_factor_types(all_factors,
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/build.py in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441     for data in data_iter_maker():
#     442         for factor in list(examine_needed):
# --> 443             value = factor.eval(factor_states[factor], data)
#     444             if factor in cat_sniffers or guess_categorical(value):
#     445                 if factor not in cat_sniffers:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/eval.py in eval(self, memorize_state, data)
#     562
#     563     def eval(self, memorize_state, data):
# --> 564         return self._eval(memorize_state["eval_code"],
#     565                           memorize_state,
#     566                           data)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/eval.py in _eval(self, code, memorize_state, data)
#     545     def _eval(self, code, memorize_state, data):
#     546         inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 547         return call_and_wrap_exc("Error evaluating factor",
#     548                                  self,
#     549                                  memorize_state["eval_env"].eval,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      41                                  origin)
#      42             # Use 'exec' to hide this syntax from the Python 2 parser:
# ---> 43             exec("raise new_exc from e")
#      44         else:
#      45             # In python 2, we just let the original exception escape -- better
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/patsy/compat.py in <module>
#
# PatsyError: Error evaluating factor: NameError: name 'Amygdala_peak1_mean' is not defined
#     Amygdala_peak1_mean ~ age + class_string + female + meanFD
#     ^^^^^^^^^^^^^^^^^^^

# %%
#weighted least squares regression model - movie TP (Discovery)
data_tp["class_string"] = data_tp["class"]
for x in range(1,7):
    if 'Amygdala{0}_mean'.format(x) in data_tp.columns:
        res = smf.wls("Amygdala_peak{0}_mean ~ age + class_string + female + meanFD".format(x), 
                      data = data_tp.loc[data_tp['site'] == "rubic",:]).fit()
        results.loc[ind, 'dataset'] = 'discovery'
        results.loc[ind, 'movie'] = 'TP'
        results.loc[ind, 'networkDV'] = 'Amygdala'
        results.loc[ind, 'sceneNo'] = x
        results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.class02]']
        results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.class02]']
        results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.class03]']
        results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.class03]']
        ind = ind + 1
    else:
        break
    print(res.summary())

# %%
#weighted least squares regression model - movie TP (Replication)
data_tp["class_string"] = data_tp["class"]
for x in range(1,7):
    if 'Amygdala_peak{0}_mean'.format(x) in data_tp.columns:
        res = smf.wls("Amygdala_peak{0}_mean ~ age + class_string + female + meanFD".format(x), 
                      data = data_tp.loc[data_tp['site'] == "cbic",:]).fit()
        results.loc[ind, 'dataset'] = 'replication'
        results.loc[ind, 'movie'] = 'TP'
        results.loc[ind, 'networkDV'] = 'Amygdala'
        results.loc[ind, 'sceneNo'] = x
        results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.class02]']
        results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.class02]']
        results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.class03]']
        results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.class03]']
        ind = ind + 1
    else:
        break
    print(res.summary())

# %%
results.to_csv('class_activation_results.csv')

# %% [markdown]
# ## ACTIVATION - DEPRESSION

# %% [markdown]
# ## Ventral Attn

# %%
#Ventral Attn
#weighted least squares regression model - movie DM (Discovery)- Depression 
for x in range(1,13):
    res = smf.wls("VentralAttn_peak{0}_mean ~ age + MFQ_P_Total + female + meanFD".format(x), 
                  data = data_dm.loc[data_dm['site'] == "rubic",:]).fit()
    results.loc[ind, 'dataset'] = 'discovery'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'VentralAttn'
    print(res.summary())
# Out:
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak1_mean   R-squared:                       0.056
# Model:                                WLS   Adj. R-squared:                  0.042
# Method:                     Least Squares   F-statistic:                     3.973
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):            0.00378
# Time:                            20:43:16   Log-Likelihood:                -904.22
# No. Observations:                     274   AIC:                             1818.
# Df Residuals:                         269   BIC:                             1837.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       9.1149      2.004      4.549      0.000       5.170      13.060
# age             0.3138      0.158      1.989      0.048       0.003       0.625
# MFQ_P_Total     0.0778      0.387      0.201      0.841      -0.684       0.839
# female         -1.4641      0.847     -1.728      0.085      -3.132       0.204
# meanFD         -7.0706      2.602     -2.718      0.007     -12.193      -1.948
# ==============================================================================
# Omnibus:                        0.988   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.610   Jarque-Bera (JB):                0.733
# Skew:                          -0.102   Prob(JB):                        0.693
# Kurtosis:                       3.150   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak2_mean   R-squared:                       0.033
# Model:                                WLS   Adj. R-squared:                  0.019
# Method:                     Least Squares   F-statistic:                     2.303
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0589
# Time:                            20:43:16   Log-Likelihood:                -774.77
# No. Observations:                     274   AIC:                             1560.
# Df Residuals:                         269   BIC:                             1578.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       7.8291      1.249      6.267      0.000       5.369      10.289
# age            -0.1078      0.098     -1.095      0.274      -0.302       0.086
# MFQ_P_Total     0.2252      0.241      0.934      0.351      -0.250       0.700
# female         -0.4014      0.528     -0.760      0.448      -1.441       0.639
# meanFD         -4.6768      1.622     -2.883      0.004      -7.870      -1.483
# ==============================================================================
# Omnibus:                        3.500   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.174   Jarque-Bera (JB):                3.168
# Skew:                           0.223   Prob(JB):                        0.205
# Kurtosis:                       3.280   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak3_mean   R-squared:                       0.066
# Model:                                WLS   Adj. R-squared:                  0.052
# Method:                     Least Squares   F-statistic:                     4.749
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):            0.00102
# Time:                            20:43:16   Log-Likelihood:                -829.32
# No. Observations:                     274   AIC:                             1669.
# Df Residuals:                         269   BIC:                             1687.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      10.1913      1.525      6.685      0.000       7.190      13.193
# age            -0.1797      0.120     -1.496      0.136      -0.416       0.057
# MFQ_P_Total    -0.3681      0.294     -1.251      0.212      -0.947       0.211
# female         -0.6893      0.645     -1.069      0.286      -1.958       0.580
# meanFD         -7.7850      1.979     -3.933      0.000     -11.682      -3.888
# ==============================================================================
# Omnibus:                        5.619   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.060   Jarque-Bera (JB):                8.198
# Skew:                          -0.014   Prob(JB):                       0.0166
# Kurtosis:                       3.847   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak4_mean   R-squared:                       0.063
# Model:                                WLS   Adj. R-squared:                  0.049
# Method:                     Least Squares   F-statistic:                     4.531
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):            0.00147
# Time:                            20:43:16   Log-Likelihood:                -905.92
# No. Observations:                     274   AIC:                             1822.
# Df Residuals:                         269   BIC:                             1840.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       6.2022      2.016      3.076      0.002       2.233      10.172
# age             0.2884      0.159      1.816      0.070      -0.024       0.601
# MFQ_P_Total     0.3840      0.389      0.987      0.325      -0.382       1.150
# female          0.9952      0.853      1.167      0.244      -0.683       2.674
# meanFD         -7.9471      2.618     -3.036      0.003     -13.101      -2.793
# ==============================================================================
# Omnibus:                        0.197   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.906   Jarque-Bera (JB):                0.335
# Skew:                           0.021   Prob(JB):                        0.846
# Kurtosis:                       2.834   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak5_mean   R-squared:                       0.028
# Model:                                WLS   Adj. R-squared:                  0.014
# Method:                     Least Squares   F-statistic:                     1.967
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0999
# Time:                            20:43:16   Log-Likelihood:                -881.42
# No. Observations:                     274   AIC:                             1773.
# Df Residuals:                         269   BIC:                             1791.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       3.1606      1.844      1.714      0.088      -0.470       6.791
# age             0.1623      0.145      1.117      0.265      -0.124       0.448
# MFQ_P_Total     0.3538      0.356      0.994      0.321      -0.347       1.054
# female         -1.6872      0.780     -2.164      0.031      -3.222      -0.152
# meanFD          0.1473      2.394      0.062      0.951      -4.566       4.860
# ==============================================================================
# Omnibus:                        2.833   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.243   Jarque-Bera (JB):                3.065
# Skew:                          -0.024   Prob(JB):                        0.216
# Kurtosis:                       3.516   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak6_mean   R-squared:                       0.059
# Model:                                WLS   Adj. R-squared:                  0.045
# Method:                     Least Squares   F-statistic:                     4.227
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):            0.00246
# Time:                            20:43:16   Log-Likelihood:                -831.45
# No. Observations:                     274   AIC:                             1673.
# Df Residuals:                         269   BIC:                             1691.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       7.9112      1.536      5.149      0.000       4.886      10.936
# age            -0.2378      0.121     -1.965      0.050      -0.476       0.000
# MFQ_P_Total     0.3145      0.297      1.061      0.290      -0.269       0.898
# female          0.2259      0.650      0.348      0.728      -1.053       1.505
# meanFD         -7.2005      1.995     -3.610      0.000     -11.128      -3.273
# ==============================================================================
# Omnibus:                        3.324   Durbin-Watson:                   2.092
# Prob(Omnibus):                  0.190   Jarque-Bera (JB):                3.326
# Skew:                          -0.267   Prob(JB):                        0.190
# Kurtosis:                       2.922   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak7_mean   R-squared:                       0.099
# Model:                                WLS   Adj. R-squared:                  0.086
# Method:                     Least Squares   F-statistic:                     7.401
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):           1.14e-05
# Time:                            20:43:16   Log-Likelihood:                -853.52
# No. Observations:                     274   AIC:                             1717.
# Df Residuals:                         269   BIC:                             1735.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -1.3919      1.665     -0.836      0.404      -4.671       1.887
# age             0.5760      0.131      4.391      0.000       0.318       0.834
# MFQ_P_Total     0.2208      0.321      0.687      0.493      -0.412       0.854
# female          1.4108      0.704      2.004      0.046       0.024       2.797
# meanFD         -3.5255      2.162     -1.631      0.104      -7.782       0.731
# ==============================================================================
# Omnibus:                        4.889   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.087   Jarque-Bera (JB):                6.679
# Skew:                           0.017   Prob(JB):                       0.0355
# Kurtosis:                       3.764   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak8_mean   R-squared:                       0.014
# Model:                                WLS   Adj. R-squared:                 -0.001
# Method:                     Least Squares   F-statistic:                    0.9653
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.427
# Time:                            20:43:16   Log-Likelihood:                -843.69
# No. Observations:                     274   AIC:                             1697.
# Df Residuals:                         269   BIC:                             1715.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       5.8100      1.607      3.616      0.000       2.647       8.973
# age            -0.2356      0.127     -1.862      0.064      -0.485       0.014
# MFQ_P_Total     0.0613      0.310      0.198      0.843      -0.549       0.672
# female         -0.0499      0.679     -0.073      0.942      -1.387       1.288
# meanFD         -1.7743      2.086     -0.851      0.396      -5.881       2.333
# ==============================================================================
# Omnibus:                        0.633   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.729   Jarque-Bera (JB):                0.537
# Skew:                          -0.108   Prob(JB):                        0.765
# Kurtosis:                       3.019   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak9_mean   R-squared:                       0.049
# Model:                                WLS   Adj. R-squared:                  0.035
# Method:                     Least Squares   F-statistic:                     3.481
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):            0.00858
# Time:                            20:43:16   Log-Likelihood:                -917.83
# No. Observations:                     274   AIC:                             1846.
# Df Residuals:                         269   BIC:                             1864.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       2.0058      2.106      0.952      0.342      -2.140       6.152
# age             0.3479      0.166      2.097      0.037       0.021       0.674
# MFQ_P_Total     0.3742      0.406      0.921      0.358      -0.426       1.174
# female         -0.7331      0.890     -0.823      0.411      -2.486       1.020
# meanFD         -6.7120      2.734     -2.455      0.015     -12.095      -1.329
# ==============================================================================
# Omnibus:                        1.350   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.509   Jarque-Bera (JB):                1.104
# Skew:                           0.003   Prob(JB):                        0.576
# Kurtosis:                       3.311   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak10_mean   R-squared:                       0.039
# Model:                                 WLS   Adj. R-squared:                  0.025
# Method:                      Least Squares   F-statistic:                     2.745
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):             0.0289
# Time:                             20:43:16   Log-Likelihood:                -903.05
# No. Observations:                      274   AIC:                             1816.
# Df Residuals:                          269   BIC:                             1834.
# Df Model:                                4
# Covariance Type:                 nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.5567      1.995      0.279      0.780      -3.372       4.485
# age             0.3756      0.157      2.390      0.018       0.066       0.685
# MFQ_P_Total     0.3444      0.385      0.894      0.372      -0.414       1.103
# female         -0.3151      0.844     -0.373      0.709      -1.976       1.346
# meanFD         -4.0648      2.591     -1.569      0.118      -9.165       1.036
# ==============================================================================
# Omnibus:                        0.803   Durbin-Watson:                   1.917
# Prob(Omnibus):                  0.669   Jarque-Bera (JB):                0.583
# Skew:                           0.097   Prob(JB):                        0.747
# Kurtosis:                       3.116   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak11_mean   R-squared:                       0.031
# Model:                                 WLS   Adj. R-squared:                  0.017
# Method:                      Least Squares   F-statistic:                     2.183
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):             0.0712
# Time:                             20:43:16   Log-Likelihood:                -892.41
# No. Observations:                      274   AIC:                             1795.
# Df Residuals:                          269   BIC:                             1813.
# Df Model:                                4
# Covariance Type:                 nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       4.8489      1.919      2.526      0.012       1.070       8.628
# age            -0.0930      0.151     -0.615      0.539      -0.391       0.205
# MFQ_P_Total    -0.2650      0.370     -0.715      0.475      -0.994       0.464
# female          1.1382      0.812      1.403      0.162      -0.460       2.736
# meanFD         -5.3236      2.492     -2.136      0.034     -10.230      -0.418
# ==============================================================================
# Omnibus:                        9.251   Durbin-Watson:                   2.214
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):               10.907
# Skew:                          -0.312   Prob(JB):                      0.00428
# Kurtosis:                       3.753   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak12_mean   R-squared:                       0.038
# Model:                                 WLS   Adj. R-squared:                  0.024
# Method:                      Least Squares   F-statistic:                     2.645
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):             0.0340
# Time:                             20:43:16   Log-Likelihood:                -898.98
# No. Observations:                      274   AIC:                             1808.
# Df Residuals:                          269   BIC:                             1826.
# Df Model:                                4
# Covariance Type:                 nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       4.1179      1.966      2.095      0.037       0.248       7.988
# age             0.0958      0.155      0.619      0.537      -0.209       0.401
# MFQ_P_Total    -0.4222      0.379     -1.113      0.267      -1.169       0.325
# female          1.1566      0.831      1.391      0.165      -0.480       2.793
# meanFD         -5.9408      2.552     -2.328      0.021     -10.966      -0.916
# ==============================================================================
# Omnibus:                        4.539   Durbin-Watson:                   1.922
# Prob(Omnibus):                  0.103   Jarque-Bera (JB):                4.945
# Skew:                           0.168   Prob(JB):                       0.0844
# Kurtosis:                       3.566   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Ventral Attn
#weighted least squares regression model - movie DM (Replication) - Depression 
for x in range(1,13):
    res = smf.wls("VentralAttn_peak{0}_mean ~ age + MFQ_P_Total + female + meanFD".format(x), 
                  data = data_dm.loc[data_dm['site'] == "cbic",:]).fit()
    results.loc[ind, 'dataset'] = 'replication'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'VentralAttn'
    print(res.summary())
# Out:
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak1_mean   R-squared:                       0.042
# Model:                                WLS   Adj. R-squared:                  0.024
# Method:                     Least Squares   F-statistic:                     2.274
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0626
# Time:                            20:41:47   Log-Likelihood:                -695.48
# No. Observations:                     210   AIC:                             1401.
# Df Residuals:                         205   BIC:                             1418.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       6.2305      2.167      2.875      0.004       1.957      10.504
# age             0.3657      0.155      2.365      0.019       0.061       0.671
# MFQ_P_Total    -0.0515      0.479     -0.108      0.914      -0.996       0.893
# female          0.4892      0.954      0.513      0.609      -1.392       2.371
# meanFD         -4.5436      2.749     -1.653      0.100      -9.963       0.876
# ==============================================================================
# Omnibus:                       24.778   Durbin-Watson:                   1.880
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.795
# Skew:                          -0.586   Prob(JB):                     2.54e-11
# Kurtosis:                       5.050   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak2_mean   R-squared:                       0.064
# Model:                                WLS   Adj. R-squared:                  0.046
# Method:                     Least Squares   F-statistic:                     3.533
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):            0.00820
# Time:                            20:41:47   Log-Likelihood:                -627.33
# No. Observations:                     210   AIC:                             1265.
# Df Residuals:                         205   BIC:                             1281.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       9.7380      1.567      6.216      0.000       6.649      12.827
# age             0.0102      0.112      0.092      0.927      -0.210       0.231
# MFQ_P_Total    -0.4210      0.346     -1.215      0.226      -1.104       0.262
# female          0.0601      0.690      0.087      0.931      -1.300       1.420
# meanFD         -6.9549      1.987     -3.500      0.001     -10.873      -3.037
# ==============================================================================
# Omnibus:                        0.413   Durbin-Watson:                   2.041
# Prob(Omnibus):                  0.813   Jarque-Bera (JB):                0.173
# Skew:                           0.011   Prob(JB):                        0.917
# Kurtosis:                       3.139   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak3_mean   R-squared:                       0.019
# Model:                                WLS   Adj. R-squared:                 -0.000
# Method:                     Least Squares   F-statistic:                    0.9828
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.418
# Time:                            20:41:47   Log-Likelihood:                -672.64
# No. Observations:                     210   AIC:                             1355.
# Df Residuals:                         205   BIC:                             1372.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      10.2944      1.944      5.295      0.000       6.462      14.127
# age            -0.1395      0.139     -1.006      0.316      -0.413       0.134
# MFQ_P_Total     0.1695      0.430      0.394      0.694      -0.678       1.017
# female         -0.3591      0.856     -0.419      0.675      -2.047       1.329
# meanFD         -3.9447      2.466     -1.600      0.111      -8.806       0.917
# ==============================================================================
# Omnibus:                       11.837   Durbin-Watson:                   1.825
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.280
# Skew:                          -0.533   Prob(JB):                      0.00216
# Kurtosis:                       3.516   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak4_mean   R-squared:                       0.015
# Model:                                WLS   Adj. R-squared:                 -0.004
# Method:                     Least Squares   F-statistic:                    0.7694
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.546
# Time:                            20:41:47   Log-Likelihood:                -711.29
# No. Observations:                     210   AIC:                             1433.
# Df Residuals:                         205   BIC:                             1449.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       5.7604      2.337      2.465      0.015       1.153      10.368
# age            -0.0248      0.167     -0.149      0.882      -0.353       0.304
# MFQ_P_Total    -0.0839      0.517     -0.162      0.871      -1.103       0.935
# female          1.7831      1.029      1.733      0.085      -0.246       3.812
# meanFD         -0.2443      2.964     -0.082      0.934      -6.088       5.599
# ==============================================================================
# Omnibus:                        4.787   Durbin-Watson:                   2.180
# Prob(Omnibus):                  0.091   Jarque-Bera (JB):                4.412
# Skew:                          -0.336   Prob(JB):                        0.110
# Kurtosis:                       3.227   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak5_mean   R-squared:                       0.018
# Model:                                WLS   Adj. R-squared:                 -0.001
# Method:                     Least Squares   F-statistic:                    0.9239
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.451
# Time:                            20:41:47   Log-Likelihood:                -696.45
# No. Observations:                     210   AIC:                             1403.
# Df Residuals:                         205   BIC:                             1420.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       9.0481      2.177      4.155      0.000       4.755      13.341
# age            -0.0584      0.155     -0.376      0.707      -0.365       0.248
# MFQ_P_Total    -0.3568      0.482     -0.741      0.460      -1.306       0.593
# female         -1.0077      0.959     -1.051      0.294      -2.898       0.883
# meanFD         -3.5490      2.762     -1.285      0.200      -8.994       1.896
# ==============================================================================
# Omnibus:                        0.810   Durbin-Watson:                   2.112
# Prob(Omnibus):                  0.667   Jarque-Bera (JB):                0.588
# Skew:                          -0.120   Prob(JB):                        0.745
# Kurtosis:                       3.099   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak6_mean   R-squared:                       0.040
# Model:                                WLS   Adj. R-squared:                  0.022
# Method:                     Least Squares   F-statistic:                     2.153
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0756
# Time:                            20:41:47   Log-Likelihood:                -658.98
# No. Observations:                     210   AIC:                             1328.
# Df Residuals:                         205   BIC:                             1345.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       9.0972      1.822      4.994      0.000       5.506      12.689
# age            -0.0146      0.130     -0.112      0.911      -0.271       0.242
# MFQ_P_Total    -0.0125      0.403     -0.031      0.975      -0.807       0.782
# female         -0.4121      0.802     -0.514      0.608      -1.993       1.169
# meanFD         -6.5639      2.310     -2.841      0.005     -11.119      -2.009
# ==============================================================================
# Omnibus:                        9.992   Durbin-Watson:                   2.118
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               10.028
# Skew:                          -0.501   Prob(JB):                      0.00664
# Kurtosis:                       3.376   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak7_mean   R-squared:                       0.006
# Model:                                WLS   Adj. R-squared:                 -0.013
# Method:                     Least Squares   F-statistic:                    0.3339
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.855
# Time:                            20:41:47   Log-Likelihood:                -674.23
# No. Observations:                     210   AIC:                             1358.
# Df Residuals:                         205   BIC:                             1375.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       2.9139      1.959      1.488      0.138      -0.948       6.776
# age             0.1298      0.140      0.929      0.354      -0.146       0.405
# MFQ_P_Total     0.1590      0.433      0.367      0.714      -0.695       1.013
# female         -0.0580      0.862     -0.067      0.946      -1.758       1.642
# meanFD          1.4491      2.484      0.583      0.560      -3.449       6.347
# ==============================================================================
# Omnibus:                        5.138   Durbin-Watson:                   2.123
# Prob(Omnibus):                  0.077   Jarque-Bera (JB):                5.236
# Skew:                          -0.381   Prob(JB):                       0.0729
# Kurtosis:                       2.863   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak8_mean   R-squared:                       0.034
# Model:                                WLS   Adj. R-squared:                  0.015
# Method:                     Least Squares   F-statistic:                     1.805
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.129
# Time:                            20:41:47   Log-Likelihood:                -625.89
# No. Observations:                     210   AIC:                             1262.
# Df Residuals:                         205   BIC:                             1279.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       5.9937      1.556      3.852      0.000       2.926       9.062
# age            -0.0469      0.111     -0.422      0.673      -0.266       0.172
# MFQ_P_Total     0.6158      0.344      1.790      0.075      -0.063       1.294
# female          0.5795      0.685      0.846      0.399      -0.771       1.930
# meanFD         -3.8868      1.974     -1.969      0.050      -7.778       0.004
# ==============================================================================
# Omnibus:                        0.076   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.963   Jarque-Bera (JB):                0.167
# Skew:                           0.040   Prob(JB):                        0.920
# Kurtosis:                       2.887   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak9_mean   R-squared:                       0.055
# Model:                                WLS   Adj. R-squared:                  0.037
# Method:                     Least Squares   F-statistic:                     2.996
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0197
# Time:                            20:41:47   Log-Likelihood:                -703.77
# No. Observations:                     210   AIC:                             1418.
# Df Residuals:                         205   BIC:                             1434.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       8.2517      2.255      3.660      0.000       3.807      12.697
# age             0.0222      0.161      0.138      0.890      -0.295       0.339
# MFQ_P_Total     0.5074      0.499      1.018      0.310      -0.476       1.490
# female          0.3389      0.993      0.341      0.733      -1.618       2.296
# meanFD         -9.5226      2.860     -3.330      0.001     -15.161      -3.885
# ==============================================================================
# Omnibus:                        0.612   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.736   Jarque-Bera (JB):                0.745
# Skew:                           0.089   Prob(JB):                        0.689
# Kurtosis:                       2.769   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak10_mean   R-squared:                       0.047
# Model:                                 WLS   Adj. R-squared:                  0.028
# Method:                      Least Squares   F-statistic:                     2.503
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):             0.0435
# Time:                             20:41:47   Log-Likelihood:                -715.60
# No. Observations:                      210   AIC:                             1441.
# Df Residuals:                          205   BIC:                             1458.
# Df Model:                                4
# Covariance Type:                 nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       5.6189      2.385      2.356      0.019       0.916      10.322
# age             0.0964      0.170      0.566      0.572      -0.239       0.432
# MFQ_P_Total     1.4264      0.527      2.704      0.007       0.386       2.466
# female          0.4145      1.050      0.395      0.693      -1.656       2.485
# meanFD         -4.7273      3.025     -1.563      0.120     -10.692       1.237
# ==============================================================================
# Omnibus:                        1.109   Durbin-Watson:                   1.792
# Prob(Omnibus):                  0.574   Jarque-Bera (JB):                1.070
# Skew:                           0.004   Prob(JB):                        0.586
# Kurtosis:                       2.650   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak11_mean   R-squared:                       0.036
# Model:                                 WLS   Adj. R-squared:                  0.017
# Method:                      Least Squares   F-statistic:                     1.895
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.113
# Time:                             20:41:47   Log-Likelihood:                -694.66
# No. Observations:                      210   AIC:                             1399.
# Df Residuals:                          205   BIC:                             1416.
# Df Model:                                4
# Covariance Type:                 nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       9.9622      2.159      4.614      0.000       5.706      14.219
# age            -0.1676      0.154     -1.088      0.278      -0.471       0.136
# MFQ_P_Total     0.5689      0.477      1.192      0.235      -0.372       1.510
# female         -0.4414      0.951     -0.464      0.643      -2.316       1.433
# meanFD         -6.0308      2.738     -2.202      0.029     -11.430      -0.632
# ==============================================================================
# Omnibus:                        4.792   Durbin-Watson:                   1.918
# Prob(Omnibus):                  0.091   Jarque-Bera (JB):                4.400
# Skew:                          -0.316   Prob(JB):                        0.111
# Kurtosis:                       3.321   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak12_mean   R-squared:                       0.021
# Model:                                 WLS   Adj. R-squared:                  0.002
# Method:                      Least Squares   F-statistic:                     1.089
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.363
# Time:                             20:41:47   Log-Likelihood:                -727.26
# No. Observations:                      210   AIC:                             1465.
# Df Residuals:                          205   BIC:                             1481.
# Df Model:                                4
# Covariance Type:                 nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.8343      2.521      0.331      0.741      -4.137       5.806
# age             0.3111      0.180      1.729      0.085      -0.044       0.666
# MFQ_P_Total    -0.4530      0.558     -0.812      0.418      -1.552       0.646
# female          0.5868      1.110      0.528      0.598      -1.602       2.776
# meanFD         -1.4496      3.198     -0.453      0.651      -7.755       4.856
# ==============================================================================
# Omnibus:                        2.616   Durbin-Watson:                   1.893
# Prob(Omnibus):                  0.270   Jarque-Bera (JB):                2.520
# Skew:                           0.101   Prob(JB):                        0.284
# Kurtosis:                       3.497   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Default Mode

# %%
#Default Mode
#weighted least squares regression model - movie DM (Discovery) - Depression
for x in range(1,10):
    res = smf.wls("Default_peak{0}_mean ~ age + MFQ_P_Total + female + meanFD".format(x), 
                  data = data_dm.loc[data_dm['site'] == "rubic",:]).fit()
    results.loc[ind, 'dataset'] = 'discovery'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'Default'
    print(res.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak1_mean   R-squared:                       0.093
# Model:                            WLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     6.932
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):           2.52e-05
# Time:                        20:41:48   Log-Likelihood:                -768.61
# No. Observations:                 274   AIC:                             1547.
# Df Residuals:                     269   BIC:                             1565.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       6.1879      1.222      5.066      0.000       3.783       8.593
# age             0.0032      0.096      0.034      0.973      -0.186       0.193
# MFQ_P_Total     0.0774      0.236      0.329      0.743      -0.387       0.542
# female          0.4351      0.516      0.842      0.400      -0.582       1.452
# meanFD         -7.8106      1.586     -4.925      0.000     -10.933      -4.688
# ==============================================================================
# Omnibus:                        0.769   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.681   Jarque-Bera (JB):                0.846
# Skew:                          -0.123   Prob(JB):                        0.655
# Kurtosis:                       2.881   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak2_mean   R-squared:                       0.095
# Model:                            WLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     7.052
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):           2.06e-05
# Time:                        20:41:48   Log-Likelihood:                -797.78
# No. Observations:                 274   AIC:                             1606.
# Df Residuals:                     269   BIC:                             1624.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       8.4419      1.359      6.213      0.000       5.767      11.117
# age            -0.2655      0.107     -2.480      0.014      -0.476      -0.055
# MFQ_P_Total    -0.2050      0.262     -0.782      0.435      -0.721       0.311
# female          0.1328      0.575      0.231      0.817      -0.998       1.264
# meanFD         -8.2613      1.764     -4.683      0.000     -11.735      -4.788
# ==============================================================================
# Omnibus:                        3.013   Durbin-Watson:                   1.821
# Prob(Omnibus):                  0.222   Jarque-Bera (JB):                3.075
# Skew:                          -0.249   Prob(JB):                        0.215
# Kurtosis:                       2.857   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak3_mean   R-squared:                       0.027
# Model:                            WLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     1.858
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.118
# Time:                        20:41:48   Log-Likelihood:                -798.46
# No. Observations:                 274   AIC:                             1607.
# Df Residuals:                     269   BIC:                             1625.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       2.6574      1.362      1.951      0.052      -0.024       5.339
# age             0.0382      0.107      0.356      0.722      -0.173       0.249
# MFQ_P_Total     0.2110      0.263      0.802      0.423      -0.307       0.729
# female          0.9780      0.576      1.698      0.091      -0.156       2.112
# meanFD         -2.7898      1.769     -1.577      0.116      -6.272       0.692
# ==============================================================================
# Omnibus:                        1.415   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.493   Jarque-Bera (JB):                1.120
# Skew:                          -0.098   Prob(JB):                        0.571
# Kurtosis:                       3.245   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak4_mean   R-squared:                       0.041
# Model:                            WLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     2.847
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0245
# Time:                        20:41:48   Log-Likelihood:                -765.12
# No. Observations:                 274   AIC:                             1540.
# Df Residuals:                     269   BIC:                             1558.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       2.7745      1.206      2.300      0.022       0.400       5.149
# age             0.1371      0.095      1.443      0.150      -0.050       0.324
# MFQ_P_Total     0.1912      0.233      0.822      0.412      -0.267       0.650
# female          0.5387      0.510      1.056      0.292      -0.465       1.543
# meanFD         -3.6491      1.566     -2.330      0.021      -6.732      -0.566
# ==============================================================================
# Omnibus:                        6.661   Durbin-Watson:                   1.847
# Prob(Omnibus):                  0.036   Jarque-Bera (JB):               10.344
# Skew:                          -0.060   Prob(JB):                      0.00567
# Kurtosis:                       3.944   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak5_mean   R-squared:                       0.005
# Model:                            WLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.3109
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.871
# Time:                        20:41:48   Log-Likelihood:                -818.56
# No. Observations:                 274   AIC:                             1647.
# Df Residuals:                     269   BIC:                             1665.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       3.3837      1.466      2.308      0.022       0.498       6.270
# age             0.0848      0.115      0.734      0.463      -0.143       0.312
# MFQ_P_Total     0.2003      0.283      0.708      0.480      -0.357       0.757
# female         -0.0611      0.620     -0.099      0.922      -1.281       1.159
# meanFD         -0.2120      1.903     -0.111      0.911      -3.959       3.535
# ==============================================================================
# Omnibus:                        4.225   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.121   Jarque-Bera (JB):                4.206
# Skew:                           0.303   Prob(JB):                        0.122
# Kurtosis:                       2.952   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak6_mean   R-squared:                       0.066
# Model:                            WLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     4.726
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):            0.00106
# Time:                        20:41:48   Log-Likelihood:                -758.98
# No. Observations:                 274   AIC:                             1528.
# Df Residuals:                     269   BIC:                             1546.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       1.3842      1.179      1.174      0.242      -0.938       3.706
# age             0.1944      0.093      2.092      0.037       0.011       0.377
# MFQ_P_Total    -0.2099      0.228     -0.922      0.357      -0.658       0.238
# female          0.4101      0.499      0.822      0.412      -0.572       1.392
# meanFD         -4.8700      1.531     -3.180      0.002      -7.885      -1.855
# ==============================================================================
# Omnibus:                       24.205   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.420
# Skew:                          -0.582   Prob(JB):                     2.04e-08
# Kurtosis:                       4.322   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak7_mean   R-squared:                       0.058
# Model:                            WLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     4.152
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):            0.00279
# Time:                        20:41:48   Log-Likelihood:                -798.88
# No. Observations:                 274   AIC:                             1608.
# Df Residuals:                     269   BIC:                             1626.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       4.3049      1.364      3.156      0.002       1.619       6.991
# age            -0.0313      0.107     -0.291      0.771      -0.243       0.180
# MFQ_P_Total    -0.2220      0.263     -0.843      0.400      -0.740       0.296
# female          0.7639      0.577      1.324      0.187      -0.372       1.900
# meanFD         -6.0920      1.771     -3.439      0.001      -9.579      -2.605
# ==============================================================================
# Omnibus:                        9.930   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               10.405
# Skew:                          -0.391   Prob(JB):                      0.00550
# Kurtosis:                       3.549   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak8_mean   R-squared:                       0.059
# Model:                            WLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     4.194
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):            0.00260
# Time:                        20:41:48   Log-Likelihood:                -781.00
# No. Observations:                 274   AIC:                             1572.
# Df Residuals:                     269   BIC:                             1590.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       5.7250      1.278      4.479      0.000       3.209       8.241
# age            -0.2087      0.101     -2.073      0.039      -0.407      -0.010
# MFQ_P_Total     0.3957      0.247      1.604      0.110      -0.090       0.881
# female         -0.2927      0.540     -0.542      0.588      -1.357       0.771
# meanFD         -5.9612      1.659     -3.592      0.000      -9.228      -2.694
# ==============================================================================
# Omnibus:                        0.330   Durbin-Watson:                   2.145
# Prob(Omnibus):                  0.848   Jarque-Bera (JB):                0.410
# Skew:                          -0.079   Prob(JB):                        0.815
# Kurtosis:                       2.896   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak9_mean   R-squared:                       0.008
# Model:                            WLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.5748
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.681
# Time:                        20:41:48   Log-Likelihood:                -815.14
# No. Observations:                 274   AIC:                             1640.
# Df Residuals:                     269   BIC:                             1658.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       2.0560      1.448      1.420      0.157      -0.794       4.906
# age            -0.0404      0.114     -0.355      0.723      -0.265       0.184
# MFQ_P_Total     0.1968      0.279      0.705      0.482      -0.353       0.747
# female          0.6530      0.612      1.067      0.287      -0.552       1.858
# meanFD          1.2990      1.880      0.691      0.490      -2.402       5.000
# ==============================================================================
# Omnibus:                        0.424   Durbin-Watson:                   1.924
# Prob(Omnibus):                  0.809   Jarque-Bera (JB):                0.209
# Skew:                           0.018   Prob(JB):                        0.901
# Kurtosis:                       3.130   Cond. No.                         77.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Default Mode
#weighted least squares regression model - movie DM (Replication) - Depression
for x in range(1,10):
    res = smf.wls("Default_peak{0}_mean ~ age + MFQ_P_Total + female + meanFD".format(x), 
                  data = data_dm.loc[data_dm['site'] == "cbic",:]).fit()
    results.loc[ind, 'dataset'] = 'discovery'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'Default'
    print(res.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak1_mean   R-squared:                       0.023
# Model:                            WLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.217
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.305
# Time:                        20:41:50   Log-Likelihood:                -630.60
# No. Observations:                 210   AIC:                             1271.
# Df Residuals:                     205   BIC:                             1288.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       7.0067      1.591      4.403      0.000       3.869      10.144
# age            -0.0996      0.114     -0.877      0.381      -0.323       0.124
# MFQ_P_Total    -0.3327      0.352     -0.945      0.346      -1.026       0.361
# female          0.4206      0.701      0.600      0.549      -0.961       1.802
# meanFD         -3.4510      2.018     -1.710      0.089      -7.430       0.528
# ==============================================================================
# Omnibus:                       10.306   Durbin-Watson:                   1.900
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.740
# Skew:                          -0.464   Prob(JB):                      0.00465
# Kurtosis:                       3.604   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak2_mean   R-squared:                       0.042
# Model:                            WLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     2.244
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0656
# Time:                        20:41:50   Log-Likelihood:                -631.62
# No. Observations:                 210   AIC:                             1273.
# Df Residuals:                     205   BIC:                             1290.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       6.2804      1.599      3.928      0.000       3.128       9.433
# age            -0.1079      0.114     -0.946      0.345      -0.333       0.117
# MFQ_P_Total     0.6649      0.354      1.880      0.061      -0.032       1.362
# female         -0.8969      0.704     -1.274      0.204      -2.285       0.491
# meanFD         -3.2155      2.028     -1.585      0.114      -7.214       0.783
# ==============================================================================
# Omnibus:                        0.998   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.607   Jarque-Bera (JB):                0.672
# Skew:                           0.060   Prob(JB):                        0.715
# Kurtosis:                       3.250   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak3_mean   R-squared:                       0.029
# Model:                            WLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1.521
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.197
# Time:                        20:41:50   Log-Likelihood:                -592.52
# No. Observations:                 210   AIC:                             1195.
# Df Residuals:                     205   BIC:                             1212.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       2.4712      1.327      1.862      0.064      -0.146       5.088
# age             0.1471      0.095      1.554      0.122      -0.040       0.334
# MFQ_P_Total     0.2117      0.294      0.721      0.472      -0.367       0.790
# female          0.6830      0.584      1.169      0.244      -0.469       1.835
# meanFD         -2.0830      1.684     -1.237      0.217      -5.402       1.236
# ==============================================================================
# Omnibus:                        1.518   Durbin-Watson:                   1.793
# Prob(Omnibus):                  0.468   Jarque-Bera (JB):                1.576
# Skew:                          -0.199   Prob(JB):                        0.455
# Kurtosis:                       2.854   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak4_mean   R-squared:                       0.056
# Model:                            WLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     3.043
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0183
# Time:                        20:41:50   Log-Likelihood:                -573.89
# No. Observations:                 210   AIC:                             1158.
# Df Residuals:                     205   BIC:                             1175.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.1969      1.215      0.162      0.871      -2.198       2.592
# age             0.2439      0.087      2.814      0.005       0.073       0.415
# MFQ_P_Total     0.2876      0.269      1.071      0.286      -0.242       0.817
# female          0.6454      0.535      1.207      0.229      -0.409       1.700
# meanFD         -1.4581      1.541     -0.946      0.345      -4.496       1.579
# ==============================================================================
# Omnibus:                        0.331   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.847   Jarque-Bera (JB):                0.328
# Skew:                          -0.094   Prob(JB):                        0.849
# Kurtosis:                       2.950   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak5_mean   R-squared:                       0.006
# Model:                            WLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.2916
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.883
# Time:                        20:41:50   Log-Likelihood:                -636.32
# No. Observations:                 210   AIC:                             1283.
# Df Residuals:                     205   BIC:                             1299.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       2.2617      1.635      1.383      0.168      -0.962       5.486
# age            -0.0471      0.117     -0.404      0.687      -0.277       0.183
# MFQ_P_Total     0.2234      0.362      0.618      0.537      -0.490       0.936
# female         -0.2792      0.720     -0.388      0.699      -1.699       1.140
# meanFD          1.3262      2.074      0.639      0.523      -2.763       5.415
# ==============================================================================
# Omnibus:                        2.616   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.270   Jarque-Bera (JB):                2.260
# Skew:                           0.238   Prob(JB):                        0.323
# Kurtosis:                       3.177   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak6_mean   R-squared:                       0.083
# Model:                            WLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     4.643
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):            0.00131
# Time:                        20:41:50   Log-Likelihood:                -601.74
# No. Observations:                 210   AIC:                             1213.
# Df Residuals:                     205   BIC:                             1230.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       5.1903      1.387      3.742      0.000       2.456       7.925
# age             0.0256      0.099      0.259      0.796      -0.169       0.221
# MFQ_P_Total    -0.0117      0.307     -0.038      0.970      -0.616       0.593
# female          1.4754      0.611      2.416      0.017       0.271       2.680
# meanFD         -6.4571      1.759     -3.670      0.000      -9.926      -2.989
# ==============================================================================
# Omnibus:                        5.329   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.070   Jarque-Bera (JB):                4.973
# Skew:                          -0.359   Prob(JB):                       0.0832
# Kurtosis:                       3.231   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak7_mean   R-squared:                       0.043
# Model:                            WLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     2.316
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0585
# Time:                        20:41:50   Log-Likelihood:                -647.87
# No. Observations:                 210   AIC:                             1306.
# Df Residuals:                     205   BIC:                             1322.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       7.0318      1.728      4.070      0.000       3.626      10.438
# age            -0.3490      0.123     -2.832      0.005      -0.592      -0.106
# MFQ_P_Total    -0.1015      0.382     -0.266      0.791      -0.855       0.652
# female         -0.3769      0.761     -0.495      0.621      -1.877       1.123
# meanFD         -1.7780      2.191     -0.811      0.418      -6.098       2.542
# ==============================================================================
# Omnibus:                        0.084   Durbin-Watson:                   1.915
# Prob(Omnibus):                  0.959   Jarque-Bera (JB):                0.217
# Skew:                           0.001   Prob(JB):                        0.897
# Kurtosis:                       2.842   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak8_mean   R-squared:                       0.026
# Model:                            WLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     1.378
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.243
# Time:                        20:41:50   Log-Likelihood:                -605.63
# No. Observations:                 210   AIC:                             1221.
# Df Residuals:                     205   BIC:                             1238.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       3.6842      1.413      2.608      0.010       0.899       6.470
# age            -0.1779      0.101     -1.765      0.079      -0.377       0.021
# MFQ_P_Total    -0.2110      0.312     -0.675      0.500      -0.827       0.405
# female          0.9143      0.622      1.470      0.143      -0.312       2.141
# meanFD         -0.2100      1.792     -0.117      0.907      -3.743       3.323
# ==============================================================================
# Omnibus:                        4.988   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.083   Jarque-Bera (JB):                4.745
# Skew:                          -0.288   Prob(JB):                       0.0932
# Kurtosis:                       3.459   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak9_mean   R-squared:                       0.025
# Model:                            WLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     1.328
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.261
# Time:                        20:41:50   Log-Likelihood:                -623.28
# No. Observations:                 210   AIC:                             1257.
# Df Residuals:                     205   BIC:                             1273.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -1.3061      1.537     -0.850      0.396      -4.336       1.724
# age             0.2213      0.110      2.018      0.045       0.005       0.437
# MFQ_P_Total     0.0188      0.340      0.055      0.956      -0.651       0.689
# female          0.3452      0.677      0.510      0.611      -0.989       1.679
# meanFD          1.7518      1.949      0.899      0.370      -2.091       5.595
# ==============================================================================
# Omnibus:                        0.211   Durbin-Watson:                   1.891
# Prob(Omnibus):                  0.900   Jarque-Bera (JB):                0.200
# Skew:                           0.073   Prob(JB):                        0.905
# Kurtosis:                       2.961   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
results.to_csv('dep_activation_results.csv')

# %% [markdown]
# ## ACTIVATION - Parent Reported DEPRESSION (FACTOR)

# %%
#Ventral Attn
#weighted least squares regression model - movie DM (Discovery)- Depression 
for x in range(1,13):
    res = smf.wls("VentralAttn_peak{0}_mean ~ age + MFQ_P_NegEmotion + female + meanFD".format(x), 
                  data = data_dm_factor.loc[data_dm_factor['site'] == "rubic",:]).fit()
    results.loc[ind, 'dataset'] = 'discovery'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'VentralAttn'
    print(res.summary())
# Out:
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak1_mean   R-squared:                       0.035
# Model:                                WLS   Adj. R-squared:                  0.016
# Method:                     Least Squares   F-statistic:                     1.872
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.116
# Time:                            21:09:20   Log-Likelihood:                -714.37
# No. Observations:                     214   AIC:                             1439.
# Df Residuals:                         209   BIC:                             1456.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           11.1156      3.040      3.656      0.000       5.123      17.109
# age                  0.1563      0.239      0.655      0.513      -0.314       0.627
# MFQ_P_NegEmotion    -0.2086      0.381     -0.548      0.584      -0.959       0.542
# female              -1.2412      1.001     -1.239      0.217      -3.215       0.733
# meanFD              -6.5403      2.972     -2.201      0.029     -12.398      -0.682
# ==============================================================================
# Omnibus:                        1.721   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.423   Jarque-Bera (JB):                1.552
# Skew:                          -0.208   Prob(JB):                        0.460
# Kurtosis:                       3.030   Cond. No.                         88.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak2_mean   R-squared:                       0.102
# Model:                                WLS   Adj. R-squared:                  0.085
# Method:                     Least Squares   F-statistic:                     5.923
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):           0.000156
# Time:                            21:09:20   Log-Likelihood:                -597.41
# No. Observations:                     214   AIC:                             1205.
# Df Residuals:                         209   BIC:                             1222.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            9.6324      1.760      5.473      0.000       6.163      13.102
# age                 -0.2664      0.138     -1.928      0.055      -0.539       0.006
# MFQ_P_NegEmotion     0.6127      0.220      2.780      0.006       0.178       1.047
# female              -1.4174      0.580     -2.445      0.015      -2.560      -0.274
# meanFD              -6.3250      1.720     -3.677      0.000      -9.716      -2.934
# ==============================================================================
# Omnibus:                        0.208   Durbin-Watson:                   1.913
# Prob(Omnibus):                  0.901   Jarque-Bera (JB):                0.360
# Skew:                           0.009   Prob(JB):                        0.835
# Kurtosis:                       2.800   Cond. No.                         88.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak3_mean   R-squared:                       0.078
# Model:                                WLS   Adj. R-squared:                  0.060
# Method:                     Least Squares   F-statistic:                     4.391
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):            0.00198
# Time:                            21:09:20   Log-Likelihood:                -637.96
# No. Observations:                     214   AIC:                             1286.
# Df Residuals:                         209   BIC:                             1303.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           11.0913      2.127      5.214      0.000       6.898      15.285
# age                 -0.2168      0.167     -1.298      0.196      -0.546       0.112
# MFQ_P_NegEmotion    -0.3152      0.266     -1.183      0.238      -0.840       0.210
# female              -1.2072      0.701     -1.723      0.086      -2.589       0.174
# meanFD              -7.5892      2.079     -3.650      0.000     -11.688      -3.490
# ==============================================================================
# Omnibus:                        6.235   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.044   Jarque-Bera (JB):                7.954
# Skew:                          -0.198   Prob(JB):                       0.0187
# Kurtosis:                       3.858   Cond. No.                         88.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak4_mean   R-squared:                       0.052
# Model:                                WLS   Adj. R-squared:                  0.034
# Method:                     Least Squares   F-statistic:                     2.870
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0241
# Time:                            21:09:20   Log-Likelihood:                -714.42
# No. Observations:                     214   AIC:                             1439.
# Df Residuals:                         209   BIC:                             1456.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           10.1768      3.041      3.347      0.001       4.182      16.171
# age                 -0.0356      0.239     -0.149      0.882      -0.506       0.435
# MFQ_P_NegEmotion     0.1157      0.381      0.304      0.762      -0.635       0.866
# female               1.0623      1.002      1.061      0.290      -0.912       3.037
# meanFD              -8.9264      2.972     -3.003      0.003     -14.786      -3.067
# ==============================================================================
# Omnibus:                        0.438   Durbin-Watson:                   1.875
# Prob(Omnibus):                  0.803   Jarque-Bera (JB):                0.552
# Skew:                          -0.096   Prob(JB):                        0.759
# Kurtosis:                       2.843   Cond. No.                         88.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak5_mean   R-squared:                       0.027
# Model:                                WLS   Adj. R-squared:                  0.008
# Method:                     Least Squares   F-statistic:                     1.425
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.227
# Time:                            21:09:20   Log-Likelihood:                -685.36
# No. Observations:                     214   AIC:                             1381.
# Df Residuals:                         209   BIC:                             1398.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            3.0959      2.655      1.166      0.245      -2.137       8.329
# age                  0.1162      0.208      0.558      0.578      -0.295       0.527
# MFQ_P_NegEmotion     0.3920      0.332      1.179      0.240      -0.263       1.047
# female              -1.6334      0.874     -1.868      0.063      -3.357       0.090
# meanFD               0.6971      2.595      0.269      0.788      -4.418       5.813
# ==============================================================================
# Omnibus:                        5.378   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.068   Jarque-Bera (JB):                7.532
# Skew:                          -0.082   Prob(JB):                       0.0231
# Kurtosis:                       3.904   Cond. No.                         88.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak6_mean   R-squared:                       0.064
# Model:                                WLS   Adj. R-squared:                  0.046
# Method:                     Least Squares   F-statistic:                     3.564
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):            0.00777
# Time:                            21:09:20   Log-Likelihood:                -645.45
# No. Observations:                     214   AIC:                             1301.
# Df Residuals:                         209   BIC:                             1318.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            7.3603      2.203      3.341      0.001       3.017      11.703
# age                 -0.2348      0.173     -1.358      0.176      -0.576       0.106
# MFQ_P_NegEmotion     0.5079      0.276      1.841      0.067      -0.036       1.052
# female              -0.5555      0.726     -0.765      0.445      -1.986       0.875
# meanFD              -7.2824      2.153     -3.382      0.001     -11.527      -3.037
# ==============================================================================
# Omnibus:                        3.900   Durbin-Watson:                   2.060
# Prob(Omnibus):                  0.142   Jarque-Bera (JB):                3.794
# Skew:                          -0.326   Prob(JB):                        0.150
# Kurtosis:                       2.987   Cond. No.                         88.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak7_mean   R-squared:                       0.080
# Model:                                WLS   Adj. R-squared:                  0.062
# Method:                     Least Squares   F-statistic:                     4.523
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):            0.00159
# Time:                            21:09:20   Log-Likelihood:                -670.76
# No. Observations:                     214   AIC:                             1352.
# Df Residuals:                         209   BIC:                             1368.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -2.8929      2.480     -1.167      0.245      -7.781       1.995
# age                  0.6867      0.195      3.529      0.001       0.303       1.070
# MFQ_P_NegEmotion    -0.1233      0.311     -0.397      0.692      -0.735       0.489
# female               1.5218      0.817      1.863      0.064      -0.088       3.132
# meanFD              -2.3430      2.424     -0.967      0.335      -7.121       2.435
# ==============================================================================
# Omnibus:                        3.109   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.211   Jarque-Bera (JB):                3.335
# Skew:                          -0.077   Prob(JB):                        0.189
# Kurtosis:                       3.592   Cond. No.                         88.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak8_mean   R-squared:                       0.017
# Model:                                WLS   Adj. R-squared:                 -0.002
# Method:                     Least Squares   F-statistic:                    0.9052
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.462
# Time:                            21:09:20   Log-Likelihood:                -663.45
# No. Observations:                     214   AIC:                             1337.
# Df Residuals:                         209   BIC:                             1354.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            6.9761      2.396      2.911      0.004       2.252      11.700
# age                 -0.3474      0.188     -1.847      0.066      -0.718       0.023
# MFQ_P_NegEmotion    -0.0528      0.300     -0.176      0.860      -0.644       0.539
# female               0.0264      0.789      0.033      0.973      -1.530       1.583
# meanFD              -0.8945      2.342     -0.382      0.703      -5.512       3.723
# ==============================================================================
# Omnibus:                        0.285   Durbin-Watson:                   1.808
# Prob(Omnibus):                  0.867   Jarque-Bera (JB):                0.150
# Skew:                          -0.060   Prob(JB):                        0.928
# Kurtosis:                       3.050   Cond. No.                         88.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak9_mean   R-squared:                       0.037
# Model:                                WLS   Adj. R-squared:                  0.018
# Method:                     Least Squares   F-statistic:                     2.000
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0957
# Time:                            21:09:20   Log-Likelihood:                -721.07
# No. Observations:                     214   AIC:                             1452.
# Df Residuals:                         209   BIC:                             1469.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            1.0249      3.137      0.327      0.744      -5.159       7.209
# age                  0.3590      0.246      1.458      0.146      -0.126       0.844
# MFQ_P_NegEmotion     0.3332      0.393      0.848      0.397      -0.441       1.108
# female              -0.3717      1.033     -0.360      0.719      -2.409       1.665
# meanFD              -5.9601      3.066     -1.944      0.053     -12.005       0.084
# ==============================================================================
# Omnibus:                        1.139   Durbin-Watson:                   2.109
# Prob(Omnibus):                  0.566   Jarque-Bera (JB):                0.818
# Skew:                          -0.037   Prob(JB):                        0.664
# Kurtosis:                       3.294   Cond. No.                         88.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak10_mean   R-squared:                       0.025
# Model:                                 WLS   Adj. R-squared:                  0.006
# Method:                      Least Squares   F-statistic:                     1.329
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.260
# Time:                             21:09:20   Log-Likelihood:                -712.68
# No. Observations:                      214   AIC:                             1435.
# Df Residuals:                          209   BIC:                             1452.
# Df Model:                                4
# Covariance Type:                 nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            3.2973      3.016      1.093      0.276      -2.649       9.243
# age                  0.1723      0.237      0.728      0.467      -0.294       0.639
# MFQ_P_NegEmotion     0.1363      0.378      0.361      0.719      -0.608       0.881
# female               0.0905      0.994      0.091      0.928      -1.868       2.049
# meanFD              -5.8128      2.948     -1.972      0.050     -11.625      -0.001
# ==============================================================================
# Omnibus:                        0.630   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.730   Jarque-Bera (JB):                0.454
# Skew:                           0.107   Prob(JB):                        0.797
# Kurtosis:                       3.068   Cond. No.                         88.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak11_mean   R-squared:                       0.044
# Model:                                 WLS   Adj. R-squared:                  0.026
# Method:                      Least Squares   F-statistic:                     2.399
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):             0.0513
# Time:                             21:09:20   Log-Likelihood:                -694.55
# No. Observations:                      214   AIC:                             1399.
# Df Residuals:                          209   BIC:                             1416.
# Df Model:                                4
# Covariance Type:                 nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            5.5090      2.771      1.988      0.048       0.046      10.972
# age                 -0.1439      0.217     -0.661      0.509      -0.573       0.285
# MFQ_P_NegEmotion     0.0203      0.347      0.059      0.953      -0.664       0.705
# female               1.3117      0.913      1.437      0.152      -0.488       3.111
# meanFD              -6.6790      2.709     -2.466      0.014     -12.019      -1.339
# ==============================================================================
# Omnibus:                        3.452   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.178   Jarque-Bera (JB):                3.603
# Skew:                          -0.132   Prob(JB):                        0.165
# Kurtosis:                       3.578   Cond. No.                         88.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak12_mean   R-squared:                       0.033
# Model:                                 WLS   Adj. R-squared:                  0.015
# Method:                      Least Squares   F-statistic:                     1.797
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.131
# Time:                             21:09:20   Log-Likelihood:                -704.71
# No. Observations:                      214   AIC:                             1419.
# Df Residuals:                          209   BIC:                             1436.
# Df Model:                                4
# Covariance Type:                 nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            4.7243      2.906      1.626      0.105      -1.004      10.453
# age                  0.0810      0.228      0.355      0.723      -0.369       0.531
# MFQ_P_NegEmotion    -0.4268      0.364     -1.173      0.242      -1.144       0.291
# female               0.9860      0.957      1.030      0.304      -0.901       2.873
# meanFD              -5.3455      2.840     -1.882      0.061     -10.945       0.254
# ==============================================================================
# Omnibus:                        6.075   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.048   Jarque-Bera (JB):                7.263
# Skew:                           0.221   Prob(JB):                       0.0265
# Kurtosis:                       3.787   Cond. No.                         88.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Ventral Attn
#weighted least squares regression model - movie DM (Replication)- Depression 
for x in range(1,13):
    res = smf.wls("VentralAttn_peak{0}_mean ~ age + MFQ_P_NegEmotion + female + meanFD".format(x), 
                  data = data_dm_factor.loc[data_dm_factor['site'] == "cbic",:]).fit()
    results.loc[ind, 'dataset'] = 'discovery'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'VentralAttn'
    print(res.summary())
# Out:
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak1_mean   R-squared:                       0.028
# Model:                                WLS   Adj. R-squared:                  0.004
# Method:                     Least Squares   F-statistic:                     1.168
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.327
# Time:                            21:09:21   Log-Likelihood:                -557.94
# No. Observations:                     170   AIC:                             1126.
# Df Residuals:                         165   BIC:                             1142.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            9.0381      2.876      3.143      0.002       3.360      14.716
# age                  0.1367      0.202      0.676      0.500      -0.262       0.536
# MFQ_P_NegEmotion    -0.4612      0.437     -1.056      0.293      -1.324       0.401
# female               1.1870      1.015      1.169      0.244      -0.818       3.192
# meanFD              -3.8474      3.102     -1.240      0.217      -9.972       2.277
# ==============================================================================
# Omnibus:                       17.667   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.707
# Skew:                          -0.538   Prob(JB):                     3.54e-07
# Kurtosis:                       4.742   Cond. No.                         88.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak2_mean   R-squared:                       0.046
# Model:                                WLS   Adj. R-squared:                  0.023
# Method:                     Least Squares   F-statistic:                     2.010
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0954
# Time:                            21:09:21   Log-Likelihood:                -504.32
# No. Observations:                     170   AIC:                             1019.
# Df Residuals:                         165   BIC:                             1034.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            9.6406      2.098      4.596      0.000       5.499      13.782
# age                 -0.0071      0.147     -0.048      0.962      -0.298       0.284
# MFQ_P_NegEmotion    -0.6293      0.319     -1.975      0.050      -1.259    -1.9e-05
# female              -0.0562      0.741     -0.076      0.940      -1.519       1.406
# meanFD              -4.3619      2.263     -1.928      0.056      -8.830       0.106
# ==============================================================================
# Omnibus:                        0.964   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.617   Jarque-Bera (JB):                0.637
# Skew:                          -0.119   Prob(JB):                        0.727
# Kurtosis:                       3.182   Cond. No.                         88.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak3_mean   R-squared:                       0.046
# Model:                                WLS   Adj. R-squared:                  0.023
# Method:                     Least Squares   F-statistic:                     2.007
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0958
# Time:                            21:09:21   Log-Likelihood:                -532.57
# No. Observations:                     170   AIC:                             1075.
# Df Residuals:                         165   BIC:                             1091.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           13.8893      2.477      5.608      0.000       8.999      18.780
# age                 -0.4146      0.174     -2.381      0.018      -0.758      -0.071
# MFQ_P_NegEmotion    -0.1256      0.376     -0.334      0.739      -0.869       0.617
# female              -0.1328      0.875     -0.152      0.880      -1.860       1.594
# meanFD              -3.9529      2.672     -1.479      0.141      -9.228       1.323
# ==============================================================================
# Omnibus:                        5.964   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.051   Jarque-Bera (JB):                5.572
# Skew:                          -0.391   Prob(JB):                       0.0617
# Kurtosis:                       3.419   Cond. No.                         88.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak4_mean   R-squared:                       0.046
# Model:                                WLS   Adj. R-squared:                  0.023
# Method:                     Least Squares   F-statistic:                     1.973
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.101
# Time:                            21:09:21   Log-Likelihood:                -580.92
# No. Observations:                     170   AIC:                             1172.
# Df Residuals:                         165   BIC:                             1188.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           10.0421      3.292      3.051      0.003       3.543      16.541
# age                 -0.2966      0.231     -1.282      0.202      -0.753       0.160
# MFQ_P_NegEmotion    -0.7300      0.500     -1.460      0.146      -1.717       0.257
# female               2.2595      1.162      1.944      0.054      -0.036       4.555
# meanFD              -0.4755      3.551     -0.134      0.894      -7.486       6.536
# ==============================================================================
# Omnibus:                        4.628   Durbin-Watson:                   2.141
# Prob(Omnibus):                  0.099   Jarque-Bera (JB):                4.190
# Skew:                          -0.364   Prob(JB):                        0.123
# Kurtosis:                       3.250   Cond. No.                         88.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak5_mean   R-squared:                       0.029
# Model:                                WLS   Adj. R-squared:                  0.005
# Method:                     Least Squares   F-statistic:                     1.229
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.301
# Time:                            21:09:21   Log-Likelihood:                -563.04
# No. Observations:                     170   AIC:                             1136.
# Df Residuals:                         165   BIC:                             1152.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           10.8202      2.963      3.652      0.000       4.970      16.671
# age                 -0.2685      0.208     -1.289      0.199      -0.680       0.143
# MFQ_P_NegEmotion     0.2505      0.450      0.556      0.579      -0.638       1.139
# female              -1.6808      1.046     -1.606      0.110      -3.747       0.385
# meanFD              -1.1975      3.196     -0.375      0.708      -7.508       5.114
# ==============================================================================
# Omnibus:                        1.062   Durbin-Watson:                   1.910
# Prob(Omnibus):                  0.588   Jarque-Bera (JB):                0.694
# Skew:                          -0.089   Prob(JB):                        0.707
# Kurtosis:                       3.257   Cond. No.                         88.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak6_mean   R-squared:                       0.015
# Model:                                WLS   Adj. R-squared:                 -0.008
# Method:                     Least Squares   F-statistic:                    0.6488
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.628
# Time:                            21:09:21   Log-Likelihood:                -524.18
# No. Observations:                     170   AIC:                             1058.
# Df Residuals:                         165   BIC:                             1074.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            6.5235      2.358      2.767      0.006       1.868      11.178
# age                  0.0773      0.166      0.467      0.641      -0.250       0.405
# MFQ_P_NegEmotion    -0.4049      0.358     -1.130      0.260      -1.112       0.302
# female              -0.3236      0.833     -0.389      0.698      -1.967       1.320
# meanFD              -2.3286      2.543     -0.916      0.361      -7.350       2.693
# ==============================================================================
# Omnibus:                       11.526   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.128
# Skew:                          -0.562   Prob(JB):                      0.00232
# Kurtosis:                       3.670   Cond. No.                         88.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak7_mean   R-squared:                       0.008
# Model:                                WLS   Adj. R-squared:                 -0.016
# Method:                     Least Squares   F-statistic:                    0.3452
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.847
# Time:                            21:09:21   Log-Likelihood:                -547.74
# No. Observations:                     170   AIC:                             1105.
# Df Residuals:                         165   BIC:                             1121.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            6.3244      2.708      2.335      0.021       0.977      11.671
# age                 -0.0693      0.190     -0.364      0.716      -0.445       0.307
# MFQ_P_NegEmotion    -0.4332      0.411     -1.053      0.294      -1.246       0.379
# female               0.2702      0.956      0.283      0.778      -1.618       2.158
# meanFD               0.5538      2.921      0.190      0.850      -5.214       6.322
# ==============================================================================
# Omnibus:                        4.854   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.088   Jarque-Bera (JB):                4.172
# Skew:                          -0.296   Prob(JB):                        0.124
# Kurtosis:                       2.512   Cond. No.                         88.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak8_mean   R-squared:                       0.034
# Model:                                WLS   Adj. R-squared:                  0.011
# Method:                     Least Squares   F-statistic:                     1.449
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.220
# Time:                            21:09:21   Log-Likelihood:                -505.79
# No. Observations:                     170   AIC:                             1022.
# Df Residuals:                         165   BIC:                             1037.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            6.3310      2.116      2.992      0.003       2.153      10.509
# age                 -0.1057      0.149     -0.711      0.478      -0.399       0.188
# MFQ_P_NegEmotion     0.3029      0.321      0.942      0.347      -0.332       0.938
# female               0.9291      0.747      1.243      0.215      -0.546       2.404
# meanFD              -4.2078      2.283     -1.844      0.067      -8.715       0.299
# ==============================================================================
# Omnibus:                        1.050   Durbin-Watson:                   1.823
# Prob(Omnibus):                  0.592   Jarque-Bera (JB):                1.144
# Skew:                          -0.176   Prob(JB):                        0.564
# Kurtosis:                       2.806   Cond. No.                         88.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak9_mean   R-squared:                       0.031
# Model:                                WLS   Adj. R-squared:                  0.007
# Method:                     Least Squares   F-statistic:                     1.309
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.269
# Time:                            21:09:21   Log-Likelihood:                -566.50
# No. Observations:                     170   AIC:                             1143.
# Df Residuals:                         165   BIC:                             1159.
# Df Model:                               4
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            7.3671      3.024      2.436      0.016       1.396      13.338
# age                  0.0063      0.213      0.030      0.976      -0.413       0.426
# MFQ_P_NegEmotion    -0.0491      0.459     -0.107      0.915      -0.956       0.858
# female               0.5702      1.068      0.534      0.594      -1.538       2.679
# meanFD              -7.2976      3.262     -2.237      0.027     -13.738      -0.857
# ==============================================================================
# Omnibus:                        0.437   Durbin-Watson:                   2.133
# Prob(Omnibus):                  0.804   Jarque-Bera (JB):                0.576
# Skew:                          -0.096   Prob(JB):                        0.750
# Kurtosis:                       2.789   Cond. No.                         88.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak10_mean   R-squared:                       0.017
# Model:                                 WLS   Adj. R-squared:                 -0.007
# Method:                      Least Squares   F-statistic:                    0.6930
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.598
# Time:                             21:09:21   Log-Likelihood:                -586.18
# No. Observations:                      170   AIC:                             1182.
# Df Residuals:                          165   BIC:                             1198.
# Df Model:                                4
# Covariance Type:                 nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            5.9308      3.395      1.747      0.083      -0.773      12.634
# age                 -0.0805      0.239     -0.337      0.736      -0.552       0.391
# MFQ_P_NegEmotion     0.7841      0.516      1.520      0.130      -0.234       1.803
# female               0.1432      1.199      0.119      0.905      -2.224       2.510
# meanFD              -2.4238      3.663     -0.662      0.509      -9.655       4.808
# ==============================================================================
# Omnibus:                        2.635   Durbin-Watson:                   1.658
# Prob(Omnibus):                  0.268   Jarque-Bera (JB):                1.896
# Skew:                          -0.048   Prob(JB):                        0.388
# Kurtosis:                       2.492   Cond. No.                         88.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak11_mean   R-squared:                       0.029
# Model:                                 WLS   Adj. R-squared:                  0.005
# Method:                      Least Squares   F-statistic:                     1.226
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.302
# Time:                             21:09:21   Log-Likelihood:                -559.35
# No. Observations:                      170   AIC:                             1129.
# Df Residuals:                          165   BIC:                             1144.
# Df Model:                                4
# Covariance Type:                 nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           10.1156      2.900      3.489      0.001       4.391      15.841
# age                 -0.2525      0.204     -1.239      0.217      -0.655       0.150
# MFQ_P_NegEmotion     0.3151      0.441      0.715      0.475      -0.555       1.185
# female              -0.7796      1.024     -0.761      0.448      -2.801       1.242
# meanFD              -4.5925      3.128     -1.468      0.144     -10.768       1.583
# ==============================================================================
# Omnibus:                        3.752   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.153   Jarque-Bera (JB):                3.280
# Skew:                          -0.303   Prob(JB):                        0.194
# Kurtosis:                       3.309   Cond. No.                         88.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak12_mean   R-squared:                       0.018
# Model:                                 WLS   Adj. R-squared:                 -0.006
# Method:                      Least Squares   F-statistic:                    0.7507
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.559
# Time:                             21:09:21   Log-Likelihood:                -593.07
# No. Observations:                      170   AIC:                             1196.
# Df Residuals:                          165   BIC:                             1212.
# Df Model:                                4
# Covariance Type:                 nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            1.4128      3.536      0.400      0.690      -5.568       8.394
# age                  0.2923      0.249      1.176      0.241      -0.198       0.783
# MFQ_P_NegEmotion    -0.6047      0.537     -1.126      0.262      -1.665       0.456
# female               0.5200      1.249      0.416      0.678      -1.945       2.985
# meanFD              -0.8950      3.814     -0.235      0.815      -8.425       6.635
# ==============================================================================
# Omnibus:                        1.649   Durbin-Watson:                   1.893
# Prob(Omnibus):                  0.438   Jarque-Bera (JB):                1.338
# Skew:                           0.021   Prob(JB):                        0.512
# Kurtosis:                       3.432   Cond. No.                         88.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Default Mode
#weighted least squares regression model - movie DM (Discovery) - Depression
for x in range(1,10):
    res = smf.wls("Default_peak{0}_mean ~ age + MFQ_SR_NegEmotion + female + meanFD".format(x), 
                  data = data_dm_factor.loc[data_dm_factor['site'] == "rubic",:]).fit()
    results.loc[ind, 'dataset'] = 'discovery'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'Default'
    print(res.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak1_mean   R-squared:                       0.086
# Model:                            WLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     4.962
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):           0.000767
# Time:                        21:09:21   Log-Likelihood:                -599.05
# No. Observations:                 215   AIC:                             1208.
# Df Residuals:                     210   BIC:                             1225.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             7.4663      1.748      4.272      0.000       4.021      10.912
# age                  -0.0921      0.137     -0.672      0.502      -0.362       0.178
# MFQ_SR_NegEmotion     0.0376      0.156      0.241      0.810      -0.269       0.345
# female               -0.2831      0.580     -0.488      0.626      -1.426       0.860
# meanFD               -7.6323      1.722     -4.432      0.000     -11.027      -4.238
# ==============================================================================
# Omnibus:                        0.251   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.882   Jarque-Bera (JB):                0.381
# Skew:                          -0.062   Prob(JB):                        0.827
# Kurtosis:                       2.836   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak2_mean   R-squared:                       0.095
# Model:                            WLS   Adj. R-squared:                  0.077
# Method:                 Least Squares   F-statistic:                     5.493
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):           0.000318
# Time:                        21:09:21   Log-Likelihood:                -625.08
# No. Observations:                 215   AIC:                             1260.
# Df Residuals:                     210   BIC:                             1277.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            10.1027      1.973      5.121      0.000       6.213      13.992
# age                  -0.3839      0.155     -2.480      0.014      -0.689      -0.079
# MFQ_SR_NegEmotion    -0.2235      0.176     -1.272      0.205      -0.570       0.123
# female               -0.1276      0.654     -0.195      0.846      -1.417       1.162
# meanFD               -7.4612      1.944     -3.839      0.000     -11.293      -3.630
# ==============================================================================
# Omnibus:                        3.170   Durbin-Watson:                   1.856
# Prob(Omnibus):                  0.205   Jarque-Bera (JB):                3.239
# Skew:                          -0.282   Prob(JB):                        0.198
# Kurtosis:                       2.790   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak3_mean   R-squared:                       0.032
# Model:                            WLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     1.736
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.143
# Time:                        21:09:22   Log-Likelihood:                -626.79
# No. Observations:                 215   AIC:                             1264.
# Df Residuals:                     210   BIC:                             1280.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             5.4833      1.989      2.757      0.006       1.563       9.403
# age                  -0.1714      0.156     -1.099      0.273      -0.479       0.136
# MFQ_SR_NegEmotion    -0.1448      0.177     -0.817      0.415      -0.494       0.204
# female                0.8946      0.660      1.356      0.176      -0.406       2.195
# meanFD               -3.0511      1.959     -1.557      0.121      -6.913       0.811
# ==============================================================================
# Omnibus:                        0.382   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.826   Jarque-Bera (JB):                0.470
# Skew:                          -0.096   Prob(JB):                        0.790
# Kurtosis:                       2.874   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak4_mean   R-squared:                       0.031
# Model:                            WLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     1.655
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.162
# Time:                        21:09:22   Log-Likelihood:                -597.23
# No. Observations:                 215   AIC:                             1204.
# Df Residuals:                     210   BIC:                             1221.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             3.2566      1.733      1.879      0.062      -0.160       6.673
# age                   0.0735      0.136      0.541      0.589      -0.194       0.342
# MFQ_SR_NegEmotion     0.1549      0.154      1.004      0.317      -0.149       0.459
# female                0.5913      0.575      1.029      0.305      -0.542       1.724
# meanFD               -3.1000      1.708     -1.815      0.071      -6.466       0.266
# ==============================================================================
# Omnibus:                        4.673   Durbin-Watson:                   1.767
# Prob(Omnibus):                  0.097   Jarque-Bera (JB):                6.342
# Skew:                          -0.012   Prob(JB):                       0.0420
# Kurtosis:                       3.841   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak5_mean   R-squared:                       0.004
# Model:                            WLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                    0.2053
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.935
# Time:                        21:09:22   Log-Likelihood:                -647.26
# No. Observations:                 215   AIC:                             1305.
# Df Residuals:                     210   BIC:                             1321.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             2.6076      2.187      1.192      0.235      -1.704       6.919
# age                   0.1485      0.172      0.865      0.388      -0.190       0.487
# MFQ_SR_NegEmotion    -0.0477      0.195     -0.245      0.807      -0.432       0.336
# female                0.0745      0.725      0.103      0.918      -1.355       1.505
# meanFD               -0.0586      2.155     -0.027      0.978      -4.307       4.190
# ==============================================================================
# Omnibus:                        4.169   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.124   Jarque-Bera (JB):                4.044
# Skew:                           0.336   Prob(JB):                        0.132
# Kurtosis:                       3.007   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak6_mean   R-squared:                       0.058
# Model:                            WLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     3.244
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0131
# Time:                        21:09:22   Log-Likelihood:                -601.96
# No. Observations:                 215   AIC:                             1214.
# Df Residuals:                     210   BIC:                             1231.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             4.2737      1.772      2.412      0.017       0.781       7.766
# age                  -0.0261      0.139     -0.188      0.851      -0.300       0.248
# MFQ_SR_NegEmotion    -0.2191      0.158     -1.388      0.166      -0.530       0.092
# female                0.5336      0.588      0.908      0.365      -0.625       1.692
# meanFD               -5.0039      1.746     -2.867      0.005      -8.445      -1.563
# ==============================================================================
# Omnibus:                       13.273   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.589
# Skew:                          -0.459   Prob(JB):                     0.000250
# Kurtosis:                       4.004   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak7_mean   R-squared:                       0.049
# Model:                            WLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     2.713
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0310
# Time:                        21:09:22   Log-Likelihood:                -629.27
# No. Observations:                 215   AIC:                             1269.
# Df Residuals:                     210   BIC:                             1285.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             4.3230      2.012      2.149      0.033       0.357       8.289
# age                  -0.0700      0.158     -0.443      0.658      -0.381       0.241
# MFQ_SR_NegEmotion     0.2093      0.179      1.168      0.244      -0.144       0.563
# female                0.4919      0.667      0.737      0.462      -0.823       1.807
# meanFD               -5.7848      1.982     -2.919      0.004      -9.692      -1.878
# ==============================================================================
# Omnibus:                       11.864   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.353
# Skew:                          -0.522   Prob(JB):                      0.00208
# Kurtosis:                       3.536   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak8_mean   R-squared:                       0.068
# Model:                            WLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     3.849
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):            0.00485
# Time:                        21:09:22   Log-Likelihood:                -609.97
# No. Observations:                 215   AIC:                             1230.
# Df Residuals:                     210   BIC:                             1247.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             4.3813      1.839      2.382      0.018       0.756       8.006
# age                  -0.0809      0.144     -0.560      0.576      -0.365       0.204
# MFQ_SR_NegEmotion     0.1563      0.164      0.954      0.341      -0.167       0.479
# female               -0.5830      0.610     -0.956      0.340      -1.785       0.619
# meanFD               -7.0384      1.812     -3.885      0.000     -10.610      -3.467
# ==============================================================================
# Omnibus:                        0.497   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.780   Jarque-Bera (JB):                0.632
# Skew:                          -0.045   Prob(JB):                        0.729
# Kurtosis:                       2.750   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak9_mean   R-squared:                       0.010
# Model:                            WLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.5433
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.704
# Time:                        21:09:22   Log-Likelihood:                -639.40
# No. Observations:                 215   AIC:                             1289.
# Df Residuals:                     210   BIC:                             1306.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             3.4092      2.109      1.617      0.107      -0.748       7.566
# age                  -0.1301      0.165     -0.787      0.432      -0.456       0.196
# MFQ_SR_NegEmotion    -0.0594      0.188     -0.316      0.752      -0.430       0.311
# female                0.7441      0.699      1.064      0.289      -0.635       2.123
# meanFD                0.7867      2.078      0.379      0.705      -3.309       4.882
# ==============================================================================
# Omnibus:                        0.752   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.687   Jarque-Bera (JB):                0.462
# Skew:                          -0.066   Prob(JB):                        0.794
# Kurtosis:                       3.185   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Default Mode
#weighted least squares regression model - movie DM (Discovery) - Depression
for x in range(1,10):
    res = smf.wls("Default_peak{0}_mean ~ age + MFQ_SR_NegEmotion + female + meanFD".format(x), 
                  data = data_dm_factor.loc[data_dm_factor['site'] == "cbic",:]).fit()
    results.loc[ind, 'dataset'] = 'discovery'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'Default'
    print(res.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak1_mean   R-squared:                       0.028
# Model:                            WLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.179
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.322
# Time:                        21:15:01   Log-Likelihood:                -514.92
# No. Observations:                 170   AIC:                             1040.
# Df Residuals:                     165   BIC:                             1056.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             8.0986      2.199      3.684      0.000       3.758      12.439
# age                  -0.2558      0.158     -1.620      0.107      -0.567       0.056
# MFQ_SR_NegEmotion     0.2038      0.251      0.813      0.417      -0.291       0.698
# female                0.7696      0.788      0.977      0.330      -0.786       2.325
# meanFD               -2.1682      2.407     -0.901      0.369      -6.921       2.585
# ==============================================================================
# Omnibus:                       12.085   Durbin-Watson:                   1.702
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               12.972
# Skew:                          -0.569   Prob(JB):                      0.00152
# Kurtosis:                       3.733   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak2_mean   R-squared:                       0.036
# Model:                            WLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     1.524
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.198
# Time:                        21:15:01   Log-Likelihood:                -511.30
# No. Observations:                 170   AIC:                             1033.
# Df Residuals:                     165   BIC:                             1048.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             4.0677      2.152      1.890      0.061      -0.182       8.317
# age                  -0.0542      0.155     -0.351      0.726      -0.359       0.251
# MFQ_SR_NegEmotion     0.5534      0.245      2.256      0.025       0.069       1.038
# female               -0.6864      0.771     -0.890      0.375      -2.209       0.837
# meanFD               -1.6418      2.357     -0.697      0.487      -6.295       3.011
# ==============================================================================
# Omnibus:                        1.497   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.473   Jarque-Bera (JB):                1.099
# Skew:                           0.146   Prob(JB):                        0.577
# Kurtosis:                       3.265   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak3_mean   R-squared:                       0.042
# Model:                            WLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     1.821
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.127
# Time:                        21:15:01   Log-Likelihood:                -477.11
# No. Observations:                 170   AIC:                             964.2
# Df Residuals:                     165   BIC:                             979.9
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             4.3721      1.760      2.484      0.014       0.897       7.847
# age                  -0.0193      0.126     -0.153      0.879      -0.269       0.230
# MFQ_SR_NegEmotion     0.3087      0.201      1.539      0.126      -0.087       0.705
# female                1.0770      0.631      1.707      0.090      -0.169       2.322
# meanFD               -2.8031      1.927     -1.454      0.148      -6.608       1.002
# ==============================================================================
# Omnibus:                        0.827   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.661   Jarque-Bera (JB):                0.947
# Skew:                          -0.122   Prob(JB):                        0.623
# Kurtosis:                       2.728   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak4_mean   R-squared:                       0.075
# Model:                            WLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     3.328
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0119
# Time:                        21:15:01   Log-Likelihood:                -461.43
# No. Observations:                 170   AIC:                             932.9
# Df Residuals:                     165   BIC:                             948.5
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.5634      1.605      0.351      0.726      -2.606       3.732
# age                   0.1977      0.115      1.716      0.088      -0.030       0.425
# MFQ_SR_NegEmotion     0.4733      0.183      2.588      0.011       0.112       0.834
# female                0.6138      0.575      1.067      0.288      -0.522       1.750
# meanFD               -2.1201      1.757     -1.206      0.229      -5.590       1.350
# ==============================================================================
# Omnibus:                        1.279   Durbin-Watson:                   1.818
# Prob(Omnibus):                  0.528   Jarque-Bera (JB):                0.897
# Skew:                          -0.087   Prob(JB):                        0.639
# Kurtosis:                       3.310   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak5_mean   R-squared:                       0.010
# Model:                            WLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.4240
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.791
# Time:                        21:15:01   Log-Likelihood:                -509.58
# No. Observations:                 170   AIC:                             1029.
# Df Residuals:                     165   BIC:                             1045.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             1.9171      2.130      0.900      0.370      -2.289       6.124
# age                  -0.0471      0.153     -0.308      0.758      -0.349       0.255
# MFQ_SR_NegEmotion     0.2754      0.243      1.134      0.258      -0.204       0.755
# female               -0.2274      0.764     -0.298      0.766      -1.735       1.280
# meanFD                1.2263      2.333      0.526      0.600      -3.380       5.832
# ==============================================================================
# Omnibus:                        0.416   Durbin-Watson:                   2.143
# Prob(Omnibus):                  0.812   Jarque-Bera (JB):                0.221
# Skew:                           0.079   Prob(JB):                        0.895
# Kurtosis:                       3.081   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak6_mean   R-squared:                       0.089
# Model:                            WLS   Adj. R-squared:                  0.067
# Method:                 Least Squares   F-statistic:                     4.043
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):            0.00373
# Time:                        21:15:01   Log-Likelihood:                -483.33
# No. Observations:                 170   AIC:                             976.7
# Df Residuals:                     165   BIC:                             992.3
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             6.9376      1.826      3.800      0.000       3.333      10.542
# age                  -0.1294      0.131     -0.987      0.325      -0.388       0.129
# MFQ_SR_NegEmotion    -0.2738      0.208     -1.316      0.190      -0.685       0.137
# female                1.7093      0.654      2.612      0.010       0.417       3.001
# meanFD               -5.3472      1.999     -2.675      0.008      -9.294      -1.400
# ==============================================================================
# Omnibus:                        5.139   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.077   Jarque-Bera (JB):                4.691
# Skew:                          -0.376   Prob(JB):                       0.0958
# Kurtosis:                       3.312   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak7_mean   R-squared:                       0.067
# Model:                            WLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     2.956
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0216
# Time:                        21:15:01   Log-Likelihood:                -525.52
# No. Observations:                 170   AIC:                             1061.
# Df Residuals:                     165   BIC:                             1077.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             8.6791      2.340      3.709      0.000       4.059      13.299
# age                  -0.5554      0.168     -3.306      0.001      -0.887      -0.224
# MFQ_SR_NegEmotion    -0.0949      0.267     -0.356      0.723      -0.621       0.432
# female               -0.3808      0.839     -0.454      0.650      -2.037       1.275
# meanFD                0.9904      2.562      0.387      0.700      -4.069       6.049
# ==============================================================================
# Omnibus:                        0.060   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.971   Jarque-Bera (JB):                0.108
# Skew:                          -0.044   Prob(JB):                        0.947
# Kurtosis:                       2.914   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak8_mean   R-squared:                       0.075
# Model:                            WLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     3.327
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0119
# Time:                        21:15:01   Log-Likelihood:                -485.63
# No. Observations:                 170   AIC:                             981.3
# Df Residuals:                     165   BIC:                             996.9
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             4.7114      1.851      2.546      0.012       1.058       8.365
# age                  -0.2927      0.133     -2.203      0.029      -0.555      -0.030
# MFQ_SR_NegEmotion    -0.3620      0.211     -1.716      0.088      -0.778       0.054
# female                1.4312      0.663      2.158      0.032       0.122       2.741
# meanFD                1.2417      2.026      0.613      0.541      -2.759       5.243
# ==============================================================================
# Omnibus:                        5.743   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.057   Jarque-Bera (JB):                6.362
# Skew:                          -0.266   Prob(JB):                       0.0415
# Kurtosis:                       3.785   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak9_mean   R-squared:                       0.022
# Model:                            WLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.9239
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.452
# Time:                        21:15:01   Log-Likelihood:                -494.72
# No. Observations:                 170   AIC:                             999.4
# Df Residuals:                     165   BIC:                             1015.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -1.1977      1.952     -0.614      0.540      -5.052       2.657
# age                   0.1872      0.140      1.336      0.183      -0.089       0.464
# MFQ_SR_NegEmotion    -0.0075      0.222     -0.034      0.973      -0.447       0.432
# female                0.5963      0.700      0.852      0.395      -0.785       1.978
# meanFD                2.2131      2.138      1.035      0.302      -2.007       6.434
# ==============================================================================
# Omnibus:                        0.409   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.815   Jarque-Bera (JB):                0.560
# Skew:                          -0.056   Prob(JB):                        0.756
# Kurtosis:                       2.742   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## ACTIVATION - Self Reported DEPRESSION (FACTOR)

# %%
#Ventral Attn
#weighted least squares regression model - movie DM (Discovery)- Depression 
for x in range(1,13):
    res = smf.wls("VentralAttn_peak{0}_mean ~ age + MFQ_SR_NegEmotion + female + meanFD".format(x), 
                  data = data_dm_factor.loc[data_dm_factor['site'] == "rubic",:]).fit()
    results.loc[ind, 'dataset'] = 'discovery'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'VentralAttn'
    print(res.summary())
# Out:
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak1_mean   R-squared:                       0.035
# Model:                                WLS   Adj. R-squared:                  0.016
# Method:                     Least Squares   F-statistic:                     1.886
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.114
# Time:                            21:15:06   Log-Likelihood:                -717.29
# No. Observations:                     215   AIC:                             1445.
# Df Residuals:                         210   BIC:                             1461.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            11.0877      3.029      3.660      0.000       5.116      17.060
# age                   0.1222      0.238      0.514      0.608      -0.346       0.591
# MFQ_SR_NegEmotion     0.1717      0.270      0.636      0.525      -0.360       0.704
# female               -1.3283      1.005     -1.322      0.188      -3.309       0.652
# meanFD               -6.9472      2.985     -2.328      0.021     -12.831      -1.063
# ==============================================================================
# Omnibus:                        1.139   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.566   Jarque-Bera (JB):                0.997
# Skew:                          -0.166   Prob(JB):                        0.608
# Kurtosis:                       3.025   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak2_mean   R-squared:                       0.069
# Model:                                WLS   Adj. R-squared:                  0.051
# Method:                     Least Squares   F-statistic:                     3.888
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):            0.00455
# Time:                            21:15:06   Log-Likelihood:                -603.56
# No. Observations:                     215   AIC:                             1217.
# Df Residuals:                         210   BIC:                             1234.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             9.8874      1.785      5.539      0.000       6.369      13.406
# age                  -0.2202      0.140     -1.573      0.117      -0.496       0.056
# MFQ_SR_NegEmotion    -0.0437      0.159     -0.275      0.784      -0.357       0.270
# female               -1.3072      0.592     -2.208      0.028      -2.474      -0.140
# meanFD               -5.8574      1.759     -3.331      0.001      -9.324      -2.391
# ==============================================================================
# Omnibus:                        0.276   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.871   Jarque-Bera (JB):                0.261
# Skew:                           0.083   Prob(JB):                        0.878
# Kurtosis:                       2.962   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak3_mean   R-squared:                       0.073
# Model:                                WLS   Adj. R-squared:                  0.055
# Method:                     Least Squares   F-statistic:                     4.127
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):            0.00306
# Time:                            21:15:06   Log-Likelihood:                -641.07
# No. Observations:                     215   AIC:                             1292.
# Df Residuals:                         210   BIC:                             1309.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            10.9597      2.125      5.157      0.000       6.770      15.149
# age                  -0.2455      0.167     -1.473      0.142      -0.574       0.083
# MFQ_SR_NegEmotion     0.1114      0.189      0.589      0.557      -0.262       0.485
# female               -1.3191      0.705     -1.871      0.063      -2.709       0.070
# meanFD               -7.9651      2.094     -3.804      0.000     -12.093      -3.837
# ==============================================================================
# Omnibus:                        4.740   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.093   Jarque-Bera (JB):                5.464
# Skew:                          -0.167   Prob(JB):                       0.0651
# Kurtosis:                       3.706   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak4_mean   R-squared:                       0.052
# Model:                                WLS   Adj. R-squared:                  0.034
# Method:                     Least Squares   F-statistic:                     2.876
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0239
# Time:                            21:15:06   Log-Likelihood:                -717.33
# No. Observations:                     215   AIC:                             1445.
# Df Residuals:                         210   BIC:                             1462.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            10.2324      3.030      3.377      0.001       4.259      16.205
# age                  -0.0260      0.238     -0.110      0.913      -0.495       0.443
# MFQ_SR_NegEmotion    -0.0443      0.270     -0.164      0.870      -0.576       0.488
# female                1.1113      1.005      1.106      0.270      -0.870       3.092
# meanFD               -8.7843      2.985     -2.943      0.004     -14.669      -2.900
# ==============================================================================
# Omnibus:                        0.414   Durbin-Watson:                   1.877
# Prob(Omnibus):                  0.813   Jarque-Bera (JB):                0.525
# Skew:                          -0.094   Prob(JB):                        0.769
# Kurtosis:                       2.848   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak5_mean   R-squared:                       0.020
# Model:                                WLS   Adj. R-squared:                  0.002
# Method:                     Least Squares   F-statistic:                     1.085
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.365
# Time:                            21:15:06   Log-Likelihood:                -689.00
# No. Observations:                     215   AIC:                             1388.
# Df Residuals:                         210   BIC:                             1405.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             3.3265      2.656      1.252      0.212      -1.909       8.562
# age                   0.1270      0.208      0.609      0.543      -0.284       0.538
# MFQ_SR_NegEmotion     0.1130      0.237      0.478      0.633      -0.353       0.579
# female               -1.5959      0.881     -1.812      0.071      -3.332       0.141
# meanFD                0.7714      2.617      0.295      0.768      -4.387       5.930
# ==============================================================================
# Omnibus:                        5.822   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.054   Jarque-Bera (JB):                8.653
# Skew:                          -0.064   Prob(JB):                       0.0132
# Kurtosis:                       3.974   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak6_mean   R-squared:                       0.052
# Model:                                WLS   Adj. R-squared:                  0.034
# Method:                     Least Squares   F-statistic:                     2.881
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0237
# Time:                            21:15:06   Log-Likelihood:                -649.76
# No. Observations:                     215   AIC:                             1310.
# Df Residuals:                         210   BIC:                             1326.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             7.5712      2.213      3.422      0.001       3.209      11.933
# age                  -0.2087      0.174     -1.203      0.231      -0.551       0.133
# MFQ_SR_NegEmotion     0.1800      0.197      0.913      0.362      -0.209       0.569
# female               -0.5979      0.734     -0.815      0.416      -2.045       0.849
# meanFD               -7.2236      2.180     -3.313      0.001     -11.521      -2.926
# ==============================================================================
# Omnibus:                        3.536   Durbin-Watson:                   2.072
# Prob(Omnibus):                  0.171   Jarque-Bera (JB):                3.348
# Skew:                          -0.305   Prob(JB):                        0.188
# Kurtosis:                       3.038   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak7_mean   R-squared:                       0.085
# Model:                                WLS   Adj. R-squared:                  0.067
# Method:                     Least Squares   F-statistic:                     4.872
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):           0.000891
# Time:                            21:15:06   Log-Likelihood:                -673.00
# No. Observations:                     215   AIC:                             1356.
# Df Residuals:                         210   BIC:                             1373.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -3.0230      2.465     -1.226      0.222      -7.883       1.837
# age                   0.7049      0.193      3.645      0.000       0.324       1.086
# MFQ_SR_NegEmotion    -0.2529      0.220     -1.151      0.251      -0.686       0.180
# female                1.5979      0.818      1.954      0.052      -0.014       3.210
# meanFD               -2.0269      2.429     -0.834      0.405      -6.815       2.762
# ==============================================================================
# Omnibus:                        3.577   Durbin-Watson:                   1.908
# Prob(Omnibus):                  0.167   Jarque-Bera (JB):                4.033
# Skew:                          -0.091   Prob(JB):                        0.133
# Kurtosis:                       3.646   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak8_mean   R-squared:                       0.017
# Model:                                WLS   Adj. R-squared:                 -0.001
# Method:                     Least Squares   F-statistic:                    0.9286
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.448
# Time:                            21:15:06   Log-Likelihood:                -666.06
# No. Observations:                     215   AIC:                             1342.
# Df Residuals:                         210   BIC:                             1359.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             6.9526      2.387      2.913      0.004       2.247      11.658
# age                  -0.3559      0.187     -1.900      0.059      -0.725       0.013
# MFQ_SR_NegEmotion     0.0860      0.213      0.405      0.686      -0.333       0.505
# female               -0.0351      0.792     -0.044      0.965      -1.596       1.526
# meanFD               -1.0597      2.352     -0.451      0.653      -5.696       3.576
# ==============================================================================
# Omnibus:                        0.198   Durbin-Watson:                   1.856
# Prob(Omnibus):                  0.906   Jarque-Bera (JB):                0.096
# Skew:                          -0.050   Prob(JB):                        0.953
# Kurtosis:                       3.029   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak9_mean   R-squared:                       0.041
# Model:                                WLS   Adj. R-squared:                  0.023
# Method:                     Least Squares   F-statistic:                     2.232
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0668
# Time:                            21:15:06   Log-Likelihood:                -723.58
# No. Observations:                     215   AIC:                             1457.
# Df Residuals:                         210   BIC:                             1474.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             1.2142      3.119      0.389      0.697      -4.935       7.364
# age                   0.3551      0.245      1.451      0.148      -0.127       0.837
# MFQ_SR_NegEmotion     0.3435      0.278      1.236      0.218      -0.204       0.891
# female               -0.4978      1.035     -0.481      0.631      -2.537       1.542
# meanFD               -6.2724      3.073     -2.041      0.043     -12.331      -0.214
# ==============================================================================
# Omnibus:                        1.921   Durbin-Watson:                   2.098
# Prob(Omnibus):                  0.383   Jarque-Bera (JB):                1.742
# Skew:                          -0.015   Prob(JB):                        0.419
# Kurtosis:                       3.440   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak10_mean   R-squared:                       0.024
# Model:                                 WLS   Adj. R-squared:                  0.005
# Method:                      Least Squares   F-statistic:                     1.281
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.278
# Time:                             21:15:06   Log-Likelihood:                -716.64
# No. Observations:                      215   AIC:                             1443.
# Df Residuals:                          210   BIC:                             1460.
# Df Model:                                4
# Covariance Type:                 nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             3.4464      3.020      1.141      0.255      -2.507       9.400
# age                   0.1648      0.237      0.696      0.487      -0.302       0.632
# MFQ_SR_NegEmotion     0.0432      0.269      0.161      0.873      -0.487       0.574
# female                0.1564      1.002      0.156      0.876      -1.818       2.131
# meanFD               -5.8035      2.976     -1.950      0.052     -11.669       0.062
# ==============================================================================
# Omnibus:                        0.594   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.743   Jarque-Bera (JB):                0.447
# Skew:                           0.109   Prob(JB):                        0.800
# Kurtosis:                       3.047   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak11_mean   R-squared:                       0.046
# Model:                                 WLS   Adj. R-squared:                  0.028
# Method:                      Least Squares   F-statistic:                     2.515
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):             0.0427
# Time:                             21:15:06   Log-Likelihood:                -697.22
# No. Observations:                      215   AIC:                             1404.
# Df Residuals:                          210   BIC:                             1421.
# Df Model:                                4
# Covariance Type:                 nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             5.5646      2.759      2.017      0.045       0.125      11.004
# age                  -0.1577      0.216     -0.729      0.467      -0.584       0.269
# MFQ_SR_NegEmotion     0.1371      0.246      0.558      0.578      -0.347       0.622
# female                1.2676      0.915      1.385      0.167      -0.537       3.072
# meanFD               -6.8815      2.719     -2.531      0.012     -12.241      -1.522
# ==============================================================================
# Omnibus:                        4.072   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.131   Jarque-Bera (JB):                4.535
# Skew:                          -0.142   Prob(JB):                        0.104
# Kurtosis:                       3.652   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak12_mean   R-squared:                       0.027
# Model:                                 WLS   Adj. R-squared:                  0.009
# Method:                      Least Squares   F-statistic:                     1.483
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.209
# Time:                             21:15:06   Log-Likelihood:                -708.76
# No. Observations:                      215   AIC:                             1428.
# Df Residuals:                          210   BIC:                             1444.
# Df Model:                                4
# Covariance Type:                 nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             4.6115      2.912      1.584      0.115      -1.128      10.351
# age                   0.0367      0.228      0.160      0.873      -0.414       0.487
# MFQ_SR_NegEmotion     0.0623      0.259      0.240      0.810      -0.449       0.574
# female                0.9415      0.966      0.975      0.331      -0.962       2.845
# meanFD               -5.7298      2.869     -1.997      0.047     -11.385      -0.075
# ==============================================================================
# Omnibus:                        6.043   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.049   Jarque-Bera (JB):                7.258
# Skew:                           0.217   Prob(JB):                       0.0265
# Kurtosis:                       3.789   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Ventral Attn
#weighted least squares regression model - movie DM (Discovery)- Depression 
for x in range(1,13):
    res = smf.wls("VentralAttn_peak{0}_mean ~ age + MFQ_SR_NegEmotion + female + meanFD".format(x), 
                  data = data_dm_factor.loc[data_dm_factor['site'] == "cbic",:]).fit()
    results.loc[ind, 'dataset'] = 'discovery'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'VentralAttn'
    print(res.summary())
# Out:
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak1_mean   R-squared:                       0.023
# Model:                                WLS   Adj. R-squared:                 -0.001
# Method:                     Least Squares   F-statistic:                    0.9673
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.427
# Time:                            21:15:07   Log-Likelihood:                -558.35
# No. Observations:                     170   AIC:                             1127.
# Df Residuals:                         165   BIC:                             1142.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             8.5252      2.838      3.004      0.003       2.921      14.129
# age                   0.1510      0.204      0.741      0.460      -0.251       0.553
# MFQ_SR_NegEmotion    -0.1851      0.323     -0.572      0.568      -0.824       0.454
# female                1.2918      1.017      1.270      0.206      -0.717       3.300
# meanFD               -3.9431      3.108     -1.269      0.206     -10.080       2.193
# ==============================================================================
# Omnibus:                       18.005   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.436
# Skew:                          -0.547   Prob(JB):                     2.46e-07
# Kurtosis:                       4.761   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak2_mean   R-squared:                       0.024
# Model:                                WLS   Adj. R-squared:                  0.001
# Method:                     Least Squares   F-statistic:                     1.031
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.393
# Time:                            21:15:07   Log-Likelihood:                -506.26
# No. Observations:                     170   AIC:                             1023.
# Df Residuals:                         165   BIC:                             1038.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             8.9117      2.089      4.265      0.000       4.786      13.037
# age                  -0.0088      0.150     -0.058      0.954      -0.305       0.287
# MFQ_SR_NegEmotion     0.0657      0.238      0.276      0.783      -0.404       0.536
# female                0.0294      0.749      0.039      0.969      -1.449       1.508
# meanFD               -4.6241      2.288     -2.021      0.045      -9.141      -0.107
# ==============================================================================
# Omnibus:                        1.778   Durbin-Watson:                   1.943
# Prob(Omnibus):                  0.411   Jarque-Bera (JB):                1.375
# Skew:                          -0.139   Prob(JB):                        0.503
# Kurtosis:                       3.342   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak3_mean   R-squared:                       0.048
# Model:                                WLS   Adj. R-squared:                  0.025
# Method:                     Least Squares   F-statistic:                     2.072
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0867
# Time:                            21:15:07   Log-Likelihood:                -532.44
# No. Observations:                     170   AIC:                             1075.
# Df Residuals:                         165   BIC:                             1091.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            13.7297      2.437      5.634      0.000       8.918      18.542
# age                  -0.4252      0.175     -2.430      0.016      -0.771      -0.080
# MFQ_SR_NegEmotion     0.1668      0.278      0.601      0.549      -0.382       0.715
# female               -0.1435      0.873     -0.164      0.870      -1.868       1.581
# meanFD               -4.0688      2.669     -1.525      0.129      -9.338       1.200
# ==============================================================================
# Omnibus:                        6.122   Durbin-Watson:                   1.865
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                5.742
# Skew:                          -0.397   Prob(JB):                       0.0566
# Kurtosis:                       3.426   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak4_mean   R-squared:                       0.034
# Model:                                WLS   Adj. R-squared:                  0.011
# Method:                     Least Squares   F-statistic:                     1.467
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.215
# Time:                            21:15:07   Log-Likelihood:                -581.92
# No. Observations:                     170   AIC:                             1174.
# Df Residuals:                         165   BIC:                             1190.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             9.2177      3.260      2.827      0.005       2.780      15.655
# age                  -0.2831      0.234     -1.209      0.228      -0.745       0.179
# MFQ_SR_NegEmotion    -0.1554      0.372     -0.418      0.676      -0.889       0.578
# female                2.4006      1.169      2.054      0.042       0.093       4.708
# meanFD               -0.6838      3.570     -0.192      0.848      -7.733       6.365
# ==============================================================================
# Omnibus:                        4.385   Durbin-Watson:                   2.129
# Prob(Omnibus):                  0.112   Jarque-Bera (JB):                3.964
# Skew:                          -0.358   Prob(JB):                        0.138
# Kurtosis:                       3.218   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak5_mean   R-squared:                       0.051
# Model:                                WLS   Adj. R-squared:                  0.028
# Method:                     Least Squares   F-statistic:                     2.199
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):             0.0713
# Time:                            21:15:07   Log-Likelihood:                -561.12
# No. Observations:                     170   AIC:                             1132.
# Df Residuals:                         165   BIC:                             1148.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            11.1690      2.885      3.871      0.000       5.473      16.865
# age                  -0.2252      0.207     -1.088      0.278      -0.634       0.184
# MFQ_SR_NegEmotion    -0.6645      0.329     -2.021      0.045      -1.314      -0.015
# female               -1.5996      1.034     -1.547      0.124      -3.641       0.442
# meanFD               -0.8289      3.159     -0.262      0.793      -7.066       5.408
# ==============================================================================
# Omnibus:                        0.843   Durbin-Watson:                   1.918
# Prob(Omnibus):                  0.656   Jarque-Bera (JB):                0.519
# Skew:                          -0.098   Prob(JB):                        0.771
# Kurtosis:                       3.187   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak6_mean   R-squared:                       0.008
# Model:                                WLS   Adj. R-squared:                 -0.016
# Method:                     Least Squares   F-statistic:                    0.3431
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.849
# Time:                            21:15:07   Log-Likelihood:                -524.80
# No. Observations:                     170   AIC:                             1060.
# Df Residuals:                         165   BIC:                             1075.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             6.0521      2.330      2.597      0.010       1.452      10.653
# age                   0.0746      0.167      0.446      0.656      -0.256       0.405
# MFQ_SR_NegEmotion     0.0674      0.266      0.254      0.800      -0.457       0.592
# female               -0.2731      0.835     -0.327      0.744      -1.922       1.376
# meanFD               -2.5077      2.551     -0.983      0.327      -7.545       2.530
# ==============================================================================
# Omnibus:                       11.043   Durbin-Watson:                   1.941
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.516
# Skew:                          -0.549   Prob(JB):                      0.00316
# Kurtosis:                       3.650   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak7_mean   R-squared:                       0.002
# Model:                                WLS   Adj. R-squared:                 -0.022
# Method:                     Least Squares   F-statistic:                   0.07110
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.991
# Time:                            21:15:07   Log-Likelihood:                -548.30
# No. Observations:                     170   AIC:                             1107.
# Df Residuals:                         165   BIC:                             1122.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             5.8235      2.675      2.177      0.031       0.541      11.106
# age                  -0.0698      0.192     -0.364      0.717      -0.449       0.309
# MFQ_SR_NegEmotion     0.0358      0.305      0.118      0.907      -0.566       0.638
# female                0.3308      0.959      0.345      0.731      -1.563       2.224
# meanFD                0.3772      2.930      0.129      0.898      -5.407       6.162
# ==============================================================================
# Omnibus:                        4.737   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.094   Jarque-Bera (JB):                4.257
# Skew:                          -0.313   Prob(JB):                        0.119
# Kurtosis:                       2.543   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak8_mean   R-squared:                       0.029
# Model:                                WLS   Adj. R-squared:                  0.005
# Method:                     Least Squares   F-statistic:                     1.232
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.299
# Time:                            21:15:07   Log-Likelihood:                -506.23
# No. Observations:                     170   AIC:                             1022.
# Df Residuals:                         165   BIC:                             1038.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             6.6743      2.089      3.195      0.002       2.550      10.799
# age                  -0.1104      0.150     -0.736      0.463      -0.406       0.186
# MFQ_SR_NegEmotion     0.0501      0.238      0.211      0.833      -0.420       0.520
# female                0.8731      0.749      1.166      0.245      -0.605       2.351
# meanFD               -4.1155      2.287     -1.799      0.074      -8.632       0.401
# ==============================================================================
# Omnibus:                        1.464   Durbin-Watson:                   1.830
# Prob(Omnibus):                  0.481   Jarque-Bera (JB):                1.504
# Skew:                          -0.218   Prob(JB):                        0.471
# Kurtosis:                       2.852   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_peak9_mean   R-squared:                       0.044
# Model:                                WLS   Adj. R-squared:                  0.021
# Method:                     Least Squares   F-statistic:                     1.894
# Date:                    Tue, 30 Aug 2022   Prob (F-statistic):              0.114
# Time:                            21:15:07   Log-Likelihood:                -565.34
# No. Observations:                     170   AIC:                             1141.
# Df Residuals:                         165   BIC:                             1156.
# Df Model:                               4
# Covariance Type:                nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             7.2640      2.957      2.456      0.015       1.425      13.103
# age                  -0.0274      0.212     -0.129      0.897      -0.447       0.392
# MFQ_SR_NegEmotion     0.5085      0.337      1.509      0.133      -0.157       1.174
# female                0.4859      1.060      0.458      0.647      -1.607       2.579
# meanFD               -7.5263      3.238     -2.324      0.021     -13.920      -1.132
# ==============================================================================
# Omnibus:                        0.793   Durbin-Watson:                   2.148
# Prob(Omnibus):                  0.673   Jarque-Bera (JB):                0.919
# Skew:                          -0.130   Prob(JB):                        0.632
# Kurtosis:                       2.751   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak10_mean   R-squared:                       0.007
# Model:                                 WLS   Adj. R-squared:                 -0.017
# Method:                      Least Squares   F-statistic:                    0.3033
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.875
# Time:                             21:15:07   Log-Likelihood:                -586.97
# No. Observations:                      170   AIC:                             1184.
# Df Residuals:                          165   BIC:                             1200.
# Df Model:                                4
# Covariance Type:                 nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             6.8011      3.359      2.025      0.044       0.169      13.433
# age                  -0.1061      0.241     -0.440      0.661      -0.582       0.370
# MFQ_SR_NegEmotion     0.3329      0.383      0.870      0.386      -0.423       1.089
# female               -0.0384      1.204     -0.032      0.975      -2.415       2.339
# meanFD               -2.2687      3.678     -0.617      0.538      -9.531       4.993
# ==============================================================================
# Omnibus:                        5.201   Durbin-Watson:                   1.662
# Prob(Omnibus):                  0.074   Jarque-Bera (JB):                2.871
# Skew:                          -0.010   Prob(JB):                        0.238
# Kurtosis:                       2.364   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak11_mean   R-squared:                       0.026
# Model:                                 WLS   Adj. R-squared:                  0.002
# Method:                      Least Squares   F-statistic:                     1.095
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.361
# Time:                             21:15:07   Log-Likelihood:                -559.61
# No. Observations:                      170   AIC:                             1129.
# Df Residuals:                          165   BIC:                             1145.
# Df Model:                                4
# Covariance Type:                 nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            10.4789      2.860      3.664      0.000       4.833      16.125
# age                  -0.2530      0.205     -1.232      0.220      -0.658       0.152
# MFQ_SR_NegEmotion    -0.0135      0.326     -0.041      0.967      -0.657       0.630
# female               -0.8259      1.025     -0.806      0.421      -2.850       1.198
# meanFD               -4.4692      3.131     -1.427      0.155     -10.652       1.713
# ==============================================================================
# Omnibus:                        3.764   Durbin-Watson:                   2.055
# Prob(Omnibus):                  0.152   Jarque-Bera (JB):                3.298
# Skew:                          -0.311   Prob(JB):                        0.192
# Kurtosis:                       3.281   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     VentralAttn_peak12_mean   R-squared:                       0.010
# Model:                                 WLS   Adj. R-squared:                 -0.014
# Method:                      Least Squares   F-statistic:                    0.4307
# Date:                     Tue, 30 Aug 2022   Prob (F-statistic):              0.786
# Time:                             21:15:07   Log-Likelihood:                -593.72
# No. Observations:                      170   AIC:                             1197.
# Df Residuals:                          165   BIC:                             1213.
# Df Model:                                4
# Covariance Type:                 nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.7177      3.495      0.205      0.838      -6.183       7.618
# age                   0.2945      0.251      1.174      0.242      -0.201       0.790
# MFQ_SR_NegEmotion     0.0050      0.398      0.013      0.990      -0.781       0.791
# female                0.6127      1.253      0.489      0.625      -1.860       3.086
# meanFD               -1.1229      3.827     -0.293      0.770      -8.679       6.433
# ==============================================================================
# Omnibus:                        1.001   Durbin-Watson:                   1.864
# Prob(Omnibus):                  0.606   Jarque-Bera (JB):                0.637
# Skew:                           0.007   Prob(JB):                        0.727
# Kurtosis:                       3.300   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Default Mode
#weighted least squares regression model - movie DM (Discovery) - Depression
for x in range(1,10):
    res = smf.wls("Default_peak{0}_mean ~ age + MFQ_SR_NegEmotion + female + meanFD".format(x), 
                  data = data_dm_factor.loc[data_dm_factor['site'] == "rubic",:]).fit()
    results.loc[ind, 'dataset'] = 'discovery'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'Default'
    print(res.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak1_mean   R-squared:                       0.086
# Model:                            WLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     4.962
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):           0.000767
# Time:                        21:15:08   Log-Likelihood:                -599.05
# No. Observations:                 215   AIC:                             1208.
# Df Residuals:                     210   BIC:                             1225.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             7.4663      1.748      4.272      0.000       4.021      10.912
# age                  -0.0921      0.137     -0.672      0.502      -0.362       0.178
# MFQ_SR_NegEmotion     0.0376      0.156      0.241      0.810      -0.269       0.345
# female               -0.2831      0.580     -0.488      0.626      -1.426       0.860
# meanFD               -7.6323      1.722     -4.432      0.000     -11.027      -4.238
# ==============================================================================
# Omnibus:                        0.251   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.882   Jarque-Bera (JB):                0.381
# Skew:                          -0.062   Prob(JB):                        0.827
# Kurtosis:                       2.836   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak2_mean   R-squared:                       0.095
# Model:                            WLS   Adj. R-squared:                  0.077
# Method:                 Least Squares   F-statistic:                     5.493
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):           0.000318
# Time:                        21:15:08   Log-Likelihood:                -625.08
# No. Observations:                 215   AIC:                             1260.
# Df Residuals:                     210   BIC:                             1277.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            10.1027      1.973      5.121      0.000       6.213      13.992
# age                  -0.3839      0.155     -2.480      0.014      -0.689      -0.079
# MFQ_SR_NegEmotion    -0.2235      0.176     -1.272      0.205      -0.570       0.123
# female               -0.1276      0.654     -0.195      0.846      -1.417       1.162
# meanFD               -7.4612      1.944     -3.839      0.000     -11.293      -3.630
# ==============================================================================
# Omnibus:                        3.170   Durbin-Watson:                   1.856
# Prob(Omnibus):                  0.205   Jarque-Bera (JB):                3.239
# Skew:                          -0.282   Prob(JB):                        0.198
# Kurtosis:                       2.790   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak3_mean   R-squared:                       0.032
# Model:                            WLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     1.736
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.143
# Time:                        21:15:08   Log-Likelihood:                -626.79
# No. Observations:                 215   AIC:                             1264.
# Df Residuals:                     210   BIC:                             1280.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             5.4833      1.989      2.757      0.006       1.563       9.403
# age                  -0.1714      0.156     -1.099      0.273      -0.479       0.136
# MFQ_SR_NegEmotion    -0.1448      0.177     -0.817      0.415      -0.494       0.204
# female                0.8946      0.660      1.356      0.176      -0.406       2.195
# meanFD               -3.0511      1.959     -1.557      0.121      -6.913       0.811
# ==============================================================================
# Omnibus:                        0.382   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.826   Jarque-Bera (JB):                0.470
# Skew:                          -0.096   Prob(JB):                        0.790
# Kurtosis:                       2.874   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak4_mean   R-squared:                       0.031
# Model:                            WLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     1.655
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.162
# Time:                        21:15:08   Log-Likelihood:                -597.23
# No. Observations:                 215   AIC:                             1204.
# Df Residuals:                     210   BIC:                             1221.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             3.2566      1.733      1.879      0.062      -0.160       6.673
# age                   0.0735      0.136      0.541      0.589      -0.194       0.342
# MFQ_SR_NegEmotion     0.1549      0.154      1.004      0.317      -0.149       0.459
# female                0.5913      0.575      1.029      0.305      -0.542       1.724
# meanFD               -3.1000      1.708     -1.815      0.071      -6.466       0.266
# ==============================================================================
# Omnibus:                        4.673   Durbin-Watson:                   1.767
# Prob(Omnibus):                  0.097   Jarque-Bera (JB):                6.342
# Skew:                          -0.012   Prob(JB):                       0.0420
# Kurtosis:                       3.841   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak5_mean   R-squared:                       0.004
# Model:                            WLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                    0.2053
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.935
# Time:                        21:15:08   Log-Likelihood:                -647.26
# No. Observations:                 215   AIC:                             1305.
# Df Residuals:                     210   BIC:                             1321.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             2.6076      2.187      1.192      0.235      -1.704       6.919
# age                   0.1485      0.172      0.865      0.388      -0.190       0.487
# MFQ_SR_NegEmotion    -0.0477      0.195     -0.245      0.807      -0.432       0.336
# female                0.0745      0.725      0.103      0.918      -1.355       1.505
# meanFD               -0.0586      2.155     -0.027      0.978      -4.307       4.190
# ==============================================================================
# Omnibus:                        4.169   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.124   Jarque-Bera (JB):                4.044
# Skew:                           0.336   Prob(JB):                        0.132
# Kurtosis:                       3.007   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak6_mean   R-squared:                       0.058
# Model:                            WLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     3.244
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0131
# Time:                        21:15:08   Log-Likelihood:                -601.96
# No. Observations:                 215   AIC:                             1214.
# Df Residuals:                     210   BIC:                             1231.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             4.2737      1.772      2.412      0.017       0.781       7.766
# age                  -0.0261      0.139     -0.188      0.851      -0.300       0.248
# MFQ_SR_NegEmotion    -0.2191      0.158     -1.388      0.166      -0.530       0.092
# female                0.5336      0.588      0.908      0.365      -0.625       1.692
# meanFD               -5.0039      1.746     -2.867      0.005      -8.445      -1.563
# ==============================================================================
# Omnibus:                       13.273   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.589
# Skew:                          -0.459   Prob(JB):                     0.000250
# Kurtosis:                       4.004   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak7_mean   R-squared:                       0.049
# Model:                            WLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     2.713
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0310
# Time:                        21:15:08   Log-Likelihood:                -629.27
# No. Observations:                 215   AIC:                             1269.
# Df Residuals:                     210   BIC:                             1285.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             4.3230      2.012      2.149      0.033       0.357       8.289
# age                  -0.0700      0.158     -0.443      0.658      -0.381       0.241
# MFQ_SR_NegEmotion     0.2093      0.179      1.168      0.244      -0.144       0.563
# female                0.4919      0.667      0.737      0.462      -0.823       1.807
# meanFD               -5.7848      1.982     -2.919      0.004      -9.692      -1.878
# ==============================================================================
# Omnibus:                       11.864   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.353
# Skew:                          -0.522   Prob(JB):                      0.00208
# Kurtosis:                       3.536   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak8_mean   R-squared:                       0.068
# Model:                            WLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     3.849
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):            0.00485
# Time:                        21:15:08   Log-Likelihood:                -609.97
# No. Observations:                 215   AIC:                             1230.
# Df Residuals:                     210   BIC:                             1247.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             4.3813      1.839      2.382      0.018       0.756       8.006
# age                  -0.0809      0.144     -0.560      0.576      -0.365       0.204
# MFQ_SR_NegEmotion     0.1563      0.164      0.954      0.341      -0.167       0.479
# female               -0.5830      0.610     -0.956      0.340      -1.785       0.619
# meanFD               -7.0384      1.812     -3.885      0.000     -10.610      -3.467
# ==============================================================================
# Omnibus:                        0.497   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.780   Jarque-Bera (JB):                0.632
# Skew:                          -0.045   Prob(JB):                        0.729
# Kurtosis:                       2.750   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak9_mean   R-squared:                       0.010
# Model:                            WLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.5433
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.704
# Time:                        21:15:08   Log-Likelihood:                -639.40
# No. Observations:                 215   AIC:                             1289.
# Df Residuals:                     210   BIC:                             1306.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             3.4092      2.109      1.617      0.107      -0.748       7.566
# age                  -0.1301      0.165     -0.787      0.432      -0.456       0.196
# MFQ_SR_NegEmotion    -0.0594      0.188     -0.316      0.752      -0.430       0.311
# female                0.7441      0.699      1.064      0.289      -0.635       2.123
# meanFD                0.7867      2.078      0.379      0.705      -3.309       4.882
# ==============================================================================
# Omnibus:                        0.752   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.687   Jarque-Bera (JB):                0.462
# Skew:                          -0.066   Prob(JB):                        0.794
# Kurtosis:                       3.185   Cond. No.                         89.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Default Mode
#weighted least squares regression model - movie DM (Discovery) - Depression
for x in range(1,10):
    res = smf.wls("Default_peak{0}_mean ~ age + MFQ_SR_NegEmotion + female + meanFD".format(x), 
                  data = data_dm_factor.loc[data_dm_factor['site'] == "cbic",:]).fit()
    results.loc[ind, 'dataset'] = 'discovery'
    results.loc[ind, 'movie'] = 'DM'
    results.loc[ind, 'networkDV'] = 'Default'
    print(res.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak1_mean   R-squared:                       0.028
# Model:                            WLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.179
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.322
# Time:                        21:15:08   Log-Likelihood:                -514.92
# No. Observations:                 170   AIC:                             1040.
# Df Residuals:                     165   BIC:                             1056.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             8.0986      2.199      3.684      0.000       3.758      12.439
# age                  -0.2558      0.158     -1.620      0.107      -0.567       0.056
# MFQ_SR_NegEmotion     0.2038      0.251      0.813      0.417      -0.291       0.698
# female                0.7696      0.788      0.977      0.330      -0.786       2.325
# meanFD               -2.1682      2.407     -0.901      0.369      -6.921       2.585
# ==============================================================================
# Omnibus:                       12.085   Durbin-Watson:                   1.702
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               12.972
# Skew:                          -0.569   Prob(JB):                      0.00152
# Kurtosis:                       3.733   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak2_mean   R-squared:                       0.036
# Model:                            WLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     1.524
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.198
# Time:                        21:15:08   Log-Likelihood:                -511.30
# No. Observations:                 170   AIC:                             1033.
# Df Residuals:                     165   BIC:                             1048.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             4.0677      2.152      1.890      0.061      -0.182       8.317
# age                  -0.0542      0.155     -0.351      0.726      -0.359       0.251
# MFQ_SR_NegEmotion     0.5534      0.245      2.256      0.025       0.069       1.038
# female               -0.6864      0.771     -0.890      0.375      -2.209       0.837
# meanFD               -1.6418      2.357     -0.697      0.487      -6.295       3.011
# ==============================================================================
# Omnibus:                        1.497   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.473   Jarque-Bera (JB):                1.099
# Skew:                           0.146   Prob(JB):                        0.577
# Kurtosis:                       3.265   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak3_mean   R-squared:                       0.042
# Model:                            WLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     1.821
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.127
# Time:                        21:15:08   Log-Likelihood:                -477.11
# No. Observations:                 170   AIC:                             964.2
# Df Residuals:                     165   BIC:                             979.9
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             4.3721      1.760      2.484      0.014       0.897       7.847
# age                  -0.0193      0.126     -0.153      0.879      -0.269       0.230
# MFQ_SR_NegEmotion     0.3087      0.201      1.539      0.126      -0.087       0.705
# female                1.0770      0.631      1.707      0.090      -0.169       2.322
# meanFD               -2.8031      1.927     -1.454      0.148      -6.608       1.002
# ==============================================================================
# Omnibus:                        0.827   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.661   Jarque-Bera (JB):                0.947
# Skew:                          -0.122   Prob(JB):                        0.623
# Kurtosis:                       2.728   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak4_mean   R-squared:                       0.075
# Model:                            WLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     3.328
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0119
# Time:                        21:15:08   Log-Likelihood:                -461.43
# No. Observations:                 170   AIC:                             932.9
# Df Residuals:                     165   BIC:                             948.5
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.5634      1.605      0.351      0.726      -2.606       3.732
# age                   0.1977      0.115      1.716      0.088      -0.030       0.425
# MFQ_SR_NegEmotion     0.4733      0.183      2.588      0.011       0.112       0.834
# female                0.6138      0.575      1.067      0.288      -0.522       1.750
# meanFD               -2.1201      1.757     -1.206      0.229      -5.590       1.350
# ==============================================================================
# Omnibus:                        1.279   Durbin-Watson:                   1.818
# Prob(Omnibus):                  0.528   Jarque-Bera (JB):                0.897
# Skew:                          -0.087   Prob(JB):                        0.639
# Kurtosis:                       3.310   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak5_mean   R-squared:                       0.010
# Model:                            WLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.4240
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.791
# Time:                        21:15:08   Log-Likelihood:                -509.58
# No. Observations:                 170   AIC:                             1029.
# Df Residuals:                     165   BIC:                             1045.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             1.9171      2.130      0.900      0.370      -2.289       6.124
# age                  -0.0471      0.153     -0.308      0.758      -0.349       0.255
# MFQ_SR_NegEmotion     0.2754      0.243      1.134      0.258      -0.204       0.755
# female               -0.2274      0.764     -0.298      0.766      -1.735       1.280
# meanFD                1.2263      2.333      0.526      0.600      -3.380       5.832
# ==============================================================================
# Omnibus:                        0.416   Durbin-Watson:                   2.143
# Prob(Omnibus):                  0.812   Jarque-Bera (JB):                0.221
# Skew:                           0.079   Prob(JB):                        0.895
# Kurtosis:                       3.081   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak6_mean   R-squared:                       0.089
# Model:                            WLS   Adj. R-squared:                  0.067
# Method:                 Least Squares   F-statistic:                     4.043
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):            0.00373
# Time:                        21:15:08   Log-Likelihood:                -483.33
# No. Observations:                 170   AIC:                             976.7
# Df Residuals:                     165   BIC:                             992.3
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             6.9376      1.826      3.800      0.000       3.333      10.542
# age                  -0.1294      0.131     -0.987      0.325      -0.388       0.129
# MFQ_SR_NegEmotion    -0.2738      0.208     -1.316      0.190      -0.685       0.137
# female                1.7093      0.654      2.612      0.010       0.417       3.001
# meanFD               -5.3472      1.999     -2.675      0.008      -9.294      -1.400
# ==============================================================================
# Omnibus:                        5.139   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.077   Jarque-Bera (JB):                4.691
# Skew:                          -0.376   Prob(JB):                       0.0958
# Kurtosis:                       3.312   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak7_mean   R-squared:                       0.067
# Model:                            WLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     2.956
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0216
# Time:                        21:15:08   Log-Likelihood:                -525.52
# No. Observations:                 170   AIC:                             1061.
# Df Residuals:                     165   BIC:                             1077.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             8.6791      2.340      3.709      0.000       4.059      13.299
# age                  -0.5554      0.168     -3.306      0.001      -0.887      -0.224
# MFQ_SR_NegEmotion    -0.0949      0.267     -0.356      0.723      -0.621       0.432
# female               -0.3808      0.839     -0.454      0.650      -2.037       1.275
# meanFD                0.9904      2.562      0.387      0.700      -4.069       6.049
# ==============================================================================
# Omnibus:                        0.060   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.971   Jarque-Bera (JB):                0.108
# Skew:                          -0.044   Prob(JB):                        0.947
# Kurtosis:                       2.914   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak8_mean   R-squared:                       0.075
# Model:                            WLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     3.327
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):             0.0119
# Time:                        21:15:08   Log-Likelihood:                -485.63
# No. Observations:                 170   AIC:                             981.3
# Df Residuals:                     165   BIC:                             996.9
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             4.7114      1.851      2.546      0.012       1.058       8.365
# age                  -0.2927      0.133     -2.203      0.029      -0.555      -0.030
# MFQ_SR_NegEmotion    -0.3620      0.211     -1.716      0.088      -0.778       0.054
# female                1.4312      0.663      2.158      0.032       0.122       2.741
# meanFD                1.2417      2.026      0.613      0.541      -2.759       5.243
# ==============================================================================
# Omnibus:                        5.743   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.057   Jarque-Bera (JB):                6.362
# Skew:                          -0.266   Prob(JB):                       0.0415
# Kurtosis:                       3.785   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_peak9_mean   R-squared:                       0.022
# Model:                            WLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.9239
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):              0.452
# Time:                        21:15:09   Log-Likelihood:                -494.72
# No. Observations:                 170   AIC:                             999.4
# Df Residuals:                     165   BIC:                             1015.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -1.1977      1.952     -0.614      0.540      -5.052       2.657
# age                   0.1872      0.140      1.336      0.183      -0.089       0.464
# MFQ_SR_NegEmotion    -0.0075      0.222     -0.034      0.973      -0.447       0.432
# female                0.5963      0.700      0.852      0.395      -0.785       1.978
# meanFD                2.2131      2.138      1.035      0.302      -2.007       6.434
# ==============================================================================
# Omnibus:                        0.409   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.815   Jarque-Bera (JB):                0.560
# Skew:                          -0.056   Prob(JB):                        0.756
# Kurtosis:                       2.742   Cond. No.                         88.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Mediation Analysis

# %%
import pingouin as pg

# test if membership to each group predicts depression via activation to peak9 scene
# this is unlikely since we don't see an association between activation and depression scores.
data_dm.loc[:,['class1','class2','class3']] = 0
data_dm.loc[data_dm['class_string']=='class01','class1'] = 1
data_dm.loc[data_dm['class_string']=='class02','class2'] = 1
data_dm.loc[data_dm['class_string']=='class03','class3'] = 1

pg.mediation_analysis(data=data_dm, x='class1', y='MFQ_SR_Total', m='VentralAttn_peak9_mean', 
                      covar=['age', 'female', 'meanFD'], seed=42)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class_string'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/0g/g8tyy3vn2zxcv2_bfxpbpr780000gn/T/ipykernel_1741/987245579.py in <module>
#       4 # this is unlikely since we don't see an association between activation and depression scores.
#       5 data_dm.loc[:,['class1','class2','class3']] = 0
# ----> 6 data_dm.loc[data_dm['class_string']=='class01','class1'] = 1
#       7 data_dm.loc[data_dm['class_string']=='class02','class2'] = 1
#       8 data_dm.loc[data_dm['class_string']=='class03','class3'] = 1
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'class_string'

# %%
pg.mediation_analysis(data=data_dm, x='class2', y='MFQ_SR_Total', m='VentralAttn_peak9_mean', 
                      covar=['age', 'female', 'meanFD'], seed=42)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.1, the latest is 0.5.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
pg.mediation_analysis(data=data_dm, x='class3', y='MFQ_SR_Total', m='VentralAttn_peak9_mean', 
                      covar=['age', 'female', 'meanFD'], seed=42)
# Out:
#                          path      coef        se      pval  CI[2.5%]  \
# 0  VentralAttn_peak9_mean ~ X  1.432669  0.713479  0.045346  0.029831
# 1  Y ~ VentralAttn_peak9_mean  0.007599  0.007250  0.295239 -0.006656
# 2                       Total  0.062176  0.101727  0.541430 -0.137839
# 3                      Direct  0.051830  0.102265  0.612572 -0.149244
# 4                    Indirect  0.010345  0.012223  0.384000 -0.008246
#
#    CI[97.5%]  sig
# 0   2.835506  Yes
# 1   0.021854   No
# 2   0.262190   No
# 3   0.252905   No
# 4   0.044318   No
