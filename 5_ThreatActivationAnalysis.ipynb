# %%
import pandas as pd
import numpy as np
import nibabel as nib
import os
import scipy.stats as scp
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date
import itertools
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import statsmodels.formula.api as smf

sns.set(context='talk', style='white', font='Arial')

today = date.today().strftime('%Y%m%d')

#project_dir = '/Users/catcamacho/Library/CloudStorage/Box-Box/CCP/HBN_study/'
project_dir = '/Users/emilyfurtado/Box/HBN_study/'
data_dir = project_dir + 'proc/group/parcel_timeseries/sub_ts/'
out_dir = project_dir + 'stress_analysis/threat_coding/threat_analysis/'
os.makedirs(out_dir,exist_ok=True)

sample_file = project_dir + 'proc/group/datasets_info/sample_gord.32k_fs_LR.pscalar.nii'
atlas_file = project_dir + 'proc/null_lL_WG33/Gordon333_SeitzmanSubcortical.32k_fs_LR.dlabel.nii'
ax0 = nib.load(sample_file).header.get_axis(0)
ax1 = nib.load(sample_file).header.get_axis(1)

TR = 0.8

# load timeseries data info
subinfo = pd.read_csv(project_dir + 'proc/group/datasets/firstleveldatalabels_withpub_thresh0.8_20220412.csv', index_col=0)

# designate stress groups
groups = pd.read_csv(project_dir + 'stress_analysis/factor_analysis/NLES_p_subset_3classes.csv', index_col=0).loc[:,'class'].to_frame()
groups.index = ['sub-{0}'.format(a) for a in groups.index]
groups['class']=['class0{0}'.format(a) for a in groups['class']]

# get network labels
parcel_labels = nib.load(sample_file).header.get_axis(1).name
network_labels = []
for s in parcel_labels:
    b = s.split('_')
    if len(b)<2:
        network_labels.append(b[0])
    else:
        network_labels.append(b[1])
network_labels = np.array(network_labels)
network_names, network_sizes = np.unique(network_labels, return_counts=True)

subinfo = subinfo.drop(['set','cond'], axis=1)
subinfo = subinfo.drop_duplicates()
subinfo = subinfo.merge(groups, how='left', left_index=True, right_index=True)

# %%
def compile_ts_data(subdf, movie, datadir, outfile):
    """
    combine data for each movie together into 1 file
    
    Parameters
    ----------
    subdf: DataFrame
        A dataframe with subject IDs as the index. Includes IDs for all usable data.
    movie: str
        Corresponds with the str for the movie content to concatenate (e.g., "DM" or "TP").
    datadir: folder path
        Path to folder with the subject timeseries ciftis.
    outfile: file path
        Path including filename to save the output data of shape Ntimepoints x Nparcels x Nsubjects.
    
    Returns
    -------
    data: numpy array
        The compiled data of shape Ntimepoints x Nparcels x Nsubjects
    """
    if not isinstance(subdf, pd.DataFrame):
        subdf = pd.read_csv(subdf, index_col=0)
    
    for sub in subdf.index:
        file = '{0}{1}_task-movie{2}_bold1_AP_Atlas_rescale_resid0.9_filt_gordonseitzman.32k_fs_LR.ptseries.nii'.format(datadir,sub, movie)
        if sub == subdf.index[0]:
            data = StandardScaler().fit_transform(nib.load(file).get_fdata())
            data = np.expand_dims(data, axis=2)
        else:
            t = StandardScaler().fit_transform(nib.load(file).get_fdata())
            t = np.expand_dims(t, axis=2)
            data = np.concatenate([data,t],axis=2)
    
    print('Compile data from {0} brain regions measured at {1} timepoints from {2} participants.'.format(data.shape[1],data.shape[0],data.shape[2]))
    np.save(outfile, data)
    return(data)

# %%
for sample in ['rubic','cbic']:
    for movie in ['TP','DM']:
        sampleinfo = subinfo.loc[(subinfo['site']==sample) & (subinfo['movie']==movie) & ((subinfo['class']=='class01') | (subinfo['class']=='class02') | (subinfo['class']=='class03')),:]
        outdir = os.path.join(out_dir, 'activation', 'pr_nle_groups','dynamic_{0}_movie{1}'.format(sample, movie))
        os.makedirs(outdir, exist_ok=True)
        group_data_file = os.path.join(outdir, 'compiled_timeseries_data_{0}_movie{1}.npy'.format(sample, movie))
        if os.path.isfile(group_data_file):
            group_data = np.load(group_data_file)
        else:
            group_data = compile_ts_data(sampleinfo, movie, data_dir, group_data_file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/0g/g8tyy3vn2zxcv2_bfxpbpr780000gn/T/ipykernel_48526/2433943783.py in <module>
#       6         group_data_file = os.path.join(outdir, 'compiled_timeseries_data_{0}_movie{1}.npy'.format(sample, movie))
#       7         if os.path.isfile(group_data_file):
# ----> 8             group_data = np.load(group_data_file)
#       9         else:
#      10             group_data = compile_ts_data(sampleinfo, movie, data_dir, group_data_file)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     438                 return format.open_memmap(file, mode=mmap_mode)
#     439             else:
# --> 440                 return format.read_array(fid, allow_pickle=allow_pickle,
#     441                                          pickle_kwargs=pickle_kwargs)
#     442         else:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     755         if isfileobj(fp):
#     756             # We can use the fast fromfile() function.
# --> 757             array = numpy.fromfile(fp, dtype=dtype, count=count)
#     758         else:
#     759             # This is not a real file. We have to read it the
#
# KeyboardInterrupt:

# %%
network_names

# %%
nois = ['Default', 'VentralAttn', 'CinguloOperc', 'Amygdala']

for movie in ['TP','DM']:
    if movie == 'TP':
        scenes = pd.read_csv(project_dir + "/stress_analysis/threat_coding/movieTP_threat_scenes.csv", index_col = 0)
    elif movie == 'DM':
        scenes = pd.read_csv(project_dir + "/stress_analysis/threat_coding/movieDM_threat_scenes.csv", index_col = 0)
    
    discinfo = subinfo.loc[(subinfo['site']=='rubic') & (subinfo['movie']==movie) & ((subinfo['class']=='class01') | (subinfo['class']=='class02') | (subinfo['class']=='class03')),:]
    repinfo = subinfo.loc[(subinfo['site']=='cbic') & (subinfo['movie']==movie) & ((subinfo['class']=='class01') | (subinfo['class']=='class02') | (subinfo['class']=='class03')),:]    
        
        ####### discovery data #########
    # load data
    disc_ts_file =  os.path.join(out_dir, 'activation', 'pr_nle_groups', 'dynamic_rubic_movie{0}'.format(movie), 
                                 'compiled_timeseries_data_rubic_movie{0}.npy'.format(movie))
    disc_ts = np.load(disc_ts_file)
    # convert to percent signal change
    disc_tss = (disc_ts - disc_ts.min(axis=0, keepdims=True)) / (disc_ts.max(axis=0, keepdims=True) - disc_ts.min(axis=0, keepdims=True))
    mean_sig = np.mean(disc_tss, axis=0, keepdims=True)
    disc_ts = ((disc_tss-mean_sig)/mean_sig)*100

    # average across network/region
    disc_net_ts = np.zeros((disc_ts.shape[0], len(nois), disc_ts.shape[2]))
    for i, n in enumerate(nois):
        disc_net_ts[:,i,:] = np.mean(disc_ts[:,network_labels==n,:], axis=1)

       ####### replication data ######### 
    # load data
    rep_ts_file =  os.path.join(out_dir, 'activation', 'pr_nle_groups', 'dynamic_cbic_movie{0}'.format(movie), 
                                'compiled_timeseries_data_cbic_movie{0}.npy'.format(movie))
    rep_ts = np.load(rep_ts_file)
    # convert to percent signal change
    rep_tss = (rep_ts - rep_ts.min(axis=0, keepdims=True)) / (rep_ts.max(axis=0, keepdims=True) - rep_ts.min(axis=0, keepdims=True))
    mean_sig = np.mean(rep_tss, axis=0, keepdims=True)
    rep_ts = ((rep_tss-mean_sig)/mean_sig)*100

    # average across network/region
    rep_net_ts = np.zeros((rep_ts.shape[0], len(nois), rep_ts.shape[2]))
    for i, n in enumerate(nois):
        rep_net_ts[:,i,:] = np.mean(rep_ts[:,network_labels==n,:], axis=1)
        

    # pull activation for each scene
    for s in scenes.index:
        start = int(scenes.loc[s,'start']/TR)+6
        end = int(scenes.loc[s,'end']/TR)+6
        for i,net in enumerate(nois):
            disc_activation = disc_net_ts[start:end, i, :]
            discinfo['{0}_movie{1}_s{2}'.format(net, movie, s)] = np.mean(disc_activation, axis = 0)
            rep_activation = rep_net_ts[start:end, i, :]
            repinfo['{0}_movie{1}_s{2}'.format(net, movie, s)] = np.mean(rep_activation, axis = 0)
    data = pd.concat([discinfo, repinfo])
    data.to_csv(project_dir + "/stress_analysis/threat_coding/movie{0}_threatactivationdata.csv".format(movie))
# Out:
# /var/folders/0g/g8tyy3vn2zxcv2_bfxpbpr780000gn/T/ipykernel_25149/3020274549.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   discinfo['{0}_movie{1}_s{2}'.format(net, movie, s)] = np.mean(disc_activation, axis = 0)
# /var/folders/0g/g8tyy3vn2zxcv2_bfxpbpr780000gn/T/ipykernel_25149/3020274549.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   repinfo['{0}_movie{1}_s{2}'.format(net, movie, s)] = np.mean(rep_activation, axis = 0)

# %%
#full data including depression scores
dep_data = pd.read_csv(project_dir+"/stress_analysis/full_data_20220124.csv", index_col = 0)
dep_data = dep_data.loc[:,["MFQ_P_Total", "MFQ_SR_Total", "MDD_mean"]]
dep_data.index.name = "sub"

#neural activation data
data_dm = pd.read_csv(project_dir + "/stress_analysis/threat_coding/movieDM_threatactivationdata.csv", index_col = 0)
data_tp = pd.read_csv(project_dir + "/stress_analysis/threat_coding/movieTP_threatactivationdata.csv", index_col = 0)

# merge activation and full data
data_dm = data_dm.merge(dep_data, how = "left", left_index = True, right_index = True).drop_duplicates()
data_tp = data_tp.merge(dep_data, how = "left", left_index = True, right_index = True).drop_duplicates()

# %% [markdown]
# ## Despicable Me

# %%
#weighted least squares regression model - movie DM (Discovery)
results = pd.DataFrame()
scenes = ["Default_movieDM_s1", "VentralAttn_movieDM_s1", "CinguloOperc_movieDM_s1", "Amygdala_movieDM_s1",
          "Default_movieDM_s3", "VentralAttn_movieDM_s3", "CinguloOperc_movieDM_s3", "Amygdala_movieDM_s3"]
          
data_dm["class_string"] = data_dm["class"]
ind = 0
for site in ["rubic", "cbic"]:
    for x in scenes:
        res = smf.wls("{0} ~ age + class_string + female + meanFD".format(x), 
                  data = data_dm.loc[data_dm['site'] == site,:]).fit()
        results.loc[ind, 'dataset'] = site
        results.loc[ind, 'movie'] = 'DM'
        results.loc[ind, 'sceneNo'] = x
        results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.class02]']
        results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.class02]']
        results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.class03]']
        results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.class03]']
        ind = ind + 1
        print(res.summary())
    
results.to_csv(project_dir + "/stress_analysis/threat_coding/movieDM_threatactivationstressanalysis.csv")
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_movieDM_s1   R-squared:                       0.023
# Model:                            WLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     1.323
# Date:                Tue, 05 Jul 2022   Prob (F-statistic):              0.254
# Time:                        19:00:05   Log-Likelihood:                -822.56
# No. Observations:                 286   AIC:                             1657.
# Df Residuals:                     280   BIC:                             1679.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -0.2250      1.285     -0.175      0.861      -2.754       2.304
# class_string[T.class02]    -1.4723      0.732     -2.011      0.045      -2.914      -0.031
# class_string[T.class03]    -1.4250      0.648     -2.199      0.029      -2.701      -0.149
# age                         0.0720      0.103      0.701      0.484      -0.130       0.274
# female                     -0.4570      0.543     -0.842      0.401      -1.526       0.612
# meanFD                     -0.9998      1.681     -0.595      0.552      -4.309       2.309
# ==============================================================================
# Omnibus:                        4.378   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.112   Jarque-Bera (JB):                4.095
# Skew:                           0.244   Prob(JB):                        0.129
# Kurtosis:                       3.324   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_movieDM_s1   R-squared:                       0.086
# Model:                                WLS   Adj. R-squared:                  0.070
# Method:                     Least Squares   F-statistic:                     5.280
# Date:                    Tue, 05 Jul 2022   Prob (F-statistic):           0.000119
# Time:                            19:00:05   Log-Likelihood:                -898.37
# No. Observations:                     286   AIC:                             1809.
# Df Residuals:                         280   BIC:                             1831.
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   0.0082      1.675      0.005      0.996      -3.288       3.304
# class_string[T.class02]     1.9344      0.954      2.027      0.044       0.056       3.813
# class_string[T.class03]     2.4965      0.845      2.955      0.003       0.834       4.159
# age                         0.2370      0.134      1.770      0.078      -0.027       0.501
# female                     -1.1405      0.708     -1.612      0.108      -2.533       0.252
# meanFD                     -5.7349      2.191     -2.617      0.009     -10.048      -1.422
# ==============================================================================
# Omnibus:                        0.466   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.792   Jarque-Bera (JB):                0.328
# Skew:                           0.078   Prob(JB):                        0.849
# Kurtosis:                       3.058   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_movieDM_s1   R-squared:                       0.014
# Model:                                 WLS   Adj. R-squared:                 -0.004
# Method:                      Least Squares   F-statistic:                    0.7785
# Date:                     Tue, 05 Jul 2022   Prob (F-statistic):              0.566
# Time:                             19:00:05   Log-Likelihood:                -906.12
# No. Observations:                      286   AIC:                             1824.
# Df Residuals:                          280   BIC:                             1846.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -1.2834      1.721     -0.746      0.456      -4.670       2.104
# class_string[T.class02]     0.1096      0.981      0.112      0.911      -1.821       2.040
# class_string[T.class03]    -0.4601      0.868     -0.530      0.596      -2.169       1.249
# age                         0.0021      0.138      0.015      0.988      -0.269       0.273
# female                     -0.2708      0.727     -0.373      0.710      -1.702       1.160
# meanFD                      3.7868      2.251      1.682      0.094      -0.645       8.219
# ==============================================================================
# Omnibus:                       11.723   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               11.995
# Skew:                           0.485   Prob(JB):                      0.00249
# Kurtosis:                       3.254   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              WLS Regression Results
# ===============================================================================
# Dep. Variable:     Amygdala_movieDM_s1   R-squared:                       0.018
# Model:                             WLS   Adj. R-squared:                  0.000
# Method:                  Least Squares   F-statistic:                     1.009
# Date:                 Tue, 05 Jul 2022   Prob (F-statistic):              0.413
# Time:                         19:00:05   Log-Likelihood:                -1065.7
# No. Observations:                  286   AIC:                             2143.
# Df Residuals:                      280   BIC:                             2165.
# Df Model:                            5
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -1.2306      3.006     -0.409      0.683      -7.148       4.687
# class_string[T.class02]     1.8148      1.713      1.059      0.290      -1.558       5.187
# class_string[T.class03]     1.6821      1.516      1.109      0.268      -1.303       4.667
# age                         0.1138      0.240      0.473      0.636      -0.359       0.587
# female                     -0.4429      1.270     -0.349      0.728      -2.943       2.057
# meanFD                     -6.0704      3.933     -1.543      0.124     -13.813       1.672
# ==============================================================================
# Omnibus:                        7.967   Durbin-Watson:                   2.076
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):               12.257
# Skew:                          -0.140   Prob(JB):                      0.00218
# Kurtosis:                       3.975   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_movieDM_s3   R-squared:                       0.020
# Model:                            WLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.156
# Date:                Tue, 05 Jul 2022   Prob (F-statistic):              0.331
# Time:                        19:00:05   Log-Likelihood:                -834.05
# No. Observations:                 286   AIC:                             1680.
# Df Residuals:                     280   BIC:                             1702.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -2.8868      1.337     -2.159      0.032      -5.519      -0.254
# class_string[T.class02]     0.5744      0.762      0.754      0.452      -0.926       2.075
# class_string[T.class03]     0.9527      0.675      1.412      0.159      -0.375       2.281
# age                        -0.1002      0.107     -0.937      0.350      -0.311       0.110
# female                      0.5396      0.565      0.955      0.340      -0.573       1.652
# meanFD                      2.5876      1.750      1.479      0.140      -0.857       6.032
# ==============================================================================
# Omnibus:                        1.421   Durbin-Watson:                   2.085
# Prob(Omnibus):                  0.491   Jarque-Bera (JB):                1.193
# Skew:                          -0.001   Prob(JB):                        0.551
# Kurtosis:                       3.316   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_movieDM_s3   R-squared:                       0.069
# Model:                                WLS   Adj. R-squared:                  0.053
# Method:                     Least Squares   F-statistic:                     4.160
# Date:                    Tue, 05 Jul 2022   Prob (F-statistic):            0.00116
# Time:                            19:00:05   Log-Likelihood:                -978.34
# No. Observations:                     286   AIC:                             1969.
# Df Residuals:                         280   BIC:                             1991.
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  10.3394      2.215      4.668      0.000       5.980      14.699
# class_string[T.class02]     1.9707      1.262      1.561      0.120      -0.514       4.456
# class_string[T.class03]     0.9358      1.117      0.838      0.403      -1.264       3.135
# age                         0.2756      0.177      1.556      0.121      -0.073       0.624
# female                     -1.5160      0.936     -1.620      0.106      -3.358       0.326
# meanFD                     -9.1011      2.898     -3.140      0.002     -14.806      -3.396
# ==============================================================================
# Omnibus:                        0.886   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.642   Jarque-Bera (JB):                0.698
# Skew:                          -0.113   Prob(JB):                        0.705
# Kurtosis:                       3.086   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_movieDM_s3   R-squared:                       0.020
# Model:                                 WLS   Adj. R-squared:                  0.003
# Method:                      Least Squares   F-statistic:                     1.170
# Date:                     Tue, 05 Jul 2022   Prob (F-statistic):              0.324
# Time:                             19:00:05   Log-Likelihood:                -885.85
# No. Observations:                      286   AIC:                             1784.
# Df Residuals:                          280   BIC:                             1806.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -3.8140      1.603     -2.380      0.018      -6.969      -0.659
# class_string[T.class02]     1.0668      0.914      1.168      0.244      -0.731       2.865
# class_string[T.class03]     0.4808      0.809      0.595      0.553      -1.111       2.072
# age                         0.0402      0.128      0.314      0.754      -0.212       0.293
# female                      1.0820      0.677      1.598      0.111      -0.251       2.415
# meanFD                      3.3177      2.097      1.582      0.115      -0.811       7.446
# ==============================================================================
# Omnibus:                        1.246   Durbin-Watson:                   2.061
# Prob(Omnibus):                  0.536   Jarque-Bera (JB):                0.978
# Skew:                           0.053   Prob(JB):                        0.613
# Kurtosis:                       3.266   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              WLS Regression Results
# ===============================================================================
# Dep. Variable:     Amygdala_movieDM_s3   R-squared:                       0.008
# Model:                             WLS   Adj. R-squared:                 -0.010
# Method:                  Least Squares   F-statistic:                    0.4325
# Date:                 Tue, 05 Jul 2022   Prob (F-statistic):              0.826
# Time:                         19:00:05   Log-Likelihood:                -1128.2
# No. Observations:                  286   AIC:                             2268.
# Df Residuals:                      280   BIC:                             2290.
# Df Model:                            5
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -5.0290      3.740     -1.345      0.180     -12.392       2.334
# class_string[T.class02]    -1.1365      2.132     -0.533      0.594      -5.333       3.060
# class_string[T.class03]    -0.5451      1.887     -0.289      0.773      -4.259       3.169
# age                         0.3227      0.299      1.079      0.281      -0.266       0.911
# female                     -0.4446      1.580     -0.281      0.779      -3.556       2.666
# meanFD                      4.4673      4.894      0.913      0.362      -5.167      14.101
# ==============================================================================
# Omnibus:                       63.836   Durbin-Watson:                   2.145
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              256.165
# Skew:                           0.868   Prob(JB):                     2.37e-56
# Kurtosis:                       7.299   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_movieDM_s1   R-squared:                       0.055
# Model:                            WLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     2.356
# Date:                Tue, 05 Jul 2022   Prob (F-statistic):             0.0417
# Time:                        19:00:05   Log-Likelihood:                -587.14
# No. Observations:                 210   AIC:                             1186.
# Df Residuals:                     204   BIC:                             1206.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -1.8920      1.400     -1.351      0.178      -4.653       0.869
# class_string[T.class02]     1.2252      0.777      1.576      0.117      -0.308       2.758
# class_string[T.class03]     0.0981      0.709      0.138      0.890      -1.300       1.496
# age                         0.1601      0.093      1.725      0.086      -0.023       0.343
# female                     -1.0277      0.572     -1.796      0.074      -2.156       0.101
# meanFD                     -1.5825      1.651     -0.959      0.339      -4.837       1.672
# ==============================================================================
# Omnibus:                        0.603   Durbin-Watson:                   1.845
# Prob(Omnibus):                  0.740   Jarque-Bera (JB):                0.326
# Skew:                          -0.043   Prob(JB):                        0.849
# Kurtosis:                       3.173   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_movieDM_s1   R-squared:                       0.054
# Model:                                WLS   Adj. R-squared:                  0.031
# Method:                     Least Squares   F-statistic:                     2.319
# Date:                    Tue, 05 Jul 2022   Prob (F-statistic):             0.0447
# Time:                            19:00:05   Log-Likelihood:                -664.89
# No. Observations:                     210   AIC:                             1342.
# Df Residuals:                         204   BIC:                             1362.
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   6.0956      2.028      3.006      0.003       2.098      10.094
# class_string[T.class02]     1.5903      1.126      1.413      0.159      -0.630       3.810
# class_string[T.class03]     1.3637      1.027      1.328      0.186      -0.661       3.388
# age                        -0.0077      0.134     -0.057      0.955      -0.273       0.257
# female                     -0.3287      0.829     -0.397      0.692      -1.963       1.305
# meanFD                     -6.7995      2.390     -2.845      0.005     -11.512      -2.087
# ==============================================================================
# Omnibus:                        1.176   Durbin-Watson:                   2.062
# Prob(Omnibus):                  0.555   Jarque-Bera (JB):                1.135
# Skew:                           0.045   Prob(JB):                        0.567
# Kurtosis:                       2.651   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_movieDM_s1   R-squared:                       0.028
# Model:                                 WLS   Adj. R-squared:                  0.004
# Method:                      Least Squares   F-statistic:                     1.167
# Date:                     Tue, 05 Jul 2022   Prob (F-statistic):              0.327
# Time:                             19:00:05   Log-Likelihood:                -657.80
# No. Observations:                      210   AIC:                             1328.
# Df Residuals:                          204   BIC:                             1348.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -4.0359      1.960     -2.059      0.041      -7.901      -0.170
# class_string[T.class02]    -1.0528      1.088     -0.967      0.335      -3.199       1.093
# class_string[T.class03]    -0.5345      0.993     -0.538      0.591      -2.492       1.423
# age                         0.1765      0.130      1.359      0.176      -0.080       0.433
# female                      0.0915      0.801      0.114      0.909      -1.488       1.671
# meanFD                      4.0641      2.311      1.759      0.080      -0.492       8.620
# ==============================================================================
# Omnibus:                        2.723   Durbin-Watson:                   2.049
# Prob(Omnibus):                  0.256   Jarque-Bera (JB):                2.368
# Skew:                           0.245   Prob(JB):                        0.306
# Kurtosis:                       3.173   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              WLS Regression Results
# ===============================================================================
# Dep. Variable:     Amygdala_movieDM_s1   R-squared:                       0.015
# Model:                             WLS   Adj. R-squared:                 -0.009
# Method:                  Least Squares   F-statistic:                    0.6271
# Date:                 Tue, 05 Jul 2022   Prob (F-statistic):              0.679
# Time:                         19:00:05   Log-Likelihood:                -776.53
# No. Observations:                  210   AIC:                             1565.
# Df Residuals:                      204   BIC:                             1585.
# Df Model:                            5
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -3.4853      3.451     -1.010      0.314     -10.289       3.318
# class_string[T.class02]     0.2082      1.916      0.109      0.914      -3.569       3.986
# class_string[T.class03]     1.3779      1.748      0.788      0.431      -2.068       4.823
# age                        -0.0905      0.229     -0.396      0.693      -0.541       0.360
# female                     -0.1620      1.410     -0.115      0.909      -2.942       2.618
# meanFD                      6.1108      4.067      1.502      0.135      -1.909      14.131
# ==============================================================================
# Omnibus:                       14.726   Durbin-Watson:                   2.106
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               33.251
# Skew:                          -0.257   Prob(JB):                     6.02e-08
# Kurtosis:                       4.880   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_movieDM_s3   R-squared:                       0.009
# Model:                            WLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                    0.3776
# Date:                Tue, 05 Jul 2022   Prob (F-statistic):              0.864
# Time:                        19:00:05   Log-Likelihood:                -620.38
# No. Observations:                 210   AIC:                             1253.
# Df Residuals:                     204   BIC:                             1273.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -0.9594      1.640     -0.585      0.559      -4.194       2.275
# class_string[T.class02]    -0.0153      0.911     -0.017      0.987      -1.811       1.781
# class_string[T.class03]    -0.3817      0.831     -0.459      0.646      -2.020       1.256
# age                         0.0675      0.109      0.621      0.536      -0.147       0.282
# female                     -0.6256      0.670     -0.933      0.352      -1.947       0.696
# meanFD                      1.1488      1.934      0.594      0.553      -2.664       4.961
# ==============================================================================
# Omnibus:                        2.409   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.300   Jarque-Bera (JB):                2.222
# Skew:                           0.107   Prob(JB):                        0.329
# Kurtosis:                       3.456   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_movieDM_s3   R-squared:                       0.064
# Model:                                WLS   Adj. R-squared:                  0.041
# Method:                     Least Squares   F-statistic:                     2.802
# Date:                    Tue, 05 Jul 2022   Prob (F-statistic):             0.0180
# Time:                            19:00:05   Log-Likelihood:                -724.08
# No. Observations:                     210   AIC:                             1460.
# Df Residuals:                         204   BIC:                             1480.
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   5.7689      2.688      2.146      0.033       0.469      11.069
# class_string[T.class02]     2.5001      1.492      1.675      0.095      -0.442       5.443
# class_string[T.class03]     2.2372      1.361      1.643      0.102      -0.447       4.921
# age                         0.4231      0.178      2.376      0.018       0.072       0.774
# female                      0.7414      1.099      0.675      0.501      -1.425       2.907
# meanFD                     -5.4391      3.169     -1.717      0.088     -11.686       0.808
# ==============================================================================
# Omnibus:                       17.834   Durbin-Watson:                   1.857
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.081
# Skew:                          -0.545   Prob(JB):                     3.58e-06
# Kurtosis:                       4.296   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_movieDM_s3   R-squared:                       0.055
# Model:                                 WLS   Adj. R-squared:                  0.032
# Method:                      Least Squares   F-statistic:                     2.393
# Date:                     Tue, 05 Jul 2022   Prob (F-statistic):             0.0390
# Time:                             19:00:05   Log-Likelihood:                -625.37
# No. Observations:                      210   AIC:                             1263.
# Df Residuals:                          204   BIC:                             1283.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -5.0745      1.680     -3.021      0.003      -8.387      -1.762
# class_string[T.class02]    -0.2573      0.933     -0.276      0.783      -2.096       1.582
# class_string[T.class03]     0.2907      0.851      0.342      0.733      -1.387       1.968
# age                        -0.0553      0.111     -0.497      0.620      -0.275       0.164
# female                      1.6344      0.687      2.380      0.018       0.281       2.988
# meanFD                      4.2541      1.980      2.148      0.033       0.350       8.159
# ==============================================================================
# Omnibus:                        2.840   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.242   Jarque-Bera (JB):                2.830
# Skew:                           0.103   Prob(JB):                        0.243
# Kurtosis:                       3.530   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              WLS Regression Results
# ===============================================================================
# Dep. Variable:     Amygdala_movieDM_s3   R-squared:                       0.004
# Model:                             WLS   Adj. R-squared:                 -0.021
# Method:                  Least Squares   F-statistic:                    0.1509
# Date:                 Tue, 05 Jul 2022   Prob (F-statistic):              0.980
# Time:                         19:00:06   Log-Likelihood:                -823.34
# No. Observations:                  210   AIC:                             1659.
# Df Residuals:                      204   BIC:                             1679.
# Df Model:                            5
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -3.7622      4.312     -0.872      0.384     -12.265       4.740
# class_string[T.class02]     0.2919      2.394      0.122      0.903      -4.429       5.013
# class_string[T.class03]     0.8347      2.184      0.382      0.703      -3.471       5.141
# age                         0.0032      0.286      0.011      0.991      -0.560       0.567
# female                      1.2238      1.762      0.694      0.488      -2.251       4.699
# meanFD                     -1.3982      5.083     -0.275      0.784     -11.421       8.624
# ==============================================================================
# Omnibus:                        0.290   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.865   Jarque-Bera (JB):                0.097
# Skew:                          -0.018   Prob(JB):                        0.953
# Kurtosis:                       3.099   Cond. No.                         80.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## The Present

# %%
#weighted least squares regression model - movie TP (Discovery)
results = pd.DataFrame()
scenes = ["Default_movieTP_s0", "VentralAttn_movieTP_s0", "CinguloOperc_movieTP_s0", "Amygdala_movieTP_s0"]
          
data_tp["class_string"] = data_tp["class"]
ind = 0
for site in ["rubic", "cbic"]:
    for x in scenes:
        res = smf.wls("{0} ~ age + class_string + female + meanFD".format(x), 
                  data = data_tp.loc[data_tp['site'] == site,:]).fit()
        results.loc[ind, 'dataset'] = site
        results.loc[ind, 'movie'] = 'TP'
        results.loc[ind, 'sceneNo'] = x
        results.loc[ind, 'group2_tstat'] = res.tvalues['class_string[T.class02]']
        results.loc[ind, 'group2_pval'] = res.pvalues['class_string[T.class02]']
        results.loc[ind, 'group3_tstat'] = res.tvalues['class_string[T.class03]']
        results.loc[ind, 'group3_pval'] = res.pvalues['class_string[T.class03]']
        ind = ind + 1
        print(res.summary())
    
results.to_csv(project_dir + "/stress_analysis/threat_coding/movieTP_threatactivationstressanalysis.csv")
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_movieTP_s0   R-squared:                       0.007
# Model:                            WLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.4704
# Date:                Tue, 05 Jul 2022   Prob (F-statistic):              0.798
# Time:                        19:00:57   Log-Likelihood:                -943.90
# No. Observations:                 329   AIC:                             1900.
# Df Residuals:                     323   BIC:                             1923.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -0.0016      1.159     -0.001      0.999      -2.282       2.279
# class_string[T.class02]     0.1152      0.653      0.176      0.860      -1.170       1.400
# class_string[T.class03]     0.2811      0.598      0.470      0.639      -0.896       1.458
# age                         0.0835      0.093      0.898      0.370      -0.099       0.266
# female                     -0.2827      0.504     -0.561      0.576      -1.275       0.710
# meanFD                      1.3547      1.437      0.943      0.347      -1.473       4.182
# ==============================================================================
# Omnibus:                       36.805   Durbin-Watson:                   1.876
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.232
# Skew:                           0.685   Prob(JB):                     8.33e-14
# Kurtosis:                       4.586   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_movieTP_s0   R-squared:                       0.013
# Model:                                WLS   Adj. R-squared:                 -0.002
# Method:                     Least Squares   F-statistic:                    0.8400
# Date:                    Tue, 05 Jul 2022   Prob (F-statistic):              0.522
# Time:                            19:00:57   Log-Likelihood:                -1021.7
# No. Observations:                     329   AIC:                             2055.
# Df Residuals:                         323   BIC:                             2078.
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -1.4728      1.468     -1.003      0.317      -4.361       1.416
# class_string[T.class02]    -0.8887      0.827     -1.074      0.283      -2.516       0.739
# class_string[T.class03]     0.0915      0.758      0.121      0.904      -1.399       1.582
# age                         0.0229      0.118      0.194      0.846      -0.209       0.254
# female                     -0.5906      0.639     -0.924      0.356      -1.848       0.667
# meanFD                      1.8849      1.821      1.035      0.301      -1.697       5.467
# ==============================================================================
# Omnibus:                        9.583   Durbin-Watson:                   1.795
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               17.053
# Skew:                           0.087   Prob(JB):                     0.000198
# Kurtosis:                       4.102   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_movieTP_s0   R-squared:                       0.023
# Model:                                 WLS   Adj. R-squared:                  0.008
# Method:                      Least Squares   F-statistic:                     1.515
# Date:                     Tue, 05 Jul 2022   Prob (F-statistic):              0.185
# Time:                             19:00:57   Log-Likelihood:                -1007.5
# No. Observations:                      329   AIC:                             2027.
# Df Residuals:                          323   BIC:                             2050.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -1.7419      1.406     -1.239      0.216      -4.509       1.025
# class_string[T.class02]    -0.1611      0.792     -0.203      0.839      -1.720       1.398
# class_string[T.class03]     0.7342      0.726      1.012      0.312      -0.694       2.162
# age                         0.0115      0.113      0.102      0.919      -0.210       0.233
# female                      0.0538      0.612      0.088      0.930      -1.150       1.258
# meanFD                      4.1000      1.744      2.351      0.019       0.669       7.531
# ==============================================================================
# Omnibus:                        8.597   Durbin-Watson:                   2.116
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):               13.346
# Skew:                          -0.140   Prob(JB):                      0.00126
# Kurtosis:                       3.946   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              WLS Regression Results
# ===============================================================================
# Dep. Variable:     Amygdala_movieTP_s0   R-squared:                       0.016
# Model:                             WLS   Adj. R-squared:                  0.001
# Method:                  Least Squares   F-statistic:                     1.046
# Date:                 Tue, 05 Jul 2022   Prob (F-statistic):              0.391
# Time:                         19:00:57   Log-Likelihood:                -1297.6
# No. Observations:                  329   AIC:                             2607.
# Df Residuals:                      323   BIC:                             2630.
# Df Model:                            5
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   0.9301      3.396      0.274      0.784      -5.751       7.611
# class_string[T.class02]     0.0076      1.913      0.004      0.997      -3.757       3.772
# class_string[T.class03]    -0.3937      1.753     -0.225      0.822      -3.842       3.054
# age                         0.2865      0.272      1.052      0.293      -0.249       0.822
# female                      2.7756      1.478      1.878      0.061      -0.132       5.683
# meanFD                     -3.0177      4.211     -0.717      0.474     -11.303       5.267
# ==============================================================================
# Omnibus:                       25.318   Durbin-Watson:                   2.118
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.448
# Skew:                           0.403   Prob(JB):                     2.48e-12
# Kurtosis:                       4.803   Cond. No.                         72.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     Default_movieTP_s0   R-squared:                       0.045
# Model:                            WLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     2.254
# Date:                Tue, 05 Jul 2022   Prob (F-statistic):             0.0498
# Time:                        19:00:57   Log-Likelihood:                -715.46
# No. Observations:                 244   AIC:                             1443.
# Df Residuals:                     238   BIC:                             1464.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   4.3729      1.444      3.029      0.003       1.529       7.217
# class_string[T.class02]    -0.2800      0.852     -0.329      0.743      -1.958       1.398
# class_string[T.class03]    -0.1794      0.754     -0.238      0.812      -1.665       1.307
# age                        -0.2644      0.105     -2.510      0.013      -0.472      -0.057
# female                     -1.0112      0.614     -1.646      0.101      -2.222       0.199
# meanFD                      0.5486      1.556      0.353      0.725      -2.517       3.614
# ==============================================================================
# Omnibus:                        3.350   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.187   Jarque-Bera (JB):                3.416
# Skew:                           0.267   Prob(JB):                        0.181
# Kurtosis:                       2.772   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     VentralAttn_movieTP_s0   R-squared:                       0.037
# Model:                                WLS   Adj. R-squared:                  0.017
# Method:                     Least Squares   F-statistic:                     1.852
# Date:                    Tue, 05 Jul 2022   Prob (F-statistic):              0.104
# Time:                            19:00:57   Log-Likelihood:                -779.85
# No. Observations:                     244   AIC:                             1572.
# Df Residuals:                         238   BIC:                             1593.
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   0.3070      1.879      0.163      0.870      -3.396       4.009
# class_string[T.class02]    -0.5948      1.109     -0.536      0.592      -2.780       1.590
# class_string[T.class03]    -0.1351      0.982     -0.138      0.891      -2.070       1.800
# age                        -0.0106      0.137     -0.077      0.939      -0.281       0.260
# female                     -2.3425      0.800     -2.928      0.004      -3.918      -0.766
# meanFD                      0.1272      2.026      0.063      0.950      -3.865       4.119
# ==============================================================================
# Omnibus:                        1.370   Durbin-Watson:                   2.174
# Prob(Omnibus):                  0.504   Jarque-Bera (JB):                1.080
# Skew:                          -0.142   Prob(JB):                        0.583
# Kurtosis:                       3.160   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                WLS Regression Results
# ===================================================================================
# Dep. Variable:     CinguloOperc_movieTP_s0   R-squared:                       0.011
# Model:                                 WLS   Adj. R-squared:                 -0.009
# Method:                      Least Squares   F-statistic:                    0.5452
# Date:                     Tue, 05 Jul 2022   Prob (F-statistic):              0.742
# Time:                             19:00:57   Log-Likelihood:                -789.65
# No. Observations:                      244   AIC:                             1591.
# Df Residuals:                          238   BIC:                             1612.
# Df Model:                                5
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -1.8959      1.956     -0.969      0.333      -5.750       1.958
# class_string[T.class02]    -1.0074      1.155     -0.873      0.384      -3.282       1.267
# class_string[T.class03]    -0.7030      1.022     -0.688      0.492      -2.717       1.311
# age                         0.1323      0.143      0.927      0.355      -0.149       0.414
# female                      0.3687      0.833      0.443      0.658      -1.272       2.009
# meanFD                      2.0507      2.109      0.972      0.332      -2.105       6.206
# ==============================================================================
# Omnibus:                       28.848   Durbin-Watson:                   2.140
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.844
# Skew:                           0.653   Prob(JB):                     9.11e-12
# Kurtosis:                       4.816   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              WLS Regression Results
# ===============================================================================
# Dep. Variable:     Amygdala_movieTP_s0   R-squared:                       0.018
# Model:                             WLS   Adj. R-squared:                 -0.003
# Method:                  Least Squares   F-statistic:                    0.8756
# Date:                 Tue, 05 Jul 2022   Prob (F-statistic):              0.498
# Time:                         19:00:57   Log-Likelihood:                -992.93
# No. Observations:                  244   AIC:                             1998.
# Df Residuals:                      238   BIC:                             2019.
# Df Model:                            5
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   8.1204      4.501      1.804      0.072      -0.746      16.987
# class_string[T.class02]     3.0563      2.656      1.151      0.251      -2.176       8.289
# class_string[T.class03]     2.9356      2.352      1.248      0.213      -1.697       7.569
# age                        -0.3116      0.328     -0.949      0.344      -0.959       0.335
# female                     -0.0635      1.916     -0.033      0.974      -3.838       3.711
# meanFD                     -7.0347      4.852     -1.450      0.148     -16.594       2.525
# ==============================================================================
# Omnibus:                       17.926   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.071
# Skew:                           0.294   Prob(JB):                     7.32e-10
# Kurtosis:                       4.947   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
